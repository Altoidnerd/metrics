# %%
from collections import Counter
import datetime
import json
import matplotlib.pyplot as plt
from os.path import abspath, isdir, isfile, join
from os import mkdir
import pandas as pd
import requests
import sys

from secrets import secrets

auth = secrets.get('mixpanel').get('auth')

pd.set_option('max_columns', None)
# pd.set_option('display.max_rows', None)


def get_data_between(start_date=None, 
                     end_date=None,
                     verbose=False):

    print('Doing API call to mixpanel.')
    
    if start_date is None or end_date is None:
        start_date = '2022-1-1'
        end_date   = '2022-1-7'
    
    url = f'https://data.mixpanel.com/api/2.0/export?from_date={start_date}&to_date={end_date}'
    headers = {
        "accept": "text/plain",
        "authorization": f"{auth}"
    }
    print(f'Getting {url} with \n{headers}')
    response = requests.get(url, headers=headers)
    
    verbose and print(response.text[:200])
    result = {'events': []}
    events = response.text.strip().split('\n')
    

    print(f'Response received. Processing events between {start_date} and {end_date}.')
    for event in events:
        result['events'].append(json.loads(event))


    # Flatten all events
    print(f'''{len(result['events'])} events received.''')
    data =  [ _['properties'] for _ in result['events']] 
    df = pd.DataFrame.from_records(data)

    # this df is missing the event names
    # df
    def humanize_timestamp(ts):
        ts = int(ts)
        return datetime.datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')

    # changing unix timestamp to stuff that is useful
    # a human readable date string
    df['date'] = [ humanize_timestamp(ts) for ts in df.time ] 
    # a python datetime format
    df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
    # the event names are here:
    event_names = [ _['event'] for _ in result['events']]
    # reorder the columns
    old_columns = list(df.columns)
    df['event'] = event_names
    newcolumns = ['event', 'date'] + old_columns
    df = df[newcolumns]
    
    print(f'Flattened data has {len(df)} rows.')
    return df


def do_histogram(df,
                 save_as=None):
    
    '''
    If save is None, no plot will be saved;
    else, pass a string and itll save to that path.
    '''
    
    print('Building histogram')
    
    c = dict(Counter(df.event).most_common(20))
    c.pop('performance__network', None)
    fig, ax = plt.subplots(figsize=(20, 7))
    # plt.rcParams["figure.figsize"] = [20, 7]
    # plt.rcParams["figure.autolayout"] = True
    plt.xticks(rotation=70)
    plt.yscale('log')
    plt.title('Frequency of most common user events in November')
    plt.bar(c.keys(), c.values())
    plt.show()
    
    if save_as:
        outfile = join(abspath('img'), save_as)
        if len(outfile.split('.'))>=1:
            astype = outfile.split('.')[-1]
        else:
            astype = 'pdf'
            outfile = outfile+'.pdf'
            
        plt.savefig(outfile,
                    dpi=300,
                    format=astype)
    
    return plt

    
odfs = []
    
def main(outdir='data'):

    i_date = datetime.date(2022,3,13)
    dt = datetime.timedelta(days=1)

    for i in range(332):
        new_date = (i_date+dt*i).isoformat()
        print(f'Doing date: {new_date}.')
        try:
            df = get_data_between(start_date=new_date,
                                  end_date=new_date,
                                  verbose=1)

            do_histogram(df)
            
            if not isdir(outdir):
                if not isdir(abspath(outdir)):
                    print(f'Making {abspath(outdir)}')
                    mkdir(abspath(outdir))
            
            outfile = join(abspath(outdir), f'{new_date}.csv')
            print(f'Saving to {outfile}.') # defaults to ./data/
            df.to_csv(outfile)
            odfs.append(df)
            print(len(odfs), 'many dfs')

        except:
            log = {}
            log['date'] = new_date
            log['e'] = f'Exception occured trying to fetch {new_date}.'
            log['info'] = str(sys.exc_info())
            continue

    
    
# outdir = 'data'
# i_date = datetime.date(2022,4,12)
# dt = datetime.timedelta(days=1)

# # dfs = [] 

# for i in range(300):
#     start_date = (i_date + dt*i).isoformat()
#     end_date = start_date
    
#     print(start_date)
#     try:
#         df = get_data_between(start_date=start_date, 
#                               end_date=end_date,
#                               verbose=1)

#         devices = dict(Counter(df['$model']).most_common(20))
#         devices_users = dict()
#         devices_N_users = dict()

#         outfile = join(abspath(outdir), f'{start_date}.csv')
#         print(f'Saving to {outfile}.') # defaults to ./data/
#         df.to_csv(outfile)
#         odfs.append(df)
#         print(len(odfs), 'many dfs')

#         dfs.append(df)
#         # plt.rcParams["figure.figsize"] = [20, 7]
#         # plt.rcParams["figure.autolayout"] = True
#         plt.xticks(rotation=70)
#         plt.yscale('log')
#         plt.title(f'Frequency of most common devices on {start_date}.')
#         plt.bar(devices.keys(), devices.values())
#         plt.show()
#         print('Number of dfs:',len(dfs))
    
#     except:
#         continue
        
        
# main()
    
#     df = get_data_between(start_date=new_date,
#                           end_date=new_date)

#     do_histogram(df)

#     outfile = f'~/Desktop/EVENTS/{new_date}.csv'
#     print(f'Saving to {outfile}.')
#     df.to_csv(outfile)

dfs = []
    
outdir = 'data'
i_date = datetime.date(2023,1,1)
dt = datetime.timedelta(days=1)

# dfs = [] 

for i in range(31):
    start_date = (i_date + dt*i).isoformat()
    end_date = start_date
    
    if isfile(f'./data/{start_date}.csv'):
        print(f'./data/{start_date}.csv exists; skipping.')
        continue
    
    print(start_date)
    try:
        df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)

        devices = dict(Counter(df['$model']).most_common(20))
        devices_users = dict()
        devices_N_users = dict()

        outfile = join(abspath(outdir), f'{start_date}.csv')
        print(f'Saving to {outfile}.') # defaults to ./data/
        df.to_csv(outfile)
        odfs.append(df)
        print(len(odfs), 'many dfs')

        dfs.append(df)
        # plt.rcParams["figure.figsize"] = [20, 7]
        # plt.rcParams["figure.autolayout"] = True
        plt.xticks(rotation=70)
        plt.yscale('log')
        plt.title(f'Frequency of most common devices on {start_date}.')
        plt.bar(devices.keys(), devices.values())
        plt.show()
        print('Number of dfs:',len(dfs))
    

    except:
        continue
# Out:
# 2023-01-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-01&to_date=2023-01-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1672589063,"distinct_id":"63309ffe64c6f20ff9925f8d","$app_build_number":"6034","$app_version_string":"1.79.1","$carrier":"","$city":"Duisburg","$device_i
# Response received. Processing events between 2023-01-01 and 2023-01-01.
# 13915 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_22647/3819473736.py:64: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 13915 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-01.csv.
# 1 many dfs
# Number of dfs: 1
# 2023-01-02
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-02&to_date=2023-01-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1672636680,"distinct_id":"2751E66A-61B4-4180-8E95-6B19C0F59E40","$ae_first_app_open_date":"2023-01-02T05:18:00","$app_build_number":"6023","$app_version_
# Response received. Processing events between 2023-01-02 and 2023-01-02.
# 20567 events received.
# Flattened data has 20567 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-02.csv.
# 2 many dfs
# Number of dfs: 2
# 2023-01-03
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-03&to_date=2023-01-03 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1672760773,"distinct_id":"6293081e82c92e0a0ca0fd92","$app_build_number":"6023","$app_version_string":"1.79.1","$carrier":"","$city":"San Antonio","$devic
# Response received. Processing events between 2023-01-03 and 2023-01-03.
# 23816 events received.
# Flattened data has 23816 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-03.csv.
# 3 many dfs
# Number of dfs: 3
# 2023-01-04
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-04&to_date=2023-01-04 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"performance__network","properties":{"time":1672803047,"distinct_id":"63688713604f359ad6570562","$app_build_number":"6034","$app_version_string":"1.79.1","$carrier":"Globe","$city":"Juban","$
# Response received. Processing events between 2023-01-04 and 2023-01-04.
# 24681 events received.
# Flattened data has 24681 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-04.csv.
# 4 many dfs
# Number of dfs: 4
# 2023-01-05
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-05&to_date=2023-01-05 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1672932437,"distinct_id":"FBC35010-5BF9-41D5-8671-17E3C14A766E","$ae_first_app_open_date":"2023-01-05T15:27:17","$app_build_number":"6034","$app_version_
# Response received. Processing events between 2023-01-05 and 2023-01-05.
# 41126 events received.
# Flattened data has 41126 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-05.csv.
# 5 many dfs
# Number of dfs: 5
# 2023-01-06
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-06&to_date=2023-01-06 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1673024188,"distinct_id":"6339f198d436642177e2af04","$ae_updated_version":"1.79.1","$app_build_number":"6023","$app_version_string":"1.79.1","$carrier":"T-M
# Response received. Processing events between 2023-01-06 and 2023-01-06.
# 33944 events received.
# Flattened data has 33944 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-06.csv.
# 6 many dfs
# Number of dfs: 6
# 2023-01-07
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-07&to_date=2023-01-07 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1673091413,"distinct_id":"4DDB592D-90AA-46FF-913F-600DF16AA260","$ae_first_app_open_date":"2023-01-07T11:36:53","$app_build_number":"5953","$app_version_
# Response received. Processing events between 2023-01-07 and 2023-01-07.
# 31709 events received.
# Flattened data has 31709 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-07.csv.
# 7 many dfs
# Number of dfs: 7
# 2023-01-08
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-08&to_date=2023-01-08 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1673184998,"distinct_id":"63bb376501f8ffc775bf81bc","$app_build_number":"5964","$app_version_string":"1.78.2","$carrier":"T-Mobile","$device_id":"B0B6
# Response received. Processing events between 2023-01-08 and 2023-01-08.
# 24777 events received.
# Flattened data has 24777 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-08.csv.
# 8 many dfs
# Number of dfs: 8
# 2023-01-09
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-09&to_date=2023-01-09 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1673260369,"distinct_id":"60c391519b928051517d7db0","$app_build_number":"6023","$app_version_string":"1.79.1","$carrier":"","$city":"Sunnyvale","$device_
# Response received. Processing events between 2023-01-09 and 2023-01-09.
# 25340 events received.
# Flattened data has 25340 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-09.csv.
# 9 many dfs
# Number of dfs: 9
# 2023-01-10
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-10&to_date=2023-01-10 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1673311156,"distinct_id":"63bd2432b02a56c6d994cc61","$app_build_number":"1","$app_version_string":"1.79.1","$carrier":"","$city":"Chisinau","$device_i
# Response received. Processing events between 2023-01-10 and 2023-01-10.
# 29649 events received.
# Flattened data has 29649 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-10.csv.
# 10 many dfs
# Number of dfs: 10
# 2023-01-11
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-11&to_date=2023-01-11 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1673424362,"distinct_id":"61097d0f8130de5a8d3cce6d","$app_build_number":"5843","$app_version_string":"1.78","$carrier":"","$city":"Kuwait City","$device_
# Response received. Processing events between 2023-01-11 and 2023-01-11.
# 35907 events received.
# Flattened data has 35907 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-11.csv.
# 11 many dfs
# Number of dfs: 11
# 2023-01-12
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-12&to_date=2023-01-12 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1673508170,"distinct_id":"6262b9079e1e45b4399ee69b","$app_build_number":"6034","$app_version_string":"1.79.1","$carrier":"","$city":"Moss","$device_id":"
# Response received. Processing events between 2023-01-12 and 2023-01-12.
# 31095 events received.
# Flattened data has 31095 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-12.csv.
# 12 many dfs
# Number of dfs: 12
# 2023-01-13
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-13&to_date=2023-01-13 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1673574966,"distinct_id":"63c12ab57039d2015b26e18b","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"Globe","$city":"Tacloban Cit
# Response received. Processing events between 2023-01-13 and 2023-01-13.
# 35253 events received.
# Flattened data has 35253 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-13.csv.
# 13 many dfs
# Number of dfs: 13
# 2023-01-14
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-14&to_date=2023-01-14 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1673692739,"distinct_id":"5ee9463955c2ec52d977680a","$app_build_number":"6034","$app_version_string":"1.79.1","$carrier":"","$city":"Los Angeles","$devic
# Response received. Processing events between 2023-01-14 and 2023-01-14.
# 31843 events received.
# Flattened data has 31843 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-14.csv.
# 14 many dfs
# Number of dfs: 14
# 2023-01-15
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-15&to_date=2023-01-15 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1673778067,"distinct_id":"63c44413c6e57459dc62d9a2","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"","$city":"Queens","$device_
# Response received. Processing events between 2023-01-15 and 2023-01-15.
# 34907 events received.
# Flattened data has 34907 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-15.csv.
# 15 many dfs
# Number of dfs: 15
# 2023-01-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-16&to_date=2023-01-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1673863952,"distinct_id":"5ee9463955c2ec52d977680a","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"","$city":"Redondo Beach","$dev
# Response received. Processing events between 2023-01-16 and 2023-01-16.
# 26552 events received.
# Flattened data has 26552 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-16.csv.
# 16 many dfs
# Number of dfs: 16
# 2023-01-17
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-17&to_date=2023-01-17 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1673962380,"distinct_id":"184D4A8B-8A53-4EB0-B37F-D6200D63E867","$ae_first_app_open_date":"2023-01-17T13:33:00","$app_build_number":"5594","$app_version_
# Response received. Processing events between 2023-01-17 and 2023-01-17.
# 31537 events received.
# Flattened data has 31537 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-17.csv.
# 17 many dfs
# Number of dfs: 17
# 2023-01-18
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-18&to_date=2023-01-18 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1674006068,"distinct_id":"04F09D98-8BF0-455F-97E8-703E7817C307","$ae_first_app_open_date":"2023-01-18T01:41:08","$app_build_number":"1","$app_version_str
# Response received. Processing events between 2023-01-18 and 2023-01-18.
# 36173 events received.
# Flattened data has 36173 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-18.csv.
# 18 many dfs
# Number of dfs: 18
# 2023-01-19
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-19&to_date=2023-01-19 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1674101907,"distinct_id":"63c9351315c7b7b8b92fb872","$app_build_number":"6101","$app_version_string":"2.0","$carrier":"Globe","$city":"Naga","$device_
# Response received. Processing events between 2023-01-19 and 2023-01-19.
# 33435 events received.
# Flattened data has 33435 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-19.csv.
# 19 many dfs
# Number of dfs: 19
# 2023-01-20
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-20&to_date=2023-01-20 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1674248693,"distinct_id":"62091247af9972084d6c3c3c","$ae_updated_version":"1.79.2","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"Ver
# Response received. Processing events between 2023-01-20 and 2023-01-20.
# 34665 events received.
# Flattened data has 34665 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-20.csv.
# 20 many dfs
# Number of dfs: 20
# 2023-01-21
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-21&to_date=2023-01-21 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1674295752,"distinct_id":"63cc2a478b736bbab7b5b7ee","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"T-Mobile","$city":"Park Fore
# Response received. Processing events between 2023-01-21 and 2023-01-21.
# 18568 events received.
# Flattened data has 18568 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-21.csv.
# 21 many dfs
# Number of dfs: 21
# 2023-01-22
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-22&to_date=2023-01-22 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1674386487,"distinct_id":"BE45A30A-AA0C-471F-AA97-6F6742374A9F","$ae_first_app_open_date":"2023-01-22T11:21:27","$app_build_number":"6043","$app_version_
# Response received. Processing events between 2023-01-22 and 2023-01-22.
# 24983 events received.
# Flattened data has 24983 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-22.csv.
# 22 many dfs
# Number of dfs: 22
# 2023-01-23
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-23&to_date=2023-01-23 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1674505066,"distinct_id":"63c70b09c3242ee002fe2d5c","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"Beeline","$city":"North Miami B
# Response received. Processing events between 2023-01-23 and 2023-01-23.
# 26731 events received.
# Flattened data has 26731 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-23.csv.
# 23 many dfs
# Number of dfs: 23
# 2023-01-24
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-24&to_date=2023-01-24 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"login__convert_anonymous","properties":{"time":1674597458,"distinct_id":"601f37217e6f40e2ac699103","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"T-Mobile","$city":"Lo
# Response received. Processing events between 2023-01-24 and 2023-01-24.
# 28857 events received.
# Flattened data has 28857 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-24.csv.
# 24 many dfs
# Number of dfs: 24
# 2023-01-25
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-25&to_date=2023-01-25 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1674663086,"distinct_id":"0283E7AE-8033-41D3-991C-A3CFA5BDE789","$app_build_number":"6014","$app_version_string":"1.79","$carrier":"","$city":"Seoul","$d
# Response received. Processing events between 2023-01-25 and 2023-01-25.
# 27663 events received.
# Flattened data has 27663 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-25.csv.
# 25 many dfs
# Number of dfs: 25
# 2023-01-26
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-26&to_date=2023-01-26 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1674741213,"distinct_id":"63d2f65be817358168d95f06","$app_build_number":"6162","$app_version_string":"1.79.3","$carrier":"","$city":"Sedona","$device_
# Response received. Processing events between 2023-01-26 and 2023-01-26.
# 36907 events received.
# Flattened data has 36907 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-26.csv.
# 26 many dfs
# Number of dfs: 26
# 2023-01-27
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-27&to_date=2023-01-27 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"login__convert_anonymous","properties":{"time":1674798126,"distinct_id":"5fe75e70e4c3771937e169d4","$app_build_number":"6054","$app_version_string":"1.79.2","$carrier":"Tuenti","$city":"Buen
# Response received. Processing events between 2023-01-27 and 2023-01-27.
# 39162 events received.
# Flattened data has 39162 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-27.csv.
# 27 many dfs
# Number of dfs: 27
# 2023-01-28
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-28&to_date=2023-01-28 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1674880736,"distinct_id":"735E00BD-E62C-4A2D-AB6D-54B985CD6676","$ae_first_app_open_date":"2023-01-28T04:38:56","$app_build_number":"5964","$app_version_
# Response received. Processing events between 2023-01-28 and 2023-01-28.
# 44548 events received.
# Flattened data has 44548 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-28.csv.
# 28 many dfs
# Number of dfs: 28
# 2023-01-29
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-29&to_date=2023-01-29 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1675007445,"distinct_id":"4C04CB80-663D-4C6F-9378-B24BF1C981A2","$ae_first_app_open_date":"2023-01-29T15:50:45","$app_build_number":"5953","$app_version_
# Response received. Processing events between 2023-01-29 and 2023-01-29.
# 22885 events received.
# Flattened data has 22885 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-29.csv.
# 29 many dfs
# Number of dfs: 29
# 2023-01-30
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-30&to_date=2023-01-30 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1675053615,"distinct_id":"638a36a1c9b349b2720b4750","$app_build_number":"6054","$app_version_string":"1.79.2","$carrier":"Globe","$city":"City of Muntinl
# Response received. Processing events between 2023-01-30 and 2023-01-30.
# 30988 events received.
# Flattened data has 30988 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-30.csv.
# 30 many dfs
# Number of dfs: 30
# 2023-01-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-31&to_date=2023-01-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1675187239,"distinct_id":"61dbd4d5dd2bd307f47c86cb","$app_build_number":"6043","$app_version_string":"1.79.2","$carrier":"AT&T","$device_id":"2C08B5A6-37
# Response received. Processing events between 2023-01-31 and 2023-01-31.
# 37106 events received.
# Flattened data has 37106 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/data/2023-01-31.csv.
# 31 many dfs
# Number of dfs: 31

# %%
# dfs = []
    
# outdir = 'data'
# i_date = datetime.date(2022,1,1)
# dt = datetime.timedelta(days=1)

# # dfs = [] 

# for i in range(365):
#     start_date = (i_date + dt*i).isoformat()
#     end_date = start_date
    
#     if isfile(f'./data/{start_date}.csv'):
#         print(f'./data/{start_date}.csv exists; skipping.')
#         continue
    
#     print(start_date)
#     try:
#         df = get_data_between(start_date=start_date, 
#                               end_date=end_date,
#                               verbose=1)

#         devices = dict(Counter(df['$model']).most_common(20))
#         devices_users = dict()
#         devices_N_users = dict()

#         outfile = join(abspath(outdir), f'{start_date}.csv')
#         print(f'Saving to {outfile}.') # defaults to ./data/
#         df.to_csv(outfile)
#         odfs.append(df)
#         print(len(odfs), 'many dfs')

#         dfs.append(df)
#         # plt.rcParams["figure.figsize"] = [20, 7]
#         # plt.rcParams["figure.autolayout"] = True
#         plt.xticks(rotation=70)
#         plt.yscale('log')
#         plt.title(f'Frequency of most common devices on {start_date}.')
#         plt.bar(devices.keys(), devices.values())
#         plt.show()
#         print('Number of dfs:',len(dfs))
    

#     except:
#         continue

# %%
import glob
import os


#os.chdir('''/Users/allen/Desktop/mixpanel-events/data''')
os.chdir('data')
dfs = []
infiles = list(sorted(glob.glob('2023-*.csv')))
ifinal = len(infiles)//2
               
for inf in infiles[0:ifinal]:
    dfs.append(pd.read_csv(inf))

    
df = pd.concat(dfs)
# Out:
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns
anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (24,26,32,52,68,69,70,71,73,75,87,92,93,95,96,97,99,100,101,102,104,105,115,116,118,119,120,121,126,127,131,132,135,136,137,138,140,145,147,148,149,150,151,157,158,159,160,161,162) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import os

# %%
os.path.isdir

# %%
infiles
# Out:
# ['2023-01-20.csv',
#  '2023-01-21.csv',
#  '2023-01-22.csv',
#  '2023-01-23.csv',
#  '2023-01-24.csv',
#  '2023-01-25.csv',
#  '2023-01-26.csv',
#  '2023-01-27.csv',
#  '2023-01-28.csv',
#  '2023-01-29.csv',
#  '2023-01-30.csv',
#  '2023-01-31.csv']

# %%
import datetime
import pandas as pd
import os
import glob
import warnings
warnings.filterwarnings("ignore")

os.chdir('''/Users/allen/Developer/clo/flickplay/mixpanel-events/data''')
# os.chdir('''./data''')
infiles = list(sorted(glob.glob('2023*.csv')))
bigdf=pd.DataFrame(columns = [ c for c in pd.read_csv(infiles[0]).columns if c not in ['Unnamed: 0'] ])

for infile in infiles[:20]:
    df = pd.read_csv(infile, low_memory=True)
    df.index=df.date
    df = df.drop(columns = ['Unnamed: 0'])
    print(min(df.index),max(df.index))
    bigdf = pd.concat([bigdf, df])
    print(len(df), len(bigdf))
    
# bigdf.index = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
# bigdf['date'] = bigdf.index.values
bigdf['date'] = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
bigdf
# Out:
# 2023-01-20 00:02:23 2023-01-20 23:47:57
# 34665 34665
# 2023-01-21 00:10:33 2023-01-21 23:50:58
# 18568 53233
# 2023-01-22 00:08:17 2023-01-22 23:59:59
# 24983 78216
# 2023-01-23 00:00:00 2023-01-23 23:55:20
# 26731 104947
# 2023-01-24 00:01:39 2023-01-24 23:58:45
# 28857 133804
# 2023-01-25 00:01:17 2023-01-25 23:59:49
# 27663 161467
# 2023-01-26 00:00:03 2023-01-26 23:59:27
# 36907 198374
# 2023-01-27 00:00:15 2023-01-27 23:59:39
# 39162 237536
# 2023-01-28 00:01:41 2023-01-28 23:59:59
# 44548 282084
# 2023-01-29 00:00:00 2023-01-29 23:55:34
# 22885 304969
# 2023-01-30 00:02:52 2023-01-30 23:59:59
# 30988 335957
# 2023-01-31 00:00:00 2023-01-31 23:59:58
# 37106 373063
#                                         event        date        time  \
# 2023-01-20 21:04:53               $ae_updated  2023-01-20  1674248693
# 2023-01-20 11:40:05               $ae_updated  2023-01-20  1674214805
# 2023-01-20 11:40:06            session__start  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# ...                                       ...         ...         ...
# 2023-01-31 04:05:22  profile_draft__load_list  2023-01-30  1675137922
# 2023-01-31 04:05:22        profile__load_page  2023-01-30  1675137922
# 2023-01-31 04:05:27      performance__network  2023-01-30  1675137927
# 2023-01-31 04:05:34      performance__network  2023-01-30  1675137934
# 2023-01-31 04:05:38      performance__network  2023-01-30  1675137938
#
#                                   distinct_id $app_build_number  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c              6043
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# ...                                       ...               ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a              6054
#
#                     $app_version_string  $carrier      $city  \
# 2023-01-20 21:04:53              1.79.2   Verizon   Kennesaw
# 2023-01-20 11:40:05              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# ...                                 ...       ...        ...
# 2023-01-31 04:05:22              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:22              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:27              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:34              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:38              1.79.2  T-Mobile      Seoul
#
#                                                $device_id  \
# 2023-01-20 21:04:53  16528B81-05A4-450D-B464-5D8CF5419A1F
# 2023-01-20 11:40:05  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# ...                                                   ...
# 2023-01-31 04:05:22  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:22  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:27  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:34  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:38  0A6398E0-4F5C-424C-91A0-D231FBF635B8
#
#                     $had_persisted_distinct_id        $insert_id $lib_version  \
# 2023-01-20 21:04:53                       True  7366f59bf7f27fe5        3.5.1
# 2023-01-20 11:40:05                       True  ccb8e7bd625e8e12        3.5.1
# 2023-01-20 11:40:06                       True  cb9d6dae68e64ae0        3.5.1
# 2023-01-20 11:40:06                       True  562689d06fa655ca        3.5.1
# 2023-01-20 11:40:06                       True  82ed5a331de27f22        3.5.1
# ...                                        ...               ...          ...
# 2023-01-31 04:05:22                       True  12959f06daa69800        3.5.1
# 2023-01-31 04:05:22                       True  3e1857d00c4187bf        3.5.1
# 2023-01-31 04:05:27                       True  e89aa74dceb31643        3.5.1
# 2023-01-31 04:05:34                       True  06a941026f2fce1c        3.5.1
# 2023-01-31 04:05:38                       True  a893f69c5ce4f2d9        3.5.1
#
#                     $manufacturer      $model  $mp_api_endpoint  \
# 2023-01-20 21:04:53         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-20 11:40:05         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# ...                           ...         ...               ...
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:27         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:34         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:38         Apple  iPhone13,2  api.mixpanel.com
#
#                     $mp_api_timestamp_ms  $os $os_version $radio   $region  \
# 2023-01-20 21:04:53        1674504732683  iOS        15.3    LTE   Georgia
# 2023-01-20 11:40:05        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# ...                                  ...  ...         ...    ...       ...
# 2023-01-31 04:05:22        1675166777266  iOS        16.3   None     Seoul
# 2023-01-31 04:05
# 2023-01-31 04:05:38     6054.0  76A71B18-9C6E-48D3-B16D-F1686446B0D5
#
#                     app_version   env location_enabled mp_country_code mp_lib  \
# 2023-01-20 21:04:53      1.78.2  prod            False              US  swift
# 2023-01-20 11:40:05        1.74  prod            False              US  swift
# 2023-01-20 11:40:06      1.79.2  prod            False              US  swift
# 2023-01-20 11:40:06      1.79.2  prod            False              US  swift
# 2023-01-20 11:40:06      1.79.2  prod            False              US  swift
# ...                         ...   ...              ...             ...    ...
# 2023-01-31 04:05:22      1.79.2  prod            False              KR  swift
# 2023-01-31 04:05:22      1.79.2  prod            False              KR  swift
# 2023-01-31 04:05:27      1.79.2  prod            False              KR  swift
# 2023-01-31 04:05:34      1.79.2  prod            False              KR  swift
# 2023-01-31 04:05:38      1.79.2  prod            False              KR  swift
#
#                     mp_processing_time_ms user_gps_location  \
# 2023-01-20 21:04:53         1674504732943               NaN
# 2023-01-20 11:40:05         1674243625155               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# ...                                   ...               ...
# 2023-01-31 04:05:22         1675166777302               NaN
# 2023-01-31 04:05:22         1675166777301               NaN
# 2023-01-31 04:05:27         1675166777302               NaN
# 2023-01-31 04:05:34         1675166777301               NaN
# 2023-01-31 04:05:38         1675166777302               NaN
#
#                                       user_id  user_location_accuracy  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c                    -2.0
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# ...                                       ...                     ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a                    -2.0
#
#                     duration_ms method  response_bytes  status_code  \
# 2023-01-20 21:04:53         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:05         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:06         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:06         530   POST          2144.0        200.0
# 2023-01-20 11:40:06         580    GET        267320.0        200.0
# ...                         ...    ...             ...          ...
# 2023-01-31 04:05:22         NaN    NaN             NaN          NaN
# 2023-01-31 04:05:22      <null>    NaN             NaN          NaN
# 2023-01-31 04:05:27        9427    GET       3893145.0        200.0
# 2023-01-31 04:05:34        5480    GET        270102.0        200.0
# 2023-01-31 04:05:38        3742    GET       1060065.0        200.0
#
#                                                                    url  \
# 2023-01-20 21:04:53                                                NaN
# 2023-01-20 11:40:05                                                NaN
# 2023-01-20 11:40:06                                                NaN
# 2023-01-20 11:40:06                       api.app.flickplay.co/users/*
# 2023-01-20 11:40:06                        api.app.flickplay.co/config
# ...                                                                ...
# 2023-01-31 04:05:22                                                NaN
# 2023-01-31 04:05:22                                                NaN
# 2023-01-31 04:05:27  api.app.flickplay.co/flicks/experiences/sync/full
# 2023-01-31 04:05:34               api.app.flickplay.co/flicks/flicksV3
# 2023-01-31 04:05:38               api.app.flickplay.co/flicks/storesV2
#
#                     feature_session_id feature_session_type  \
# 2023-01-20 21:04:53                NaN                  NaN
# 2023-01-20 11:40:05                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# ...                                ...                  ...
# 2023-01-31 04:05:22                NaN                  NaN
# 2023-01-31 04:05:22                NaN                  NaN
# 2023-01-31 04:05:27                NaN                  NaN
# 2023-01-31 04:05:34                NaN                  NaN
# 2023-01-31 04:05:38                NaN                  NaN
#
#                     feature_source_page  tab  count result session_length  \
# 2023-01-20 21:04:53                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:05                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# ...                                 ...  ...    ...    ...            ...
# 2023-01-31 04:05:22   user_profile_main  NaN    1.0    NaN            NaN
# 2023-01-31 04:05:22   user_profile_main  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:27                 NaN  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:34                 NaN  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:38                 NaN  NaN    NaN    NaN            NaN
#
#                      col_position creator_user_id creator_username  \
# 2023-01-20 21:04:53           NaN             NaN              NaN
# 2023-01-20 11:40:05           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# ...                           ...             ...              ...
# 2023-01-31 04:05:22           NaN             NaN              NaN
# 2023-01-31 04:05:22           NaN             NaN              NaN
# 2023-01-31 04:05:27           NaN             NaN              NaN
# 2023-01-31 04:05:34           NaN             NaN              NaN
# 2023-01-31 04:05:38           NaN             NaN              NaN
#
#                               profile_user_id  row_position video_id  \
# 2023-01-20 21:04:53                       NaN           NaN      NaN
# 2023-01-20 11:40:05                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# ...                                       ...           ...      ...
# 2023-01-31 04:05:22                       NaN           NaN      NaN
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a           NaN      NaN
# 2023-01-31 04:05:27                       NaN           NaN      NaN
# 2023-01-31 04:05:34                       NaN           NaN      NaN
# 2023-01-31 04:05:38                       NaN           NaN      NaN
#
#                     video_type experience_ids experience_names session  \
# 2023-01-20 21:04:53        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:05        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# ...                        ...            ...              ...     ...
# 2023-01-31 04:05:38            NaN       NaN           NaN             NaN
#
#                     experience_state experience_type if_have_stock if_nft  \
# 2023-01-20 21:04:53              NaN             NaN           NaN    NaN
# 2023-01-20 11:40:05              NaN             NaN           NaN    NaN
# 2023-01-20 11:40:06              NaN             NaN           NaN    NaN
# 2023-01-20 11:40:06              NaN             NaN           NaN    NaN
# 2023-01-20 11:40:06              NaN             NaN           NaN    NaN
# ...                              ...             ...           ...    ...
# 2023-01-31 04:05:22              NaN             NaN           NaN    NaN
# 2023-01-31 04:05:22              NaN             NaN           NaN    NaN
# 2023-01-31 04:05:27              NaN             NaN           NaN    NaN
# 2023-01-31 04:05:34              NaN             NaN           NaN    NaN
# 2023-01-31 04:05:38              NaN             NaN           NaN    NaN
#
#                     if_unlocked experience_tier            username  \
# 2023-01-20 21:04:53         NaN             NaN                 NaN
# 2023-01-20 11:40:05         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# ...                         ...             ...                 ...
# 2023-01-31 04:05:22         NaN             NaN                 NaN
# 2023-01-31 04:05:22         NaN             NaN  anonymous-30244568
# 2023-01-31 04:05:27         NaN             NaN                 NaN
# 2023-01-31 04:05:34         NaN             NaN                 NaN
# 2023-01-31 04:05:38         NaN             NaN                 NaN
#
#                     $ae_updated_version type anonymous_user_id  \
# 2023-01-20 21:04:53              1.79.2  NaN               NaN
# 2023-01-20 11:40:05              1.79.2  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# ...                                 ...  ...               ...
# 2023-01-31 04:05:22                 NaN  NaN               NaN
# 2023-01-31 04:05:22                 NaN  NaN               NaN
# 2023-01-31 04:05:27                 NaN  NaN               NaN
# 2023-01-31 04:05:34                 NaN  NaN               NaN
# 2023-01-31 04:05:38                 NaN  NaN               NaN
#
#                     $ae_first_app_open_date  \
# 2023-01-20 21:04:53                     NaN
# 2023-01-20 11:40:05                     NaN
# 2023-01-20 11:40:06                     NaN
# 2023-01-20 11:40:06                     NaN
# 2023-01-20 11:40:06                     NaN
# ...                                     ...
# 2023-01-31 04:05:22                     NaN
# 2023-01-31 04:05:22                     NaN
# 2023-01-31 04:05:27                     NaN
# 2023-01-31 04:05:34                     NaN
# 2023-01-31 04:05:38                     NaN
#
#                                                session_id   session_type  \
# 2023-01-20 21:04:53                                   NaN            NaN
# 2023-01-20 11:40:05                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# ...                                                   ...            ...
# 2023-01-31 04:05:22  11FB1873-7B9B-4811-858D-7C122654D82D  profile_draft
# 2023-01-31 04:05:22                                   NaN            NaN
# 2023-01-31 04:05:27                                   NaN            NaN
# 2023-01-31 04:05:34                                   NaN            NaN
# 2023-01-31 04:05:38                                   NaN            NaN
#
#                     action source_page coin_id coin_type  entity_id store_id  \
# 2023-01-20 21:04:53    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:05    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# ...                    ...         ...     ...       ...        ...      ...
# 2023-01-31 04:05:22    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:22    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:27    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:34    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:38    NaN         NaN     NaN       NaN        NaN      NaN
#
#                     store_name if_claimed destination_coin_type  \
# 2023-01-20 21:04:53        NaN        NaN                   NaN
# 2023-01-20 11:40:05        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# ...                        ...        ...                   ...
# 2023-01-31 04:05:22        NaN        NaN                   NaN
# 2023-01-31 04:05:22        NaN        NaN                   NaN
# 2023-01-31 04:05:27        NaN        NaN                   NaN
# 2023-01-31 04:05:34        NaN        NaN                   NaN
# 2023-01-31 04:05:38        NaN        NaN                   NaN
#
#                     destination_id destination_name destination_type  \
# 2023-01-20 21:04:53            NaN              NaN              NaN
# 2023-01-20 11:40:05            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# ...                            ...              ...              ...
# 2023-01-31 04:05:22            NaN              NaN              NaN
# 2023-01-31 04:05:22            NaN              NaN              NaN
# 2023-01-31 04:05:27            NaN              NaN              NaN
# 2023-01-31 04:05:34            NaN              NaN              NaN
# 2023-01-31 04:05:38            NaN              NaN              NaN
#
#                      navigation_distance_m  navigation_duration_s  \
# 2023-01-20 21:04:53                    NaN                    NaN
# 2023-01-20 11:40:05                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# ...                                    ...                    ...
# 2023-01-31 04:05:22                    NaN                    NaN
# 2023-01-31 04:05:22                    NaN                    NaN
# 2023-01-31 04:05:27                    NaN                    NaN
# 2023-01-31 04:05:34                    NaN                    NaN
# 2023-01-31 04:05:38                    NaN                    NaN
#
#                      remaining_distance_m  remaining_duration_s search_text  \
# 2023-01-20 21:04:53                   NaN                   NaN         NaN
# 2023-01-20 11:40:05                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# ...                                   ...                   ...         ...
# 2023-01-31 04:05:22                   NaN                   NaN         NaN
# 2023-01-31 04:05:22                   NaN                   NaN         NaN
# 2023-01-31 04:05:27                   NaN                   NaN         NaN
# 2023-01-31 04:05:34                   NaN                   NaN         NaN
# 2023-01-31 04:05:38                   NaN                   NaN         NaN
#
#                     if_empty  wallet_count error_code  total_clips  \
# 2023-01-20 21:04:53      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:05      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# ...                      ...           ...        ...          ...
# 2023-01-31 04:05:22      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:22      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:27      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:34      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:38      NaN           NaN        NaN          NaN
#
#                      total_video_time_ms category_id category_name  position  \
# 2023-01-20 21:04:53                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:05                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# ...                                  ...         ...           ...       ...
# 2023-01-31 04:05:22                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:22                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:27                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:34                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:38                  NaN         NaN           NaN       NaN
#
#                     entry_point style_id button_type  tutorial_step  \
# 2023-01-20 21:04:53         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:05         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# ...                         ...      ...         ...            ...
# 2023-01-31 04:05:22         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:22         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:27         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:34         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:38         NaN      NaN         NaN            NaN
#
#                     object_placed object_type entry_category_id  \
# 2023-01-20 21:04:53           NaN         NaN               NaN
# 2023-01-20 11:40:05           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# ...                           ...         ...               ...
# 2023-01-31 04:05:22           NaN         NaN               NaN
# 2023-01-31 04:05:22           NaN         NaN               NaN
# 2023-01-31 04:05:27           NaN         NaN               NaN
# 2023-01-31 04:05:34           NaN         NaN               NaN
# 2023-01-31 04:05:38           NaN         NaN               NaN
#
#                     entry_category_name place_type  clip  start_time_ms  \
# 2023-01-20 21:04:53                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:05                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# ...                                 ...        ...   ...            ...
# 2023-01-31 04:05:22                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:22                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:27                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:34                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:38                 NaN        NaN   NaN            NaN
#
#                     trash_type category_ids category_names experience_types  \
# 2023-01-20 21:04:53        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:05        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# ...                        ...          ...            ...              ...
# 2023-01-31 04:05:22        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:22        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:27        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:34        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:38        NaN          NaN            NaN              NaN
#
#                     filter_id  clip_duration_ms  clip_start_time_ms  \
# 2023-01-20 21:04:53       NaN               NaN                 NaN
# 2023-01-20 11:40:05       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# ...                       ...               ...                 ...
# 2023-01-31 04:05:22       NaN               NaN                 NaN
# 2023-01-31 04:05:22       NaN               NaN                 NaN
# 2023-01-31 04:05:27       NaN               NaN                 NaN
# 2023-01-31 04:05:34       NaN               NaN                 NaN
# 2023-01-31 04:05:38       NaN               NaN                 NaN
#
#                     previous_page  position_offset  col_count  row_count  \
# 2023-01-20 21:04:53           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:05           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# ...                           ...              ...        ...        ...
# 2023-01-31 04:05:22           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:22           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:27           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:34           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:38           NaN              NaN        NaN        NaN
#
#                     button_state music_id toggle_state  caption_length  \
# 2023-01-20 21:04:53          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:05          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# ...                          ...      ...          ...             ...
# 2023-01-31 04:05:22          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:22          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:27          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:34          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:38          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06         NaN            NaN          NaN            NaN
# 2023-01-20 11:40:06         NaN            NaN          NaN            NaN
# ...                         ...            ...          ...            ...
# 2023-01-31 04:05:22         NaN            NaN          NaN            NaN
# 2023-01-31 04:05:22         NaN            NaN          NaN            NaN
# 2023-01-31 04:05:27         NaN            NaN          NaN            NaN
# 2023-01-31 04:05:34         NaN            NaN          NaN            NaN
# 2023-01-31 04:05:38         NaN            NaN          NaN            NaN
#
#                      $ae_iap_quantity share_platform badge_id badge_name  \
# 2023-01-20 21:04:53               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:05               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# ...                               ...            ...      ...        ...
# 2023-01-31 04:05:22               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:22               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:27               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:34               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:38               NaN            NaN      NaN        NaN
#
#                     message target tour_id tour_user_id tour_username  \
# 2023-01-20 21:04:53     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:05     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# ...                     ...    ...     ...          ...           ...
# 2023-01-31 04:05:22     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:22     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:27     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:34     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:38     NaN    NaN     NaN          NaN           NaN
#
#                     original property property_category reward_id  \
# 2023-01-20 21:04:53      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:05      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# ...                      ...      ...               ...       ...
# 2023-01-31 04:05:22      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:22      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:27      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:34      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:38      NaN      NaN               NaN       NaN
#
#                     session_duration_ms if_nft_reward if_redeemed  \
# 2023-01-20 21:04:53                 NaN           NaN         NaN
# 2023-01-20 11:40:05                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# ...                                 ...           ...         ...
# 2023-01-31 04:05:22                 NaN           NaN         NaN
# 2023-01-31 04:05:22                 NaN           NaN         NaN
# 2023-01-31 04:05:27                 NaN           NaN         NaN
# 2023-01-31 04:05:34                 NaN           NaN         NaN
# 2023-01-31 04:05:38                 NaN           NaN         NaN
#
#                     reward_state option platform  deeplink_type deeplink_url  \
# 2023-01-20 21:04:53          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:05          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# ...                          ...    ...      ...            ...          ...
# 2023-01-31 04:05:22          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:22          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:27          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:34          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:38          NaN    NaN      NaN            NaN          NaN
#
#                     traffic
# 2023-01-20 21:04:53     NaN
# 2023-01-20 11:40:05     NaN
# 2023-01-20 11:40:06     NaN
# 2023-01-20 11:40:06     NaN
# 2023-01-20 11:40:06     NaN
# ...                     ...
# 2023-01-31 04:05:22     NaN
# 2023-01-31 04:05:22     NaN
# 2023-01-31 04:05:27     NaN
# 2023-01-31 04:05:34     NaN
# 2023-01-31 04:05:38     NaN
#
# [373063 rows x 183 columns]

# %%
bigdf
# Out:
#                                         event        date        time  \
# 2023-01-20 21:04:53               $ae_updated  2023-01-20  1674248693
# 2023-01-20 11:40:05               $ae_updated  2023-01-20  1674214805
# 2023-01-20 11:40:06            session__start  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# ...                                       ...         ...         ...
# 2023-01-31 04:05:22  profile_draft__load_list  2023-01-30  1675137922
# 2023-01-31 04:05:22        profile__load_page  2023-01-30  1675137922
# 2023-01-31 04:05:27      performance__network  2023-01-30  1675137927
# 2023-01-31 04:05:34      performance__network  2023-01-30  1675137934
# 2023-01-31 04:05:38      performance__network  2023-01-30  1675137938
#
#                                   distinct_id $app_build_number  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c              6043
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb              6043
# ...                                       ...               ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a              6054
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a              6054
#
#                     $app_version_string  $carrier      $city  \
# 2023-01-20 21:04:53              1.79.2   Verizon   Kennesaw
# 2023-01-20 11:40:05              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# 2023-01-20 11:40:06              1.79.2       NaN  Hampshire
# ...                                 ...       ...        ...
# 2023-01-31 04:05:22              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:22              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:27              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:34              1.79.2  T-Mobile      Seoul
# 2023-01-31 04:05:38              1.79.2  T-Mobile      Seoul
#
#                                                $device_id  \
# 2023-01-20 21:04:53  16528B81-05A4-450D-B464-5D8CF5419A1F
# 2023-01-20 11:40:05  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# ...                                                   ...
# 2023-01-31 04:05:22  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:22  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:27  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:34  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:38  0A6398E0-4F5C-424C-91A0-D231FBF635B8
#
#                     $had_persisted_distinct_id        $insert_id $lib_version  \
# 2023-01-20 21:04:53                       True  7366f59bf7f27fe5        3.5.1
# 2023-01-20 11:40:05                       True  ccb8e7bd625e8e12        3.5.1
# 2023-01-20 11:40:06                       True  cb9d6dae68e64ae0        3.5.1
# 2023-01-20 11:40:06                       True  562689d06fa655ca        3.5.1
# 2023-01-20 11:40:06                       True  82ed5a331de27f22        3.5.1
# ...                                        ...               ...          ...
# 2023-01-31 04:05:22                       True  12959f06daa69800        3.5.1
# 2023-01-31 04:05:22                       True  3e1857d00c4187bf        3.5.1
# 2023-01-31 04:05:27                       True  e89aa74dceb31643        3.5.1
# 2023-01-31 04:05:34                       True  06a941026f2fce1c        3.5.1
# 2023-01-31 04:05:38                       True  a893f69c5ce4f2d9        3.5.1
#
#                     $manufacturer      $model  $mp_api_endpoint  \
# 2023-01-20 21:04:53         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-20 11:40:05         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# ...                           ...         ...               ...
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:27         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:34         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:38         Apple  iPhone13,2  api.mixpanel.com
#
#                     $mp_api_timestamp_ms  $os $os_version $radio   $region  \
# 2023-01-20 21:04:53        1674504732683  iOS        15.3    LTE   Georgia
# 2023-01-20 11:40:05        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# 2023-01-20 11:40:06        1674243607716  iOS        16.2  NRNSA  Illinois
# ...                                  ...  ...         ...    ...       ...
# 2023-01-31 04:05:22        1675166777266  iOS        16.3   None     Seoul
# 2023-01-31 04:05:22        1675166777266  iOS        16.3   None     Seoul
# 2023-01-31 04:05:27        1675166777266  iOS        16.3   None     Seoul
# 2023-01-31 04:05:34        1675166777266  iOS        16.3   None     Seoul
# 2023-01-31 04:05:38        1675166777266  iOS        16.3   None     Seoul
#
#                     $screen_height $screen_width                  $user_id  \
# 2023-01-20 21:04:53            844           390  62091247af9972084d6c3c3c
# 2023-01-20 11:40:05            844           390  62169902b3fc532d89a663cb
# 2023-01-20 11:40:06            844           390  62169902b3fc532d89a663cb
# 2023-01-20 11:40:06            844           390  62169902b3fc532d89a663cb
# 2023-01-20 11:40:06            844           390  62169902b3fc532d89a663cb
# ...                            ...           ...                       ...
# 2023-01-31 04:05:38      1.79.2  prod            False              KR  swift
#
#                     mp_processing_time_ms user_gps_location  \
# 2023-01-20 21:04:53         1674504732943               NaN
# 2023-01-20 11:40:05         1674243625155               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# 2023-01-20 11:40:06         1674243625167               NaN
# ...                                   ...               ...
# 2023-01-31 04:05:22         1675166777302               NaN
# 2023-01-31 04:05:22         1675166777301               NaN
# 2023-01-31 04:05:27         1675166777302               NaN
# 2023-01-31 04:05:34         1675166777301               NaN
# 2023-01-31 04:05:38         1675166777302               NaN
#
#                                       user_id  user_location_accuracy  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c                    -2.0
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                    -2.0
# ...                                       ...                     ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a                    -2.0
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a                    -2.0
#
#                     duration_ms method  response_bytes  status_code  \
# 2023-01-20 21:04:53         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:05         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:06         NaN    NaN             NaN          NaN
# 2023-01-20 11:40:06         530   POST          2144.0        200.0
# 2023-01-20 11:40:06         580    GET        267320.0        200.0
# ...                         ...    ...             ...          ...
# 2023-01-31 04:05:22         NaN    NaN             NaN          NaN
# 2023-01-31 04:05:22      <null>    NaN             NaN          NaN
# 2023-01-31 04:05:27        9427    GET       3893145.0        200.0
# 2023-01-31 04:05:34        5480    GET        270102.0        200.0
# 2023-01-31 04:05:38        3742    GET       1060065.0        200.0
#
#                                                                    url  \
# 2023-01-20 21:04:53                                                NaN
# 2023-01-20 11:40:05                                                NaN
# 2023-01-20 11:40:06                                                NaN
# 2023-01-20 11:40:06                       api.app.flickplay.co/users/*
# 2023-01-20 11:40:06                        api.app.flickplay.co/config
# ...                                                                ...
# 2023-01-31 04:05:22                                                NaN
# 2023-01-31 04:05:22                                                NaN
# 2023-01-31 04:05:27  api.app.flickplay.co/flicks/experiences/sync/full
# 2023-01-31 04:05:34               api.app.flickplay.co/flicks/flicksV3
# 2023-01-31 04:05:38               api.app.flickplay.co/flicks/storesV2
#
#                     feature_session_id feature_session_type  \
# 2023-01-20 21:04:53                NaN                  NaN
# 2023-01-20 11:40:05                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# 2023-01-20 11:40:06                NaN                  NaN
# ...                                ...                  ...
# 2023-01-31 04:05:22                NaN                  NaN
# 2023-01-31 04:05:22                NaN                  NaN
# 2023-01-31 04:05:27                NaN                  NaN
# 2023-01-31 04:05:34                NaN                  NaN
# 2023-01-31 04:05:38                NaN                  NaN
#
#                     feature_source_page  tab  count result session_length  \
# 2023-01-20 21:04:53                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:05                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# 2023-01-20 11:40:06                 NaN  NaN    NaN    NaN            NaN
# ...                                 ...  ...    ...    ...            ...
# 2023-01-31 04:05:22   user_profile_main  NaN    1.0    NaN            NaN
# 2023-01-31 04:05:22   user_profile_main  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:27                 NaN  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:34                 NaN  NaN    NaN    NaN            NaN
# 2023-01-31 04:05:38                 NaN  NaN    NaN    NaN            NaN
#
#                      col_position creator_user_id creator_username  \
# 2023-01-20 21:04:53           NaN             NaN              NaN
# 2023-01-20 11:40:05           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# 2023-01-20 11:40:06           NaN             NaN              NaN
# ...                           ...             ...              ...
# 2023-01-31 04:05:22           NaN             NaN              NaN
# 2023-01-31 04:05:22           NaN             NaN              NaN
# 2023-01-31 04:05:27           NaN             NaN              NaN
# 2023-01-31 04:05:34           NaN             NaN              NaN
# 2023-01-31 04:05:38           NaN             NaN              NaN
#
#                               profile_user_id  row_position video_id  \
# 2023-01-20 21:04:53                       NaN           NaN      NaN
# 2023-01-20 11:40:05                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# 2023-01-20 11:40:06                       NaN           NaN      NaN
# ...                                       ...           ...      ...
# 2023-01-31 04:05:22                       NaN           NaN      NaN
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a           NaN      NaN
# 2023-01-31 04:05:27                       NaN           NaN      NaN
# 2023-01-31 04:05:34                       NaN           NaN      NaN
# 2023-01-31 04:05:38                       NaN           NaN      NaN
#
#                     video_type experience_ids experience_names session  \
# 2023-01-20 21:04:53        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:05        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# 2023-01-20 11:40:06        NaN            NaN              NaN     NaN
# ...                        ...            ...              ...     ...
# 2023-01-31 04:05:22        NaN            NaN              NaN     NaN
# 2023-01-31 04:05:22        NaN            NaN              NaN     NaN
# 2023-01-31 04:05:27        NaN            NaN              NaN     NaN
# 2023-01-31 04:05:34        NaN            NaN              NaN     NaN
# 2023-01-31 04:05:38        NaN            NaN              NaN     NaN
#
#                     sub_session video_user_id  distance_m location_id  \
# 2023-01-20 21:04:53         NaN           NaN         NaN         NaN
# 2023-01-20 11:40:05         NaN           NaN         NaN         NaN
# 2023-01-20 11:40:06         NaN           NaN         NaN         NaN
# 2023-01-20 11:40:06         NaN           NaN         NaN         NaN
# 2023-01-20 11:40:06         NaN           NaN         NaN         NaN
# ...                         ...           ...         ...         ...
# 2023-01-31 04:05:22         NaN           NaN         NaN         NaN
#                     if_unlocked experience_tier            username  \
# 2023-01-20 21:04:53         NaN             NaN                 NaN
# 2023-01-20 11:40:05         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# 2023-01-20 11:40:06         NaN             NaN                 NaN
# ...                         ...             ...                 ...
# 2023-01-31 04:05:22         NaN             NaN                 NaN
# 2023-01-31 04:05:22         NaN             NaN  anonymous-30244568
# 2023-01-31 04:05:27         NaN             NaN                 NaN
# 2023-01-31 04:05:34         NaN             NaN                 NaN
# 2023-01-31 04:05:38         NaN             NaN                 NaN
#
#                     $ae_updated_version type anonymous_user_id  \
# 2023-01-20 21:04:53              1.79.2  NaN               NaN
# 2023-01-20 11:40:05              1.79.2  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# 2023-01-20 11:40:06                 NaN  NaN               NaN
# ...                                 ...  ...               ...
# 2023-01-31 04:05:22                 NaN  NaN               NaN
# 2023-01-31 04:05:22                 NaN  NaN               NaN
# 2023-01-31 04:05:27                 NaN  NaN               NaN
# 2023-01-31 04:05:34                 NaN  NaN               NaN
# 2023-01-31 04:05:38                 NaN  NaN               NaN
#
#                     $ae_first_app_open_date  \
# 2023-01-20 21:04:53                     NaN
# 2023-01-20 11:40:05                     NaN
# 2023-01-20 11:40:06                     NaN
# 2023-01-20 11:40:06                     NaN
# 2023-01-20 11:40:06                     NaN
# ...                                     ...
# 2023-01-31 04:05:22                     NaN
# 2023-01-31 04:05:22                     NaN
# 2023-01-31 04:05:27                     NaN
# 2023-01-31 04:05:34                     NaN
# 2023-01-31 04:05:38                     NaN
#
#                                                session_id   session_type  \
# 2023-01-20 21:04:53                                   NaN            NaN
# 2023-01-20 11:40:05                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# 2023-01-20 11:40:06                                   NaN            NaN
# ...                                                   ...            ...
# 2023-01-31 04:05:22  11FB1873-7B9B-4811-858D-7C122654D82D  profile_draft
# 2023-01-31 04:05:22                                   NaN            NaN
# 2023-01-31 04:05:27                                   NaN            NaN
# 2023-01-31 04:05:34                                   NaN            NaN
# 2023-01-31 04:05:38                                   NaN            NaN
#
#                     action source_page coin_id coin_type  entity_id store_id  \
# 2023-01-20 21:04:53    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:05    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-20 11:40:06    NaN         NaN     NaN       NaN        NaN      NaN
# ...                    ...         ...     ...       ...        ...      ...
# 2023-01-31 04:05:22    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:22    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:27    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:34    NaN         NaN     NaN       NaN        NaN      NaN
# 2023-01-31 04:05:38    NaN         NaN     NaN       NaN        NaN      NaN
#
#                     store_name if_claimed destination_coin_type  \
# 2023-01-20 21:04:53        NaN        NaN                   NaN
# 2023-01-20 11:40:05        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# 2023-01-20 11:40:06        NaN        NaN                   NaN
# ...                        ...        ...                   ...
# 2023-01-31 04:05:22        NaN        NaN                   NaN
# 2023-01-31 04:05:22        NaN        NaN                   NaN
# 2023-01-31 04:05:27        NaN        NaN                   NaN
# 2023-01-31 04:05:34        NaN        NaN                   NaN
# 2023-01-31 04:05:38        NaN        NaN                   NaN
#
#                     destination_id destination_name destination_type  \
# 2023-01-20 21:04:53            NaN              NaN              NaN
# 2023-01-20 11:40:05            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# 2023-01-20 11:40:06            NaN              NaN              NaN
# ...                            ...              ...              ...
# 2023-01-31 04:05:22            NaN              NaN              NaN
# 2023-01-31 04:05:22            NaN              NaN              NaN
# 2023-01-31 04:05:27            NaN              NaN              NaN
# 2023-01-31 04:05:34            NaN              NaN              NaN
# 2023-01-31 04:05:38            NaN              NaN              NaN
#
#                      navigation_distance_m  navigation_duration_s  \
# 2023-01-20 21:04:53                    NaN                    NaN
# 2023-01-20 11:40:05                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# 2023-01-20 11:40:06                    NaN                    NaN
# ...                                    ...                    ...
# 2023-01-31 04:05:22                    NaN                    NaN
# 2023-01-31 04:05:22                    NaN                    NaN
# 2023-01-31 04:05:27                    NaN                    NaN
# 2023-01-31 04:05:34                    NaN                    NaN
# 2023-01-31 04:05:38                    NaN                    NaN
#
#                      remaining_distance_m  remaining_duration_s search_text  \
# 2023-01-20 21:04:53                   NaN                   NaN         NaN
# 2023-01-20 11:40:05                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# 2023-01-20 11:40:06                   NaN                   NaN         NaN
# ...                                   ...                   ...         ...
# 2023-01-31 04:05:22                   NaN                   NaN         NaN
# 2023-01-31 04:05:22                   NaN                   NaN         NaN
# 2023-01-31 04:05:27                   NaN                   NaN         NaN
# 2023-01-31 04:05:34                   NaN                   NaN         NaN
# 2023-01-31 04:05:38                   NaN                   NaN         NaN
#
#                     if_empty  wallet_count error_code  total_clips  \
# 2023-01-20 21:04:53      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:05      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# 2023-01-20 11:40:06      NaN           NaN        NaN          NaN
# ...                      ...           ...        ...          ...
# 2023-01-31 04:05:22      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:22      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:27      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:34      NaN           NaN        NaN          NaN
# 2023-01-31 04:05:38      NaN           NaN        NaN          NaN
#
#                      total_video_time_ms category_id category_name  position  \
# 2023-01-20 21:04:53                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:05                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# 2023-01-20 11:40:06                  NaN         NaN           NaN       NaN
# ...                                  ...         ...           ...       ...
# 2023-01-31 04:05:22                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:22                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:27                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:34                  NaN         NaN           NaN       NaN
# 2023-01-31 04:05:38                  NaN         NaN           NaN       NaN
#
#                     entry_point style_id button_type  tutorial_step  \
# 2023-01-20 21:04:53         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:05         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# 2023-01-20 11:40:06         NaN      NaN         NaN            NaN
# ...                         ...      ...         ...            ...
# 2023-01-31 04:05:22         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:22         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:27         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:34         NaN      NaN         NaN            NaN
# 2023-01-31 04:05:38         NaN      NaN         NaN            NaN
#
#                     object_placed object_type entry_category_id  \
# 2023-01-20 21:04:53           NaN         NaN               NaN
# 2023-01-20 11:40:05           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# 2023-01-20 11:40:06           NaN         NaN               NaN
# ...                           ...         ...               ...
# 2023-01-31 04:05:22           NaN         NaN               NaN
# 2023-01-31 04:05:22           NaN         NaN               NaN
# 2023-01-31 04:05:27           NaN         NaN               NaN
# 2023-01-31 04:05:34           NaN         NaN               NaN
# 2023-01-31 04:05:38           NaN         NaN               NaN
#
#                     entry_category_name place_type  clip  start_time_ms  \
# 2023-01-20 21:04:53                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:05                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# 2023-01-20 11:40:06                 NaN        NaN   NaN            NaN
# ...                                 ...        ...   ...            ...
# 2023-01-31 04:05:22                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:22                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:27                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:34                 NaN        NaN   NaN            NaN
# 2023-01-31 04:05:38                 NaN        NaN   NaN            NaN
#
#                     trash_type category_ids category_names experience_types  \
# 2023-01-20 21:04:53        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:05        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# 2023-01-20 11:40:06        NaN          NaN            NaN              NaN
# ...                        ...          ...            ...              ...
# 2023-01-31 04:05:22        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:22        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:27        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:34        NaN          NaN            NaN              NaN
# 2023-01-31 04:05:38        NaN          NaN            NaN              NaN
#
#                     filter_id  clip_duration_ms  clip_start_time_ms  \
# 2023-01-20 21:04:53       NaN               NaN                 NaN
# 2023-01-20 11:40:05       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# 2023-01-20 11:40:06       NaN               NaN                 NaN
# ...                       ...               ...                 ...
# 2023-01-31 04:05:22       NaN               NaN                 NaN
# 2023-01-31 04:05:22       NaN               NaN                 NaN
# 2023-01-31 04:05:27       NaN               NaN                 NaN
# 2023-01-31 04:05:34       NaN               NaN                 NaN
# 2023-01-31 04:05:38       NaN               NaN                 NaN
#
#                     previous_page  position_offset  col_count  row_count  \
# 2023-01-20 21:04:53           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:05           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# 2023-01-20 11:40:06           NaN              NaN        NaN        NaN
# ...                           ...              ...        ...        ...
# 2023-01-31 04:05:22           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:22           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:27           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:34           NaN              NaN        NaN        NaN
# 2023-01-31 04:05:38           NaN              NaN        NaN        NaN
#
#                     button_state music_id toggle_state  caption_length  \
# 2023-01-20 21:04:53          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:05          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# 2023-01-20 11:40:06          NaN      NaN          NaN             NaN
# ...                          ...      ...          ...             ...
# 2023-01-31 04:05:22          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:22          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:27          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:34          NaN      NaN          NaN             NaN
# 2023-01-31 04:05:38          NaN      NaN          NaN             NaN
#
#                      friend_count  hashtag_count  experience_count  \
# 2023-01-20 21:04:53           NaN            NaN               NaN
# 2023-01-20 11:40:05           NaN            NaN               NaN
# 2023-01-20 11:40:06           NaN            NaN               NaN
# 2023-01-20 11:40:06           NaN            NaN               NaN
# 2023-01-20 11:40:06           NaN            NaN               NaN
# ...                           ...            ...               ...
# 2023-01-31 04:05:22           NaN            NaN               NaN
# 2023-01-31 04:05:22           NaN            NaN               NaN
# 2023-01-31 04:05:27           NaN            NaN               NaN
# 2023-01-31 04:05:34           NaN            NaN               NaN
# 2023-01-31 04:05:38           NaN            NaN               NaN
#
#                     save_to_local spot_to_map  from_position  to_position  \
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# 2023-01-20 11:40:06               NaN            NaN      NaN        NaN
# ...                               ...            ...      ...        ...
# 2023-01-31 04:05:22               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:22               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:27               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:34               NaN            NaN      NaN        NaN
# 2023-01-31 04:05:38               NaN            NaN      NaN        NaN
#
#                     message target tour_id tour_user_id tour_username  \
# 2023-01-20 21:04:53     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:05     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# 2023-01-20 11:40:06     NaN    NaN     NaN          NaN           NaN
# ...                     ...    ...     ...          ...           ...
# 2023-01-31 04:05:22     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:22     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:27     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:34     NaN    NaN     NaN          NaN           NaN
# 2023-01-31 04:05:38     NaN    NaN     NaN          NaN           NaN
#
#                     original property property_category reward_id  \
# 2023-01-20 21:04:53      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:05      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# 2023-01-20 11:40:06      NaN      NaN               NaN       NaN
# ...                      ...      ...               ...       ...
# 2023-01-31 04:05:22      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:22      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:27      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:34      NaN      NaN               NaN       NaN
# 2023-01-31 04:05:38      NaN      NaN               NaN       NaN
#
#                     session_duration_ms if_nft_reward if_redeemed  \
# 2023-01-20 21:04:53                 NaN           NaN         NaN
# 2023-01-20 11:40:05                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# 2023-01-20 11:40:06                 NaN           NaN         NaN
# ...                                 ...           ...         ...
# 2023-01-31 04:05:22                 NaN           NaN         NaN
# 2023-01-31 04:05:22                 NaN           NaN         NaN
# 2023-01-31 04:05:27                 NaN           NaN         NaN
# 2023-01-31 04:05:34                 NaN           NaN         NaN
# 2023-01-31 04:05:38                 NaN           NaN         NaN
#
#                     reward_state option platform  deeplink_type deeplink_url  \
# 2023-01-20 21:04:53          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:05          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# 2023-01-20 11:40:06          NaN    NaN      NaN            NaN          NaN
# ...                          ...    ...      ...            ...          ...
# 2023-01-31 04:05:22          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:22          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:27          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:34          NaN    NaN      NaN            NaN          NaN
# 2023-01-31 04:05:38          NaN    NaN      NaN            NaN          NaN
#
#                     traffic
# 2023-01-20 21:04:53     NaN
# 2023-01-20 11:40:05     NaN
# 2023-01-20 11:40:06     NaN
# 2023-01-20 11:40:06     NaN
# 2023-01-20 11:40:06     NaN
# ...                     ...
# 2023-01-31 04:05:22     NaN
# 2023-01-31 04:05:22     NaN
# 2023-01-31 04:05:27     NaN
# 2023-01-31 04:05:34     NaN
# 2023-01-31 04:05:38     NaN
#
# [373063 rows x 183 columns]

# %%
import pandas as pd
import datetime
import glob
import pymysql
from mysql.connector import connect
import os
from sqlalchemy import create_engine


    
data_dir = '/Users/allen/Desktop/clo/flickplay/mixpanel-events/data'

host='localhost'
user='root'
password=''
port=3306
database='fpa'
creds = dict(host=host,user=user,password=password,database=database)

def get_alchemy_con():
    host='localhost'
    user='root'
    password=''
    port=3306
    database='fpa'
    return create_engine(f'mysql+pymysql://{user}:{password}@localhost/{database}')

def get_pymysql_con():
    return pymysql.connect(**creds)

def get_mysql_connector_con():
    return connect(**creds)
# get the superset of column names

def get_all_columns(path_to_csvs='/Users/allen/Desktop/clo/flickplay/mixpanel-events/data/mon'):
    all_columns = set()

    for inf in glob.glob('*.csv'):
        cols = pd.read_csv(inf).columns

        for col in cols:
            all_columns.add(col)

        print('all:',len(all_columns),'these:',len(cols))
    
    to_be_removed = [
        'Unnamed: 0',
        'date.1',
        'path'
    ]

    for colname in to_be_removed:
        all_columns.remove(colname)
        
    return all_columns


con = get_alchemy_con()

# %%
columns = pd.read_sql('SELECT * FROM fpa.events limit 1', con).columns

df1 = pd.DataFrame(columns = columns )

bigdf = pd.concat([df1, bigdf])

bigdf = bigdf[columns]

# %%
bigdf
# Out:
#                                         event        date        time  \
# 2023-01-20 21:04:53               $ae_updated  2023-01-20  1674248693
# 2023-01-20 11:40:05               $ae_updated  2023-01-20  1674214805
# 2023-01-20 11:40:06            session__start  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# 2023-01-20 11:40:06      performance__network  2023-01-20  1674214806
# ...                                       ...         ...         ...
# 2023-01-31 04:05:22  profile_draft__load_list  2023-01-30  1675137922
# 2023-01-31 04:05:22        profile__load_page  2023-01-30  1675137922
# 2023-01-31 04:05:27      performance__network  2023-01-30  1675137927
# 2023-01-31 04:05:34      performance__network  2023-01-30  1675137934
# 2023-01-31 04:05:38      performance__network  2023-01-30  1675137938
#
#                                   distinct_id $ae_first_app_open_date  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c                     NaN
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb                     NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                     NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                     NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                     NaN
# ...                                       ...                     ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                     NaN
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                     NaN
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a                     NaN
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a                     NaN
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a                     NaN
#
#                     $app_build_number $app_version_string  $carrier  \
# 2023-01-20 21:04:53              6043              1.79.2   Verizon
# 2023-01-20 11:40:05              6043              1.79.2       NaN
# 2023-01-20 11:40:06              6043              1.79.2       NaN
# 2023-01-20 11:40:06              6043              1.79.2       NaN
# 2023-01-20 11:40:06              6043              1.79.2       NaN
# ...                               ...                 ...       ...
# 2023-01-31 04:05:22              6054              1.79.2  T-Mobile
# 2023-01-31 04:05:22              6054              1.79.2  T-Mobile
# 2023-01-31 04:05:27              6054              1.79.2  T-Mobile
# 2023-01-31 04:05:34              6054              1.79.2  T-Mobile
# 2023-01-31 04:05:38              6054              1.79.2  T-Mobile
#
#                          $city                            $device_id  \
# 2023-01-20 21:04:53   Kennesaw  16528B81-05A4-450D-B464-5D8CF5419A1F
# 2023-01-20 11:40:05  Hampshire  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  Hampshire  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  Hampshire  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# 2023-01-20 11:40:06  Hampshire  7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17
# ...                        ...                                   ...
# 2023-01-31 04:05:22      Seoul  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:22      Seoul  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:27      Seoul  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:34      Seoul  0A6398E0-4F5C-424C-91A0-D231FBF635B8
# 2023-01-31 04:05:38      Seoul  0A6398E0-4F5C-424C-91A0-D231FBF635B8
#
#                     $had_persisted_distinct_id        $insert_id $lib_version  \
# 2023-01-20 21:04:53                       True  7366f59bf7f27fe5        3.5.1
# 2023-01-20 11:40:05                       True  ccb8e7bd625e8e12        3.5.1
# 2023-01-20 11:40:06                       True  cb9d6dae68e64ae0        3.5.1
# 2023-01-20 11:40:06                       True  562689d06fa655ca        3.5.1
# 2023-01-20 11:40:06                       True  82ed5a331de27f22        3.5.1
# ...                                        ...               ...          ...
# 2023-01-31 04:05:22                       True  12959f06daa69800        3.5.1
# 2023-01-31 04:05:22                       True  3e1857d00c4187bf        3.5.1
# 2023-01-31 04:05:27                       True  e89aa74dceb31643        3.5.1
# 2023-01-31 04:05:34                       True  06a941026f2fce1c        3.5.1
# 2023-01-31 04:05:38                       True  a893f69c5ce4f2d9        3.5.1
#
#                     $manufacturer      $model  $mp_api_endpoint  \
# 2023-01-20 21:04:53         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-20 11:40:05         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# 2023-01-20 11:40:06         Apple  iPhone14,2  api.mixpanel.com
# ...                           ...         ...               ...
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:22         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05:27         Apple  iPhone13,2  api.mixpanel.com
# 2023-01-31 04:05
# 2023-01-20 11:40:06  6B91B105-25DB-45BA-B820-1BEEDDFB99F0      1.79.2  prod
# ...                                                   ...         ...   ...
# 2023-01-31 04:05:22  76A71B18-9C6E-48D3-B16D-F1686446B0D5      1.79.2  prod
# 2023-01-31 04:05:22  76A71B18-9C6E-48D3-B16D-F1686446B0D5      1.79.2  prod
# 2023-01-31 04:05:27  76A71B18-9C6E-48D3-B16D-F1686446B0D5      1.79.2  prod
# 2023-01-31 04:05:34  76A71B18-9C6E-48D3-B16D-F1686446B0D5      1.79.2  prod
# 2023-01-31 04:05:38  76A71B18-9C6E-48D3-B16D-F1686446B0D5      1.79.2  prod
#
#                     location_enabled user_gps_location  \
# 2023-01-20 21:04:53            False               NaN
# 2023-01-20 11:40:05            False               NaN
# 2023-01-20 11:40:06            False               NaN
# 2023-01-20 11:40:06            False               NaN
# 2023-01-20 11:40:06            False               NaN
# ...                              ...               ...
# 2023-01-31 04:05:22            False               NaN
# 2023-01-31 04:05:22            False               NaN
# 2023-01-31 04:05:27            False               NaN
# 2023-01-31 04:05:34            False               NaN
# 2023-01-31 04:05:38            False               NaN
#
#                      user_location_accuracy duration_ms method  \
# 2023-01-20 21:04:53                    -2.0         NaN    NaN
# 2023-01-20 11:40:05                    -2.0         NaN    NaN
# 2023-01-20 11:40:06                    -2.0         NaN    NaN
# 2023-01-20 11:40:06                    -2.0         530   POST
# 2023-01-20 11:40:06                    -2.0         580    GET
# ...                                     ...         ...    ...
# 2023-01-31 04:05:22                    -2.0         NaN    NaN
# 2023-01-31 04:05:22                    -2.0      <null>    NaN
# 2023-01-31 04:05:27                    -2.0        9427    GET
# 2023-01-31 04:05:34                    -2.0        5480    GET
# 2023-01-31 04:05:38                    -2.0        3742    GET
#
#                      response_bytes  status_code  \
# 2023-01-20 21:04:53             NaN          NaN
# 2023-01-20 11:40:05             NaN          NaN
# 2023-01-20 11:40:06             NaN          NaN
# 2023-01-20 11:40:06          2144.0        200.0
# 2023-01-20 11:40:06        267320.0        200.0
# ...                             ...          ...
# 2023-01-31 04:05:22             NaN          NaN
# 2023-01-31 04:05:22             NaN          NaN
# 2023-01-31 04:05:27       3893145.0        200.0
# 2023-01-31 04:05:34        270102.0        200.0
# 2023-01-31 04:05:38       1060065.0        200.0
#
#                                                                    url  count  \
# 2023-01-20 21:04:53                                                NaN    NaN
# 2023-01-20 11:40:05                                                NaN    NaN
# 2023-01-20 11:40:06                                                NaN    NaN
# 2023-01-20 11:40:06                       api.app.flickplay.co/users/*    NaN
# 2023-01-20 11:40:06                        api.app.flickplay.co/config    NaN
# ...                                                                ...    ...
# 2023-01-31 04:05:22                                                NaN    1.0
# 2023-01-31 04:05:22                                                NaN    NaN
# 2023-01-31 04:05:27  api.app.flickplay.co/flicks/experiences/sync/full    NaN
# 2023-01-31 04:05:34               api.app.flickplay.co/flicks/flicksV3    NaN
# 2023-01-31 04:05:38               api.app.flickplay.co/flicks/storesV2    NaN
#
#                     feature_source_page           profile_user_id result  tab  \
# 2023-01-20 21:04:53                 NaN                       NaN    NaN  NaN
# 2023-01-20 11:40:05                 NaN                       NaN    NaN  NaN
# 2023-01-20 11:40:06                 NaN                       NaN    NaN  NaN
# 2023-01-20 11:40:06                 NaN                       NaN    NaN  NaN
# 2023-01-20 11:40:06                 NaN                       NaN    NaN  NaN
# ...                                 ...                       ...    ...  ...
# 2023-01-31 04:05:22   user_profile_main                       NaN    NaN  NaN
# 2023-01-31 04:05:22   user_profile_main  63d903fe7733afd5c426b99a    NaN  NaN
# 2023-01-31 04:05:27                 NaN                       NaN    NaN  NaN
# 2023-01-31 04:05:34                 NaN                       NaN    NaN  NaN
# 2023-01-31 04:05:38                 NaN                       NaN    NaN  NaN
#
#                     $ae_updated_version                  $user_id anon_user  \
# 2023-01-20 21:04:53              1.79.2  62091247af9972084d6c3c3c      True
# 2023-01-20 11:40:05              1.79.2  62169902b3fc532d89a663cb      True
# 2023-01-20 11:40:06                 NaN  62169902b3fc532d89a663cb      True
# 2023-01-20 11:40:06                 NaN  62169902b3fc532d89a663cb      True
# 2023-01-20 11:40:06                 NaN  62169902b3fc532d89a663cb      True
# ...                                 ...                       ...       ...
# 2023-01-31 04:05:22                 NaN  63d903fe7733afd5c426b99a      True
# 2023-01-31 04:05:22                 NaN  63d903fe7733afd5c426b99a      True
# 2023-01-31 04:05:27                 NaN  63d903fe7733afd5c426b99a      True
# 2023-01-31 04:05:34                 NaN  63d903fe7733afd5c426b99a      True
# 2023-01-31 04:05:38                 NaN  63d903fe7733afd5c426b99a      True
#
#                                       user_id            username  \
# 2023-01-20 21:04:53  62091247af9972084d6c3c3c                 NaN
# 2023-01-20 11:40:05  62169902b3fc532d89a663cb                 NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                 NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                 NaN
# 2023-01-20 11:40:06  62169902b3fc532d89a663cb                 NaN
# ...                                       ...                 ...
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a                 NaN
# 2023-01-31 04:05:22  63d903fe7733afd5c426b99a  anonymous-30244568
# 2023-01-31 04:05:27  63d903fe7733afd5c426b99a                 NaN
# 2023-01-31 04:05:34  63d903fe7733afd5c426b99a                 NaN
# 2023-01-31 04:05:38  63d903fe7733afd5c426b99a                 NaN
#
#                     session_length session sub_session video_id video_type  \
# 2023-01-20 21:04:53            NaN     NaN         NaN      NaN        NaN
# 2023-01-20 11:40:05            NaN     NaN         NaN      NaN        NaN
# 2023-01-20 11:40:06            NaN     NaN         NaN      NaN        NaN
# 2023-01-20 11:40:06            NaN     NaN         NaN      NaN        NaN
# 2023-01-20 11:40:06            NaN     NaN         NaN      NaN        NaN
# ...                            ...     ...         ...      ...        ...
# 2023-01-31 04:05:22            NaN     NaN         NaN      NaN        NaN
# 2023-01-31 04:05:22            NaN     NaN         NaN      NaN        NaN
# 2023-01-31 04:05:27            NaN     NaN         NaN      NaN        NaN
# 2023-01-31 04:05:34            NaN     NaN         NaN      NaN        NaN
# 2023-01-31 04:05:38            NaN     NaN         NaN      NaN        NaN
#
#                     video_user_id source_page  $ae_session_length  \
# 2023-01-20 21:04:53           NaN         NaN                 NaN
#
#                      reload_amount  price_value button_type  wallet_count  \
# 2023-01-20 21:04:53            NaN          NaN         NaN           NaN
# 2023-01-20 11:40:05            NaN          NaN         NaN           NaN
# 2023-01-20 11:40:06            NaN          NaN         NaN           NaN
# 2023-01-20 11:40:06            NaN          NaN         NaN           NaN
# 2023-01-20 11:40:06            NaN          NaN         NaN           NaN
# ...                            ...          ...         ...           ...
# 2023-01-31 04:05:22            NaN          NaN         NaN           NaN
# 2023-01-31 04:05:22            NaN          NaN         NaN           NaN
# 2023-01-31 04:05:27            NaN          NaN         NaN           NaN
# 2023-01-31 04:05:34            NaN          NaN         NaN           NaN
# 2023-01-31 04:05:38            NaN          NaN         NaN           NaN
#
#                     wallet_name if_empty collectible_id collectible_name  \
# 2023-01-20 21:04:53         NaN      NaN            NaN              NaN
# 2023-01-20 11:40:05         NaN      NaN            NaN              NaN
# 2023-01-20 11:40:06         NaN      NaN            NaN              NaN
# 2023-01-20 11:40:06         NaN      NaN            NaN              NaN
# 2023-01-20 11:40:06         NaN      NaN            NaN              NaN
# ...                         ...      ...            ...              ...
# 2023-01-31 04:05:22         NaN      NaN            NaN              NaN
# 2023-01-31 04:05:22         NaN      NaN            NaN              NaN
# 2023-01-31 04:05:27         NaN      NaN            NaN              NaN
# 2023-01-31 04:05:34         NaN      NaN            NaN              NaN
# 2023-01-31 04:05:38         NaN      NaN            NaN              NaN
#
#                     collectible_status collectible_tier  clip  \
# 2023-01-20 21:04:53                NaN              NaN   NaN
# 2023-01-20 11:40:05                NaN              NaN   NaN
# 2023-01-20 11:40:06                NaN              NaN   NaN
# 2023-01-20 11:40:06                NaN              NaN   NaN
# 2023-01-20 11:40:06                NaN              NaN   NaN
# ...                                ...              ...   ...
# 2023-01-31 04:05:22                NaN              NaN   NaN
# 2023-01-31 04:05:22                NaN              NaN   NaN
# 2023-01-31 04:05:27                NaN              NaN   NaN
# 2023-01-31 04:05:34                NaN              NaN   NaN
# 2023-01-31 04:05:38                NaN              NaN   NaN
#
#                     entry_category_id entry_category_name  tutorial_step  \
# 2023-01-20 21:04:53               NaN                 NaN            NaN
# 2023-01-20 11:40:05               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2023-01-31 04:05:22               NaN                 NaN            NaN
# 2023-01-31 04:05:22               NaN                 NaN            NaN
# 2023-01-31 04:05:27               NaN                 NaN            NaN
# 2023-01-31 04:05:34               NaN                 NaN            NaN
# 2023-01-31 04:05:38               NaN                 NaN            NaN
#
#                     object_placed object_type place_type  start_time_ms  \
# 2023-01-20 21:04:53           NaN         NaN        NaN            NaN
# 2023-01-20 11:40:05           NaN         NaN        NaN            NaN
# 2023-01-20 11:40:06           NaN         NaN        NaN            NaN
# 2023-01-20 11:40:06           NaN         NaN        NaN            NaN
# 2023-01-20 11:40:06           NaN         NaN        NaN            NaN
# 2023-01-31 04:05:38           NaN     NaN     NaN          NaN      NaN
#
#                      col_count  row_count share_platform error_code reason  \
# 2023-01-20 21:04:53        NaN        NaN            NaN        NaN    NaN
# 2023-01-20 11:40:05        NaN        NaN            NaN        NaN    NaN
# 2023-01-20 11:40:06        NaN        NaN            NaN        NaN    NaN
# 2023-01-20 11:40:06        NaN        NaN            NaN        NaN    NaN
# 2023-01-20 11:40:06        NaN        NaN            NaN        NaN    NaN
# ...                        ...        ...            ...        ...    ...
# 2023-01-31 04:05:22        NaN        NaN            NaN        NaN    NaN
# 2023-01-31 04:05:22        NaN        NaN            NaN        NaN    NaN
# 2023-01-31 04:05:27        NaN        NaN            NaN        NaN    NaN
# 2023-01-31 04:05:34        NaN        NaN            NaN        NaN    NaN
# 2023-01-31 04:05:38        NaN        NaN            NaN        NaN    NaN
#
#                      position_offset previous_page  goal_like badge_id  \
# 2023-01-20 21:04:53              NaN           NaN        NaN      NaN
# 2023-01-20 11:40:05              NaN           NaN        NaN      NaN
# 2023-01-20 11:40:06              NaN           NaN        NaN      NaN
# 2023-01-20 11:40:06              NaN           NaN        NaN      NaN
# 2023-01-20 11:40:06              NaN           NaN        NaN      NaN
# ...                              ...           ...        ...      ...
# 2023-01-31 04:05:22              NaN           NaN        NaN      NaN
# 2023-01-31 04:05:22              NaN           NaN        NaN      NaN
# 2023-01-31 04:05:27              NaN           NaN        NaN      NaN
# 2023-01-31 04:05:34              NaN           NaN        NaN      NaN
# 2023-01-31 04:05:38              NaN           NaN        NaN      NaN
#
#                     badge_name coin_type  nft_sync_count wallet_address path  \
# 2023-01-20 21:04:53        NaN       NaN             NaN            NaN  NaN
# 2023-01-20 11:40:05        NaN       NaN             NaN            NaN  NaN
# 2023-01-20 11:40:06        NaN       NaN             NaN            NaN  NaN
# 2023-01-20 11:40:06        NaN       NaN             NaN            NaN  NaN
# 2023-01-20 11:40:06        NaN       NaN             NaN            NaN  NaN
# ...                        ...       ...             ...            ...  ...
# 2023-01-31 04:05:22        NaN       NaN             NaN            NaN  NaN
# 2023-01-31 04:05:22        NaN       NaN             NaN            NaN  NaN
# 2023-01-31 04:05:27        NaN       NaN             NaN            NaN  NaN
# 2023-01-31 04:05:34        NaN       NaN             NaN            NaN  NaN
# 2023-01-31 04:05:38        NaN       NaN             NaN            NaN  NaN
#
#                     toggle_state entity_id poi_type store_id store_name  \
# 2023-01-20 21:04:53          NaN       NaN      NaN      NaN        NaN
# 2023-01-20 11:40:05          NaN       NaN      NaN      NaN        NaN
# 2023-01-20 11:40:06          NaN       NaN      NaN      NaN        NaN
# 2023-01-20 11:40:06          NaN       NaN      NaN      NaN        NaN
# 2023-01-20 11:40:06          NaN       NaN      NaN      NaN        NaN
# ...                          ...       ...      ...      ...        ...
# 2023-01-31 04:05:22          NaN       NaN      NaN      NaN        NaN
# 2023-01-31 04:05:22          NaN       NaN      NaN      NaN        NaN
# 2023-01-31 04:05:27          NaN       NaN      NaN      NaN        NaN
# 2023-01-31 04:05:34          NaN       NaN      NaN      NaN        NaN
# 2023-01-31 04:05:38          NaN       NaN      NaN      NaN        NaN
#
#                     destination_coin_type destination_id destination_name  \
# 2023-01-20 21:04:53                   NaN            NaN              NaN
# 2023-01-20 11:40:05                   NaN            NaN              NaN
# 2023-01-20 11:40:06                   NaN            NaN              NaN
# 2023-01-20 11:40:06                   NaN            NaN              NaN
# 2023-01-20 11:40:06                   NaN            NaN              NaN
# ...                                   ...            ...              ...
# 2023-01-31 04:05:22                   NaN            NaN              NaN
# 2023-01-31 04:05:22                   NaN            NaN              NaN
# 2023-01-31 04:05:27                   NaN            NaN              NaN
# 2023-01-31 04:05:34                   NaN            NaN              NaN
# 2023-01-31 04:05:38                   NaN            NaN              NaN
#
#                     destination_type  navigation_distance_m  \
# 2023-01-20 21:04:53              NaN                    NaN
# 2023-01-20 11:40:05              NaN                    NaN
# 2023-01-20 11:40:06              NaN                    NaN
# 2023-01-20 11:40:06              NaN                    NaN
# 2023-01-20 11:40:06              NaN                    NaN
# ...                              ...                    ...
# 2023-01-31 04:05:22              NaN                    NaN
# 2023-01-31 04:05:22              NaN                    NaN
# 2023-01-31 04:05:27              NaN                    NaN
# 2023-01-31 04:05:34              NaN                    NaN
# 2023-01-31 04:05:38              NaN                    NaN
#
#                      navigation_duration_s  remaining_distance_m  \
# 2023-01-20 21:04:53                    NaN                   NaN
# 2023-01-20 11:40:05                    NaN                   NaN
# 2023-01-20 11:40:06                    NaN                   NaN
# 2023-01-20 11:40:06                    NaN                   NaN
# 2023-01-20 11:40:06                    NaN                   NaN
# ...                                    ...                   ...
# 2023-01-31 04:05:22                    NaN                   NaN
# 2023-01-31 04:05:22                    NaN                   NaN
# 2023-01-31 04:05:27                    NaN                   NaN
# 2023-01-31 04:05:34                    NaN                   NaN
# 2023-01-31 04:05:38                    NaN                   NaN
#
#                      remaining_duration_s text   id name property  \
# 2023-01-20 21:04:53                   NaN  NaN  NaN  NaN      NaN
# 2023-01-20 11:40:05                   NaN  NaN  NaN  NaN      NaN
# 2023-01-20 11:40:06                   NaN  NaN  NaN  NaN      NaN
# 2023-01-20 11:40:06                   NaN  NaN  NaN  NaN      NaN
# 2023-01-20 11:40:06                   NaN  NaN  NaN  NaN      NaN
# ...                                   ...  ...  ...  ...      ...
# 2023-01-31 04:05:22                   NaN  NaN  NaN  NaN      NaN
# 2023-01-31 04:05:22                   NaN  NaN  NaN  NaN      NaN
# 2023-01-31 04:05:27                   NaN  NaN  NaN  NaN      NaN
# 2023-01-31 04:05:34                   NaN  NaN  NaN  NaN      NaN
# 2023-01-31 04:05:38                   NaN  NaN  NaN  NaN      NaN
#
#                     property_category reward_id if_claimed user_name  \
# 2023-01-20 21:04:53               NaN       NaN        NaN       NaN
# 2023-01-20 11:40:05               NaN       NaN        NaN       NaN
# 2023-01-20 11:40:06               NaN       NaN        NaN       NaN
# 2023-01-20 11:40:06               NaN       NaN        NaN       NaN
# 2023-01-20 11:40:06               NaN       NaN        NaN       NaN
# ...                               ...       ...        ...       ...
# 2023-01-31 04:05:22               NaN       NaN        NaN       NaN
# 2023-01-31 04:05:22               NaN       NaN        NaN       NaN
# 2023-01-31 04:05:27               NaN       NaN        NaN       NaN
# 2023-01-31 04:05:34               NaN       NaN        NaN       NaN
# 2023-01-31 04:05:38               NaN       NaN        NaN       NaN
#
#                      clip_duration_ms  clip_start_time_ms display_avatar  \
# 2023-01-20 21:04:53               NaN                 NaN            NaN
# 2023-01-20 11:40:05               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# 2023-01-20 11:40:06               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2023-01-31 04:05:22               NaN                 NaN            NaN
# 2023-01-31 04:05:22               NaN                 NaN            NaN
# 2023-01-31 04:05:27               NaN                 NaN            NaN
# 2023-01-31 04:05:34               NaN                 NaN            NaN
# 2023-01-31 04:05:38               NaN                 NaN            NaN
#
#                     have_stock  nft state email
# 2023-01-20 21:04:53        NaN  NaN   NaN   NaN
# 2023-01-20 11:40:05        NaN  NaN   NaN   NaN
# 2023-01-20 11:40:06        NaN  NaN   NaN   NaN
# 2023-01-20 11:40:06        NaN  NaN   NaN   NaN
# 2023-01-20 11:40:06        NaN  NaN   NaN   NaN
# ...                        ...  ...   ...   ...
# 2023-01-31 04:05:22        NaN  NaN   NaN   NaN
# 2023-01-31 04:05:22        NaN  NaN   NaN   NaN
# 2023-01-31 04:05:27        NaN  NaN   NaN   NaN
# 2023-01-31 04:05:34        NaN  NaN   NaN   NaN
# 2023-01-31 04:05:38        NaN  NaN   NaN   NaN
#
# [373063 rows x 165 columns]

# %%
bigdf.to_sql('events',
             con,
             if_exists='append',
             index=False)

# %%
infiles
# Out:
# ['2023-01-01.csv',
#  '2023-01-02.csv',
#  '2023-01-03.csv',
#  '2023-01-04.csv',
#  '2023-01-05.csv',
#  '2023-01-06.csv',
#  '2023-01-07.csv',
#  '2023-01-08.csv',
#  '2023-01-09.csv',
#  '2023-01-10.csv',
#  '2023-01-11.csv',
#  '2023-01-12.csv',
#  '2023-01-13.csv',
#  '2023-01-14.csv',
#  '2023-01-15.csv',
#  '2023-01-16.csv',
#  '2023-01-17.csv',
#  '2023-01-18.csv',
#  '2023-01-19.csv',
#  '2023-01-20.csv',
#  '2023-01-21.csv',
#  '2023-01-22.csv',
#  '2023-01-23.csv',
#  '2023-01-24.csv',
#  '2023-01-25.csv',
#  '2023-01-26.csv',
#  '2023-01-27.csv',
#  '2023-01-28.csv',
#  '2023-01-29.csv',
#  '2023-01-30.csv',
#  '2023-01-31.csv']

# %%
d=pd.read_sql("SELECT count(event) e, date from fpa.events where date>'2022-12-31' group by date", con)

# %%
d
# Out:
#         e        date
# 0   20165  2023-01-01
# 1   18601  2023-01-02
# 2   25083  2023-01-03
# 3   23811  2023-01-04
# 4   43918  2023-01-05
# 5   30891  2023-01-06
# 6   33410  2023-01-07
# 7   26468  2023-01-08
# 8   29519  2023-01-09
# 2023-01-20 23:40:50  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
# 2023-01-20 23:40:51  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
# 2023-01-20 23:40:52  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
#
#                     location_enabled           user_gps_location  \
# 2023-01-01 16:04:23             True  lat: 51.4037; long: 6.7038
# 2023-01-01 16:04:24             True  lat: 51.4037; long: 6.7038
# 2023-01-01 16:04:25             True  lat: 51.4037; long: 6.7038
# 2023-01-01 16:04:25             True  lat: 51.4037; long: 6.7038
# 2023-01-01 16:04:25             True  lat: 51.4037; long: 6.7038
# ...                              ...                         ...
# 2023-01-20 21:00:55            False                         NaN
# 2023-01-20 21:02:14            False                         NaN
# 2023-01-20 23:40:50            False                         NaN
# 2023-01-20 23:40:51            False                         NaN
# 2023-01-20 23:40:52            False                         NaN
#
#                      user_location_accuracy duration_ms method  \
# 2023-01-01 16:04:23                    -2.0         NaN    NaN
# 2023-01-01 16:04:24                    -2.0         760   POST
# 2023-01-01 16:04:25                    -2.0        1329    GET
# 2023-01-01 16:04:25                    -2.0        1464    GET
# 2023-01-01 16:04:25                    -2.0         181   POST
# ...                                     ...         ...    ...
# 2023-01-20 21:00:55                    -2.0        3104    GET
# 2023-01-20 21:02:14                    -2.0         NaN    NaN
# 2023-01-20 23:40:50                    -2.0         NaN    NaN
# 2023-01-20 23:40:51                    -2.0         448    GET
# 2023-01-20 23:40:52                    -2.0         527   POST
#
#                      response_bytes  status_code  \
# 2023-01-01 16:04:23             NaN          NaN
# 2023-01-01 16:04:24          2512.0        200.0
# 2023-01-01 16:04:25          4524.0        200.0
# 2023-01-01 16:04:25        261960.0        200.0
# 2023-01-01 16:04:25           175.0        404.0
# ...                             ...          ...
# 2023-01-20 21:00:55       1060351.0        200.0
# 2023-01-20 21:02:14             NaN          NaN
# 2023-01-20 23:40:50             NaN          NaN
# 2023-01-20 23:40:51        268193.0        200.0
# 2023-01-20 23:40:52        188568.0        200.0
#
#                                                                    url  count  \
# 2023-01-01 16:04:23                                                NaN    NaN
# 2023-01-01 16:04:24                       api.app.flickplay.co/users/*    NaN
# 2023-01-01 16:04:25                       api.app.flickplay.co/users/*    NaN
# 2023-01-01 16:04:25                        api.app.flickplay.co/config    NaN
# 2023-01-01 16:04:25  api.app.flickplay.co/flicks/experiences/sync/r...    NaN
# ...                                                                ...    ...
# 2023-01-20 21:00:55               api.app.flickplay.co/flicks/storesV2    NaN
# 2023-01-20 21:02:14                                                NaN    NaN
# 2023-01-20 23:40:50                                                NaN    NaN
# 2023-01-20 23:40:51                        api.app.flickplay.co/config    NaN
# 2023-01-20 23:40:52                api.app.flickplay.co/auth/anonymous    NaN
#
#                     feature_source_page profile_user_id result  tab  \
# 2023-01-01 16:04:23                 NaN             NaN    NaN  NaN
# 2023-01-01 16:04:24                 NaN             NaN    NaN  NaN
# 2023-01-01 16:04:25                 NaN             NaN    NaN  NaN
# 2023-01-01 16:04:25                 NaN             NaN    NaN  NaN
# 2023-01-20 23:40:51            NaN          NaN         NaN           NaN
# 2023-01-20 23:40:52            NaN          NaN         NaN           NaN
#
#                     wallet_name if_empty collectible_id collectible_name  \
# 2023-01-01 16:04:23         NaN      NaN            NaN              NaN
# 2023-01-01 16:04:24         NaN      NaN            NaN              NaN
# 2023-01-01 16:04:25         NaN      NaN            NaN              NaN
# 2023-01-01 16:04:25         NaN      NaN            NaN              NaN
# 2023-01-01 16:04:25         NaN      NaN            NaN              NaN
# ...                         ...      ...            ...              ...
# 2023-01-20 21:00:55         NaN      NaN            NaN              NaN
# 2023-01-20 21:02:14         NaN      NaN            NaN              NaN
# 2023-01-20 23:40:50         NaN      NaN            NaN              NaN
# 2023-01-20 23:40:51         NaN      NaN            NaN              NaN
# 2023-01-20 23:40:52         NaN      NaN            NaN              NaN
#
#                     collectible_status collectible_tier  clip  \
# 2023-01-01 16:04:23                NaN              NaN   NaN
# 2023-01-01 16:04:24                NaN              NaN   NaN
# 2023-01-01 16:04:25                NaN              NaN   NaN
# 2023-01-01 16:04:25                NaN              NaN   NaN
# 2023-01-01 16:04:25                NaN              NaN   NaN
# ...                                ...              ...   ...
# 2023-01-20 21:00:55                NaN              NaN   NaN
# 2023-01-20 21:02:14                NaN              NaN   NaN
# 2023-01-20 23:40:50                NaN              NaN   NaN
# 2023-01-20 23:40:51                NaN              NaN   NaN
# 2023-01-20 23:40:52                NaN              NaN   NaN
#
#                     entry_category_id entry_category_name  tutorial_step  \
# 2023-01-01 16:04:23               NaN                 NaN            NaN
# 2023-01-01 16:04:24               NaN                 NaN            NaN
# 2023-01-01 16:04:25               NaN                 NaN            NaN
# 2023-01-01 16:04:25               NaN                 NaN            NaN
# 2023-01-01 16:04:25               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2023-01-20 21:00:55               NaN                 NaN            NaN
# 2023-01-20 21:02:14               NaN                 NaN            NaN
# 2023-01-20 23:40:50               NaN                 NaN            NaN
# 2023-01-20 23:40:51               NaN                 NaN            NaN
# 2023-01-20 23:40:52               NaN                 NaN            NaN
#
#                     object_placed object_type place_type  start_time_ms  \
# 2023-01-01 16:04:23           NaN         NaN        NaN            NaN
# 2023-01-01 16:04:24           NaN         NaN        NaN            NaN
# 2023-01-01 16:04:25           NaN         NaN        NaN            NaN
# 2023-01-01 16:04:25           NaN         NaN        NaN            NaN
# 2023-01-01 16:04:25           NaN         NaN        NaN            NaN
# ...                           ...         ...        ...            ...
# 2023-01-20 21:00:55           NaN         NaN        NaN            NaN
# 2023-01-20 21:02:14           NaN         NaN        NaN            NaN
# 2023-01-20 23:40:50           NaN         NaN        NaN            NaN
# 2023-01-20 23:40:51           NaN         NaN        NaN            NaN
# 2023-01-20 23:40:52           NaN         NaN        NaN            NaN
#
#                     trash_type filter_id  caption_length  friend_count  \
# 2023-01-01 16:04:23        NaN       NaN             NaN           NaN
# 2023-01-01 16:04:24        NaN       NaN             NaN           NaN
# 2023-01-01 16:04:25        NaN       NaN             NaN           NaN
# 2023-01-01 16:04:25               NaN                 NaN            NaN
# 2023-01-01 16:04:25               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2023-01-20 21:00:55               NaN                 NaN            NaN
# 2023-01-20 21:02:14               NaN                 NaN            NaN
# 2023-01-20 23:40:50               NaN                 NaN            NaN
# 2023-01-20 23:40:51               NaN                 NaN            NaN
# 2023-01-20 23:40:52               NaN                 NaN            NaN
#
#                     have_stock  nft state email
# 2023-01-01 16:04:23        NaN  NaN   NaN   NaN
# 2023-01-01 16:04:24        NaN  NaN   NaN   NaN
# 2023-01-01 16:04:25        NaN  NaN   NaN   NaN
# 2023-01-01 16:04:25        NaN  NaN   NaN   NaN
# 2023-01-01 16:04:25        NaN  NaN   NaN   NaN
# ...                        ...  ...   ...   ...
# 2023-01-20 21:00:55        NaN  NaN   NaN   NaN
# 2023-01-20 21:02:14        NaN  NaN   NaN   NaN
# 2023-01-20 23:40:50        NaN  NaN   NaN   NaN
# 2023-01-20 23:40:51        NaN  NaN   NaN   NaN
# 2023-01-20 23:40:52        NaN  NaN   NaN   NaN
#
# [600891 rows x 165 columns]

# %%
df = pd.read_csv('2023-01-20.csv')
df
# Out:
#        Unnamed: 0                 event                 date        time  \
# 0               0           $ae_updated  2023-01-20 21:04:53  1674248693
# 1               1           $ae_updated  2023-01-20 11:40:05  1674214805
# 2               2        session__start  2023-01-20 11:40:06  1674214806
# 3               3  performance__network  2023-01-20 11:40:06  1674214806
# 4               4  performance__network  2023-01-20 11:40:06  1674214806
# ...           ...                   ...                  ...         ...
# 34660       34660  performance__network  2023-01-20 21:00:55  1674248455
# 34661       34661           $ae_session  2023-01-20 21:02:14  1674248534
# 34662       34662        session__start  2023-01-20 23:40:50  1674258050
# 34663       34663  performance__network  2023-01-20 23:40:51  1674258051
# 34664       34664  performance__network  2023-01-20 23:40:52  1674258052
#
#                                 distinct_id $ae_updated_version  \
# 0                  62091247af9972084d6c3c3c              1.79.2
# 1                  62169902b3fc532d89a663cb              1.79.2
# 2                  62169902b3fc532d89a663cb                 NaN
# 3                  62169902b3fc532d89a663cb                 NaN
# 4                  62169902b3fc532d89a663cb                 NaN
# ...                                     ...                 ...
# 34660              63cb6fea70530cdfd83d72cc                 NaN
# 34661              63cb6fea70530cdfd83d72cc                 NaN
# 34662  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                 NaN
# 34663  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                 NaN
# 34664  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                 NaN
#
#        $app_build_number $app_version_string           $carrier      $city  \
# 0                   6043              1.79.2            Verizon   Kennesaw
# 1                   6043              1.79.2                NaN  Hampshire
# 2                   6043              1.79.2                NaN  Hampshire
# 3                   6043              1.79.2                NaN  Hampshire
# 4                   6043              1.79.2                NaN  Hampshire
# ...                  ...                 ...                ...        ...
# 34660               6043              1.79.2  Ultra/Mint Mobile    Chicago
# 34661               6043              1.79.2  Ultra/Mint Mobile    Chicago
# 34662               6054              1.79.2                NaN      Seoul
# 34663               6054              1.79.2                NaN      Seoul
# 34664               6054              1.79.2                NaN      Seoul
#
#                                  $device_id  $had_persisted_distinct_id  \
# 0      16528B81-05A4-450D-B464-5D8CF5419A1F                        True
# 1      7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17                        True
# 2      7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17                        True
# 3      7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17                        True
# 4      7D6D8FD4-73C1-417E-8FA5-3C3E63C04F17                        True
# ...                                     ...                         ...
# 34660  BF892544-ADAC-489D-A404-8E2FBBFBC526                        True
# 34661  BF892544-ADAC-489D-A404-8E2FBBFBC526                        True
# 34662  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                        True
# 34663  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                        True
# 34664  33E53FFF-CDD3-4200-B629-C62DAFC3A5A3                        True
#
#              $insert_id $lib_version $manufacturer      $model  \
# 0      7366f59bf7f27fe5        3.5.1         Apple  iPhone13,2
# 1      ccb8e7bd625e8e12        3.5.1         Apple  iPhone14,2
# 2      cb9d6dae68e64ae0        3.5.1         Apple  iPhone14,2
# 3      562689d06fa655ca        3.5.1         Apple  iPhone14,2
# 4      82ed5a331de27f22        3.5.1         Apple  iPhone14,2
# ...                 ...          ...           ...         ...
# 34660  c9676d21d29bfb14        3.5.1         Apple  iPhone15,2
# 34661  60536b314ea3fc91        3.5.1         Apple  iPhone15,2
# 34662  681ac9ab48abe399        3.5.1         Apple  iPhone10,1
# 34663  f302a7bcbbeabd11        3.5.1         Apple  iPhone10,1
# 34664  d0d7d521dc4d537c        3.5.1         Apple  iPhone10,1
#
#        $mp_api_endpoint  $mp_api_timestamp_ms  $os $os_version $radio  \
# 0      api.mixpanel.com         1674504732683  iOS        15.3    LTE
# 1      api.mixpanel.com         1674243607716  iOS        16.2  NRNSA
# 2      api.mixpanel.com         1674243607716  iOS        16.2  NRNSA
# 3      api.mixpanel.com         1674243607716  iOS        16.2  NRNSA
# 4      api.mixpanel.com         1674243607716  iOS        16.2  NRNSA
# ...                 ...                   ...  ...         ...    ...
# 34660  api.mixpanel.com         1674277323117  iOS      16.0.1  NRNSA
# 34661  api.mixpanel.com         1674277335526  iOS      16.0.1  NRNSA
# 34662  api.mixpanel.com         1674286911039  iOS        16.2   None
# 34663  api.mixpanel.com         1674286911039  iOS        16.2   None
# 34664  api.mixpanel.com         1674286911039  iOS        16.2   None
#
#         $region  $screen_height  $screen_width                  $user_id  \
# 0       Georgia             844            390  62091247af9972084d6c3c3c
# 1      Illinois             844            390  62169902b3fc532d89a663cb
# 2      Illinois             844            390  62169902b3fc532d89a663cb
# 3      Illinois             844            390  62169902b3fc532d89a663cb
# 4      Illinois             844            390  62169902b3fc532d89a663cb
# ...         ...             ...            ...                       ...
# 34660  Illinois             852            393  63cb6fea70530cdfd83d72cc
# 34661  Illinois             852            393  63cb6fea70530cdfd83d72cc
# 34662     Seoul             667            375                       NaN
# 34663     Seoul             667            375                       NaN
# 34664     Seoul             667            375                       NaN
#
#        $wifi                                  IDFV anon_user  app_build  \
# 0       True  3742F481-284C-4AF7-BF4D-7D4C0A10F394      True     5953.0
# 1        NaN  75823C86-8D89-4098-A32D-F26488CBB029      True     5473.0
# 2        NaN  75823C86-8D89-4098-A32D-F26488CBB029      True     6043.0
# 3      False  75823C86-8D89-4098-A32D-F26488CBB029      True     6043.0
# 4      False  75823C86-8D89-4098-A32D-F26488CBB029      True     6043.0
# ...      ...                                   ...       ...        ...
# 34660   True  1D576117-0564-4B86-AA2E-234246A25365      True     6043.0
# 34661   True  1D576117-0564-4B86-AA2E-234246A25365      True     6043.0
# 34662   True  E3AAE370-9B02-4AE9-A3B8-D0FE7916B69D       NaN     6054.0
# 34663   True  E3AAE370-9B02-4AE9-A3B8-D0FE7916B69D       NaN     6054.0
# 34664   True  E3AAE370-9B02-4AE9-A3B8-D0FE7916B69D       NaN     6054.0
#
#                              app_session_id app_version   env  \
# 0      935EEAE9-9CF7-472B-B820-C439C8572297      1.78.2  prod
# 1      8CC6B7D7-44D6-4DB3-BE79-86671C689802        1.74  prod
# 2      6B91B105-25DB-45BA-B820-1BEEDDFB99F0      1.79.2  prod
# 3      6B91B105-25DB-45BA-B820-1BEEDDFB99F0      1.79.2  prod
# 4      6B91B105-25DB-45BA-B820-1BEEDDFB99F0      1.79.2  prod
# ...                                     ...         ...   ...
# 34660  CEDAC66B-7FCD-48B5-8D08-350963FF3D9F      1.79.2  prod
# 34661  CEDAC66B-7FCD-48B5-8D08-350963FF3D9F      1.79.2  prod
# 34662  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
# 34663  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
# 34664  625BD168-F917-4907-8EDA-89599056EBB0      1.79.2  prod
#
#       location_enabled mp_country_code mp_lib  mp_processing_time_ms  \
# 0                False              US  swift          1674504732943
# 1                False              US  swift          1674243625155
# 2                False              US  swift          1674243625167
# 3                False              US  swift          1674243625167
# 4                False              US  swift          1674243625167
# ...                ...             ...    ...                    ...
# 34660            False              US  swift          1674277323233
# 34661            False              US  swift          1674277338650
# 34662            False              KR  swift          1674286911076
# 34663            False              KR  swift          1674286911076
# 34664            False              KR  swift          1674286911075
#
#                         user_id  user_location_accuracy duration_ms method  \
# 0      62091247af9972084d6c3c3c                    -2.0         NaN    NaN
# 1      62169902b3fc532d89a663cb                    -2.0         NaN    NaN
# 2      62169902b3fc532d89a663cb                    -2.0         NaN    NaN
# 3      62169902b3fc532d89a663cb                    -2.0         530   POST
# 4      62169902b3fc532d89a663cb                    -2.0         580    GET
# ...                         ...                     ...         ...    ...
# 34660  63cb6fea70530cdfd83d72cc                    -2.0        3104    GET
# 34661  63cb6fea70530cdfd83d72cc                    -2.0         NaN    NaN
# 34662                       NaN                    -2.0         NaN    NaN
# 34663                       NaN                    -2.0         448    GET
# 34664                       NaN                    -2.0         527   POST
#
#        response_bytes  status_code                                   url  \
# 0                 NaN          NaN                                   NaN
# 1                 NaN          NaN                                   NaN
# 2                 NaN          NaN                                   NaN
# 3              2144.0        200.0          api.app.flickplay.co/users/*
# 4            267320.0        200.0           api.app.flickplay.co/config
# ...               ...          ...                                   ...
# 34660       1060351.0        200.0  api.app.flickplay.co/flicks/storesV2
# 34661             NaN          NaN                                   NaN
# 34662             NaN          NaN                                   NaN
# 34663        268193.0        200.0           api.app.flickplay.co/config
# 34664        188568.0        200.0   api.app.flickplay.co/auth/anonymous
#
#       feature_session_id feature_session_type feature_source_page  tab  count  \
# 0                    NaN                  NaN                 NaN  NaN    NaN
# 1                    NaN                  NaN                 NaN  NaN    NaN
# 2                    NaN                  NaN                 NaN  NaN    NaN
# 3                    NaN                  NaN                 NaN  NaN    NaN
# 4                    NaN                  NaN                 NaN  NaN    NaN
# ...                  ...                  ...                 ...  ...    ...
# 34660                NaN                  NaN                 NaN  NaN    NaN
# 34661                NaN                  NaN                 NaN  NaN    NaN
# 34662                NaN                  NaN                 NaN  NaN    NaN
# 34663                NaN                  NaN                 NaN  NaN    NaN
# 34664                NaN                  NaN                 NaN  NaN    NaN
#
#       result $ae_first_app_open_date user_gps_location session_id  \
# 0        NaN                     NaN               NaN        NaN
# 1        NaN                     NaN               NaN        NaN
# 2        NaN                     NaN               NaN        NaN
# 3        NaN                     NaN               NaN        NaN
# 4        NaN                     NaN               NaN        NaN
# ...      ...                     ...               ...        ...
# 34660    NaN                     NaN               NaN        NaN
# 34661    NaN                     NaN               NaN        NaN
# 34662    NaN                     NaN               NaN        NaN
# 34663    NaN                     NaN               NaN        NaN
# 34664    NaN                     NaN               NaN        NaN
#
#       session_type  feature_session_length profile_user_id username  \
# 0              NaN                     NaN             NaN      NaN
# 1              NaN                     NaN             NaN      NaN
# 2              NaN                     NaN             NaN      NaN
# 3              NaN                     NaN             NaN      NaN
# 4              NaN                     NaN             NaN      NaN
# ...            ...                     ...             ...      ...
# 34660          NaN                     NaN             NaN      NaN
# 34661          NaN                     NaN             NaN      NaN
# 34662          NaN                     NaN             NaN      NaN
# 34663          NaN                     NaN             NaN      NaN
# 34664          NaN                     NaN             NaN      NaN
#
#       source_page  wallet_count wallet_name  $ae_session_length  \
# 0             NaN           NaN         NaN                 NaN
# 1             NaN           NaN         NaN                 NaN
# 2             NaN           NaN         NaN                 NaN
# 3             NaN           NaN         NaN                 NaN
# 4             NaN           NaN         NaN                 NaN
# ...           ...           ...         ...                 ...
# 34660         NaN           NaN         NaN                 NaN
# 34661         NaN           NaN         NaN                71.7
# 34662         NaN           NaN         NaN                 NaN
# 34663         NaN           NaN         NaN                 NaN
# 34664         NaN           NaN         NaN                 NaN
#
#       session_length error_code if_empty anonymous_user_id type  \
# 0                NaN        NaN      NaN               NaN  NaN
# 1                NaN        NaN      NaN               NaN  NaN
# 2                NaN        NaN      NaN               NaN  NaN
# 3                NaN        NaN      NaN               NaN  NaN
# 4                NaN        NaN      NaN               NaN  NaN
# ...              ...        ...      ...               ...  ...
# 34660            NaN        NaN      NaN               NaN  NaN
# 34661            NaN        NaN      NaN               NaN  NaN
# 34662            NaN        NaN      NaN               NaN  NaN
# 34663            NaN        NaN      NaN               NaN  NaN
# 34664            NaN        NaN      NaN               NaN  NaN
#
#        nft_sync_count wallet_address experience_ids experience_names  \
# 0                 NaN            NaN            NaN              NaN
# 1                 NaN            NaN            NaN              NaN
# 2                 NaN            NaN            NaN              NaN
# 3                 NaN            NaN            NaN              NaN
# 4                 NaN            NaN            NaN              NaN
# ...               ...            ...            ...              ...
# 34660             NaN            NaN            NaN              NaN
# 34661             NaN            NaN            NaN              NaN
# 34662             NaN            NaN            NaN              NaN
# 34663             NaN            NaN            NaN              NaN
# 34664             NaN            NaN            NaN              NaN
#
#       location_id location_name session sub_session video_id video_type  \
# 0             NaN           NaN     NaN         NaN      NaN        NaN
# 1             NaN           NaN     NaN         NaN      NaN        NaN
# 2             NaN           NaN     NaN         NaN      NaN        NaN
# 3             NaN           NaN     NaN         NaN      NaN        NaN
# 4             NaN           NaN     NaN         NaN      NaN        NaN
# ...           ...           ...     ...         ...      ...        ...
# 34660         NaN           NaN     NaN         NaN      NaN        NaN
# 34661         NaN           NaN     NaN         NaN      NaN        NaN
# 34662         NaN           NaN     NaN         NaN      NaN        NaN
# 34663         NaN           NaN     NaN         NaN      NaN        NaN
# 34664         NaN           NaN     NaN         NaN      NaN        NaN
#
#       video_user_id  distance_m active avatar_display card_type experience_id  \
# 0               NaN         NaN    NaN            NaN       NaN           NaN
# 1               NaN         NaN    NaN            NaN       NaN           NaN
# 2               NaN         NaN    NaN            NaN       NaN           NaN
# 3               NaN         NaN    NaN            NaN       NaN           NaN
# 4               NaN         NaN    NaN            NaN       NaN           NaN
# ...             ...         ...    ...            ...       ...           ...
# 34660           NaN         NaN    NaN            NaN       NaN           NaN
# 34661           NaN         NaN    NaN            NaN       NaN           NaN
# 34662           NaN         NaN    NaN            NaN       NaN           NaN
# 34663           NaN         NaN    NaN            NaN       NaN           NaN
# 34664           NaN         NaN    NaN            NaN       NaN           NaN
#
#       experience_name experience_state experience_type if_have_stock if_nft  \
# 0                 NaN              NaN             NaN           NaN    NaN
# 1                 NaN              NaN             NaN           NaN    NaN
# 2                 NaN              NaN             NaN           NaN    NaN
# 3                 NaN              NaN             NaN           NaN    NaN
# 4                 NaN              NaN             NaN           NaN    NaN
# ...               ...              ...             ...           ...    ...
# 34660             NaN              NaN             NaN           NaN    NaN
# 34661             NaN              NaN             NaN           NaN    NaN
# 34662             NaN              NaN             NaN           NaN    NaN
# 34663             NaN              NaN             NaN           NaN    NaN
# 34664             NaN              NaN             NaN           NaN    NaN
#
#       if_unlocked experience_tier action  col_position creator_user_id  \
# 0             NaN             NaN    NaN           NaN             NaN
# 1             NaN             NaN    NaN           NaN             NaN
# 2             NaN             NaN    NaN           NaN             NaN
# 3             NaN             NaN    NaN           NaN             NaN
# 4             NaN             NaN    NaN           NaN             NaN
# ...           ...             ...    ...           ...             ...
# 34660         NaN             NaN    NaN           NaN             NaN
# 34661         NaN             NaN    NaN           NaN             NaN
# 34662         NaN             NaN    NaN           NaN             NaN
# 34663         NaN             NaN    NaN           NaN             NaN
# 34664         NaN             NaN    NaN           NaN             NaN
#
#       creator_username  row_position  total_clips  total_video_time_ms  \
# 0                  NaN           NaN          NaN                  NaN
# 1                  NaN           NaN          NaN                  NaN
# 2                  NaN           NaN          NaN                  NaN
# 3                  NaN           NaN          NaN                  NaN
# 4                  NaN           NaN          NaN                  NaN
# 1                NaN              NaN       NaN          NaN             NaN
# 2                NaN              NaN       NaN          NaN             NaN
# 3                NaN              NaN       NaN          NaN             NaN
# 4                NaN              NaN       NaN          NaN             NaN
# ...              ...              ...       ...          ...             ...
# 34660            NaN              NaN       NaN          NaN             NaN
# 34661            NaN              NaN       NaN          NaN             NaN
# 34662            NaN              NaN       NaN          NaN             NaN
# 34663            NaN              NaN       NaN          NaN             NaN
# 34664            NaN              NaN       NaN          NaN             NaN
#
#        experience_count  friend_count  hashtag_count save_to_local  \
# 0                   NaN           NaN            NaN           NaN
# 1                   NaN           NaN            NaN           NaN
# 2                   NaN           NaN            NaN           NaN
# 3                   NaN           NaN            NaN           NaN
# 4                   NaN           NaN            NaN           NaN
# ...                 ...           ...            ...           ...
# 34660               NaN           NaN            NaN           NaN
# 34661               NaN           NaN            NaN           NaN
# 34662               NaN           NaN            NaN           NaN
# 34663               NaN           NaN            NaN           NaN
# 34664               NaN           NaN            NaN           NaN
#
#       spot_to_map previous_page coin_id coin_type  entity_id store_id  \
# 0             NaN           NaN     NaN       NaN        NaN      NaN
# 1             NaN           NaN     NaN       NaN        NaN      NaN
# 2             NaN           NaN     NaN       NaN        NaN      NaN
# 3             NaN           NaN     NaN       NaN        NaN      NaN
# 4             NaN           NaN     NaN       NaN        NaN      NaN
# ...           ...           ...     ...       ...        ...      ...
# 34660         NaN           NaN     NaN       NaN        NaN      NaN
# 34661         NaN           NaN     NaN       NaN        NaN      NaN
# 34662         NaN           NaN     NaN       NaN        NaN      NaN
# 34663         NaN           NaN     NaN       NaN        NaN      NaN
# 34664         NaN           NaN     NaN       NaN        NaN      NaN
#
#       store_name poi_type  price_value search_text  start_time_ms trash_type  \
# 0            NaN      NaN          NaN         NaN            NaN        NaN
# 1            NaN      NaN          NaN         NaN            NaN        NaN
# 2            NaN      NaN          NaN         NaN            NaN        NaN
# 3            NaN      NaN          NaN         NaN            NaN        NaN
# 4            NaN      NaN          NaN         NaN            NaN        NaN
# ...          ...      ...          ...         ...            ...        ...
# 34660        NaN      NaN          NaN         NaN            NaN        NaN
# 34661        NaN      NaN          NaN         NaN            NaN        NaN
# 34662        NaN      NaN          NaN         NaN            NaN        NaN
# 34663        NaN      NaN          NaN         NaN            NaN        NaN
# 34664        NaN      NaN          NaN         NaN            NaN        NaN
#
#       music_id text  clip_duration_ms  clip_start_time_ms  reload_amount  \
# 0          NaN  NaN               NaN                 NaN            NaN
# 1          NaN  NaN               NaN                 NaN            NaN
# 2          NaN  NaN               NaN                 NaN            NaN
# 3          NaN  NaN               NaN                 NaN            NaN
# 4          NaN  NaN               NaN                 NaN            NaN
# ...        ...  ...               ...                 ...            ...
# 34660      NaN  NaN               NaN                 NaN            NaN
# 34661      NaN  NaN               NaN                 NaN            NaN
# 34662      NaN  NaN               NaN                 NaN            NaN
# 34663      NaN  NaN               NaN                 NaN            NaN
# 34664      NaN  NaN               NaN                 NaN            NaN
#
#       $ae_iap_name  $ae_iap_price  $ae_iap_quantity share_platform  \
# 0              NaN            NaN               NaN            NaN
# 1              NaN            NaN               NaN            NaN
# 2              NaN            NaN               NaN            NaN
# 3              NaN            NaN               NaN            NaN
# 4              NaN            NaN               NaN            NaN
# ...            ...            ...               ...            ...
# 34660          NaN            NaN               NaN            NaN
# 34661          NaN            NaN               NaN            NaN
# 34662          NaN            NaN               NaN            NaN
# 34663          NaN            NaN               NaN            NaN
# 34664          NaN            NaN               NaN            NaN
#
#       toggle_state  goal_like  position_offset badge_id badge_name  \
# 0              NaN        NaN              NaN      NaN        NaN
# 1              NaN        NaN              NaN      NaN        NaN
# 2              NaN        NaN              NaN      NaN        NaN
# 3              NaN        NaN              NaN      NaN        NaN
# 4              NaN        NaN              NaN      NaN        NaN
# ...            ...        ...              ...      ...        ...
# 34660          NaN        NaN              NaN      NaN        NaN
# 34661          NaN        NaN              NaN      NaN        NaN
# 34662          NaN        NaN              NaN      NaN        NaN
# 34663          NaN        NaN              NaN      NaN        NaN
# 34664          NaN        NaN              NaN      NaN        NaN
#
#                     date.1
# 0      2023-01-20 21:04:53
# 1      2023-01-20 11:40:05
# 2      2023-01-20 11:40:06
# 3      2023-01-20 11:40:06
# 4      2023-01-20 11:40:06
# ...                    ...
# 34660  2023-01-20 21:00:55
# 34661  2023-01-20 21:02:14
# 34662  2023-01-20 23:40:50
# 34663  2023-01-20 23:40:51
# 34664  2023-01-20 23:40:52
#
# [34665 rows x 155 columns]

# %%
# max(bigdf.date)

# %%
bigdf.to_sql('events',
           con,
           if_exists='append',
             index=False)

# %%
import matplotlib.pyplot as plt
from collections import Counter


vals = dict(Counter(bigdf.event).most_common(10))

# plt.rcParams["figure.figsize"] = [20, 7]
# plt.rcParams["figure.autolayout"] = True
plt.xticks(rotation=70)
plt.yscale('log')
plt.title('Frequency of most common user events in November')
# plt.bar(c.keys(), c.values())
plt.bar(vals.keys(), vals.values())
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Questions
#
# * What are the non-web3 user characteristics? What do they do?
# * What are the actual number of daily, weekly, monthly active users?
# * Distinguish web3 power users from non?
# * The popular times of day for use? Use vs time of day?
# * Variance of popularity of features over time (within day, week, month)
# * Video creation broken down by which videos are created with NFTs vs not with NFTs?
# * What predicts dropoff?

# %%
# Out:
# ['profile_video__load_page',
#  'profile_tour__load_page',
#  'profile__load_page',
#  'profile_video__open',
#  'profile__signin_signup',
#  'profile_tour__sub_tab',
#  'profile_draft__open',
#  'profile_video__',
#  'profile_tour__',
#  'profile_edit__invite',
#  'profile_draft__select',
#  'profile_draft__select_check',
#  'profile_draft__select_cancel',
#  'profile_draft__delete',
#  'profile_draft__delete_confirm']

# %%
b = bigdf.loc['2022-02-06']

print(len(b[b['$user_id']=='60d2d9a220ba361847a6f2ed']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '2022-02-06'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_21347/1929214859.py in <module>
# ----> 1 b = bigdf.loc['2022-02-06']
#       2
#       3 print(len(b[b['$user_id']=='60d2d9a220ba361847a6f2ed']))
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '2022-02-06'

# %%
bigdf.groupby('index')
# Out:
# ['2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  ...]

# %%
d = dates[0]
d.isoformat()
# Out:
# '2022-05-23'

# %%
 

odfs = []
    
def main():

#     i_date = datetime.date(2022,1,1)
#     dt = datetime.timedelta(days=15)

#     for i in range(332):
#         new_date = (i_date+dt*i).isoformat()
#         print(f'Doing date: {new_date}.')
#         try:
#             df = get_data_between(start_date=new_date,
#                                   end_date=new_date,
#                                   verbose=1)

#             do_histogram(df)


    i_date = datetime.date(2022,1,1)
    n_days = random.randint(15,16)
    dt = datetime.timedelta(days=n_days)

    for i in range(12):
        print()


        start_date = (i_date + dt*i).isoformat()
        end_date = start_date

        print('Doing:' ,start_date)
        try:
            this_stuff = dict()

            df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)


            devices = dict(Counter(df['$model']).most_common(20))

            n_users_by_device = dict()

            for m in devices.keys():

                dd = df[df['$model'] == m ]
                print(f'''There are {len(set(dd['$user_id'].values))} unique users of device {m} on {start_date}.''')
                n_users_by_device[m] = len(set(dd['$user_id'].values))


            this_stuff['raw'] = df
            this_stuff['devlist'] = devices
            this_stuff['users_by_model'] = n_users_by_device

            print()

            stuff_by_date[start_date] = this_stuff
            # plt.rcParams["figure.figsize"] = [20, 7]
            # plt.rcParams["figure.autolayout"] = True
            plt.xticks(rotation=70)
            plt.yscale('log')
            plt.title(f'Frequency of most common devices on {start_date}.')
            plt.bar(devices.keys(), devices.values())
            plt.show()



            outfile = f'~/Desktop/EVENTS/{new_date}.csv'
            print(f'Saving to {outfile}.')
            df.to_csv(outfile)

            odfs.append(df)
            print(len(odfs), 'many dfs')
            
            stuff_by_date[start_date] = this_stuff

        except:
            log = {}
            log['date'] = start_date
            log['e'] = f'Exception occured trying to fetch {start_date}.'
            log['info'] = str(sys.exc_info())
            print(log)
            continue

    
main()
# Out:
# Doing: 2022-01-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-01&to_date=2022-01-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-01 and 2022-01-01.
# {'date': '2022-01-01', 'e': 'Exception occured trying to fetch 2022-01-01.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c063f8d40>)"}
#
# Doing: 2022-01-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-16&to_date=2022-01-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-16 and 2022-01-16.
# {'date': '2022-01-16', 'e': 'Exception occured trying to fetch 2022-01-16.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c0647e4c0>)"}
#
# Doing: 2022-01-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-31&to_date=2022-01-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-31 and 2022-01-31.
# {'date': '2022-01-31', 'e': 'Exception occured trying to fetch 2022-01-31.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c063f8e40>)"}
#
# Doing: 2022-02-15
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-02-15&to_date=2022-02-15 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1644887464,"distinct_id":"93EF2D5B-B7F7-4391-B25F-3D2CC87B0E7B","$ae_first_app_open_date":"2022-02-15T01:11:04","$app_build_number":"3853","$app_version_
# Response received. Processing events between 2022-02-15 and 2022-02-15.
# 54214 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19199/942482732.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 54214 rows.
# There are 36 unique users of device iPhone12,1 on 2022-02-15.
# There are 36 unique users of device iPhone13,4 on 2022-02-15.
# There are 5 unique users of device iPhone9,1 on 2022-02-15.
# There are 25 unique users of device iPhone13,2 on 2022-02-15.
# There are 20 unique users of device iPhone13,3 on 2022-02-15.
# There are 19 unique users of device iPhone11,8 on 2022-02-15.
# There are 1 unique users of device iPad8,6 on 2022-02-15.
# There are 1 unique users of device x86_64 on 2022-02-15.
# There are 14 unique users of device iPhone12,5 on 2022-02-15.
# There are 15 unique users of device iPhone14,5 on 2022-02-15.
# There are 14 unique users of device iPhone14,2 on 2022-02-15.
# There are 22 unique users of device iPhone14,3 on 2022-02-15.
# There are 8 unique users of device iPhone12,3 on 2022-02-15.
# There are 13 unique users of device iPhone12,8 on 2022-02-15.
# There are 7 unique users of device iPhone11,6 on 2022-02-15.
# There are 5 unique users of device iPhone10,2 on 2022-02-15.
# There are 5 unique users of device iPhone10,1 on 2022-02-15.
# There are 3 unique users of device iPhone10,4 on 2022-02-15.
# There are 3 unique users of device iPhone9,2 on 2022-02-15.
# There are 3 unique users of device iPhone13,1 on 2022-02-15.
#
# {'date': '2022-02-15', 'e': 'Exception occured trying to fetch 2022-02-15.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd029d180>)'}
#
# Doing: 2022-03-02
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-02&to_date=2022-03-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1646188100,"distinct_id":"62153feeae2a90a088ba3794","$ae_updated_version":"1.61.0","$app_build_number":"3923","$app_version_string":"1.61.0","$carrier":"Ver
# Response received. Processing events between 2022-03-02 and 2022-03-02.
# 40648 events received.
# Flattened data has 40648 rows.
# There are 71 unique users of device iPhone12,1 on 2022-03-02.
# There are 61 unique users of device iPhone13,4 on 2022-03-02.
# There are 48 unique users of device iPhone11,8 on 2022-03-02.
# There are 32 unique users of device iPhone12,5 on 2022-03-02.
# There are 55 unique users of device iPhone13,2 on 2022-03-02.
# There are 30 unique users of device iPhone14,5 on 2022-03-02.
# There are 16 unique users of device iPhone10,2 on 2022-03-02.
# There are 39 unique users of device iPhone14,3 on 2022-03-02.
# There are 28 unique users of device iPhone13,3 on 2022-03-02.
# There are 3 unique users of device iPad8,6 on 2022-03-02.
# There are 12 unique users of device iPhone13,1 on 2022-03-02.
# There are 30 unique users of device iPhone12,8 on 2022-03-02.
# There are 16 unique users of device iPhone12,3 on 2022-03-02.
# There are 16 unique users of device iPhone14,2 on 2022-03-02.
# There are 12 unique users of device iPhone10,6 on 2022-03-02.
# There are 4 unique users of device x86_64 on 2022-03-02.
# There are 9 unique users of device iPhone11,2 on 2022-03-02.
# There are 11 unique users of device iPhone11,6 on 2022-03-02.
# There are 2 unique users of device iPhone8,4 on 2022-03-02.
# There are 3 unique users of device iPhone9,1 on 2022-03-02.
#
# {'date': '2022-03-02', 'e': 'Exception occured trying to fetch 2022-03-02.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0566a600>)'}
#
# Doing: 2022-03-17
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-17&to_date=2022-03-17 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1647526785,"distinct_id":"621197eea439dd27c51ca057","$ae_updated_version":"1.62.0","$app_build_number":"3973","$app_version_string":"1.62.0","$carrier":"","
# Response received. Processing events between 2022-03-17 and 2022-03-17.
# 43627 events received.
# Flattened data has 43627 rows.
# There are 50 unique users of device iPhone13,2 on 2022-03-17.
# There are 62 unique users of device iPhone12,1 on 2022-03-17.
# There are 34 unique users of device iPhone13,4 on 2022-03-17.
# There are 9 unique users of device iPhone12,3 on 2022-03-17.
# There are 21 unique users of device iPhone14,3 on 2022-03-17.
# There are 4 unique users of device iPhone11,2 on 2022-03-17.
# There are 28 unique users of device iPhone11,8 on 2022-03-17.
# There are 17 unique users of device iPhone12,5 on 2022-03-17.
# There are 15 unique users of device iPhone13,3 on 2022-03-17.
# There are 10 unique users of device iPhone13,1 on 2022-03-17.
# There are 19 unique users of device iPhone14,5 on 2022-03-17.
# There are 17 unique users of device iPhone12,8 on 2022-03-17.
# There are 3 unique users of device iPhone8,1 on 2022-03-17.
# There are 14 unique users of device iPhone11,6 on 2022-03-17.
# There are 15 unique users of device iPhone14,2 on 2022-03-17.
# There are 8 unique users of device iPhone10,2 on 2022-03-17.
# There are 7 unique users of device iPhone10,6 on 2022-03-17.
# There are 4 unique users of device x86_64 on 2022-03-17.
# There are 2 unique users of device iPhone9,1 on 2022-03-17.
# There are 1 unique users of device iPhone9,4 on 2022-03-17.
#
# {'date': '2022-03-17', 'e': 'Exception occured trying to fetch 2022-03-17.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd044af40>)'}
#
# Doing: 2022-04-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-04-01&to_date=2022-04-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"deeplink__open","properties":{"time":1648822334,"distinct_id":"5ff0b0579c245f7bc7253438","$app_build_number":"4083","$app_version_string":"1.63.0","$carrier":"","$city":"Largo","$device_id":
# Response received. Processing events between 2022-04-01 and 2022-04-01.
# 46780 events received.
# Flattened data has 46780 rows.
# There are 62 unique users of device iPhone12,1 on 2022-04-01.
# There are 32 unique users of device iPhone13,4 on 2022-04-01.
# There are 33 unique users of device iPhone13,3 on 2022-04-01.
# There are 16 unique users of device iPhone14,2 on 2022-04-01.
# There are 18 unique users of device iPhone11,8 on 2022-04-01.
# There are 7 unique users of device x86_64 on 2022-04-01.
# There are 19 unique users of device iPhone14,5 on 2022-04-01.
# There are 4 unique users of device iPhone9,1 on 2022-04-01.
# There are 8 unique users of device iPhone12,8 on 2022-04-01.
# There are 16 unique users of device iPhone14,3 on 2022-04-01.
# There are 15 unique users of device iPhone13,2 on 2022-04-01.
# There are 8 unique users of device iPhone10,6 on 2022-04-01.
# There are 9 unique users of device iPhone12,3 on 2022-04-01.
# There are 9 unique users of device iPhone13,1 on 2022-04-01.
# There are 8 unique users of device iPhone11,6 on 2022-04-01.
# There are 6 unique users of device iPhone10,1 on 2022-04-01.
# There are 7 unique users of device iPhone10,2 on 2022-04-01.
# There are 6 unique users of device iPhone10,3 on 2022-04-01.
# There are 10 unique users of device iPhone12,5 on 2022-04-01.
# There are 3 unique users of device iPhone9,4 on 2022-04-01.
#
# {'date': '2022-04-01', 'e': 'Exception occured trying to fetch 2022-04-01.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd04ff940>)'}
#
# Doing: 2022-04-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-04-16&to_date=2022-04-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"homefeed__tab","properties":{"time":1650135591,"distinct_id":"625b7487baa145b2cec6675c","$app_build_number":"4083","$app_version_string":"1.63.0","$carrier":"","$city":"Buenos Aires","$devic
# Response received. Processing events between 2022-04-16 and 2022-04-16.
# 16288 events received.
# Flattened data has 16288 rows.
# There are 36 unique users of device iPhone12,1 on 2022-04-16.
# There are 5 unique users of device iPhone12,3 on 2022-04-16.
# There are 13 unique users of device iPhone13,4 on 2022-04-16.
# There are 8 unique users of device iPhone11,8 on 2022-04-16.
# There are 8 unique users of device iPhone14,5 on 2022-04-16.
# There are 8 unique users of device iPhone13,2 on 2022-04-16.
# There are 7 unique users of device iPhone13,3 on 2022-04-16.
# There are 9 unique users of device iPhone14,3 on 2022-04-16.
# There are 1 unique users of device iPhone12,5 on 2022-04-16.
# There are 5 unique users of device iPhone14,2 on 2022-04-16.
# There are 3 unique users of device iPhone10,4 on 2022-04-16.
# There are 3 unique users of device iPhone10,2 on 2022-04-16.
# There are 1 unique users of device iPhone11,2 on 2022-04-16.
# There are 1 unique users of device iPad12,1 on 2022-04-16.
# There are 3 unique users of device iPhone10,1 on 2022-04-16.
# There are 3 unique users of device iPhone13,1 on 2022-04-16.
# There are 2 unique users of device iPad13,1 on 2022-04-16.
# There are 2 unique users of device iPhone10,3 on 2022-04-16.
# There are 3 unique users of device iPhone12,8 on 2022-04-16.
# There are 2 unique users of device iPad8,1 on 2022-04-16.
#
# {'date': '2022-04-16', 'e': 'Exception occured trying to fetch 2022-04-16.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c06e03f00>)'}
#
# Doing: 2022-05-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-01&to_date=2022-05-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"homefeed__tab","properties":{"time":1651417018,"distinct_id":"626f02285a00c94e675a9aa6","$app_build_number":"4333","$app_version_string":"1.66.0","$carrier":"CMHK","$city":"Los Angeles","$de
# Response received. Processing events between 2022-05-01 and 2022-05-01.
# 23369 events received.
# Flattened data has 23369 rows.
# There are 32 unique users of device iPhone12,1 on 2022-05-01.
# There are 8 unique users of device iPhone14,3 on 2022-05-01.
# There are 10 unique users of device iPhone11,8 on 2022-05-01.
# There are 14 unique users of device iPhone13,4 on 2022-05-01.
# There are 2 unique users of device iPhone10,5 on 2022-05-01.
# There are 4 unique users of device iPhone9,3 on 2022-05-01.
# There are 7 unique users of device iPhone14,5 on 2022-05-01.
# There are 9 unique users of device iPhone12,5 on 2022-05-01.
# There are 8 unique users of device iPhone12,8 on 2022-05-01.
# There are 14 unique users of device iPhone13,3 on 2022-05-01.
# There are 4 unique users of device iPhone10,6 on 2022-05-01.
# There are 3 unique users of device iPhone12,3 on 2022-05-01.
# There are 6 unique users of device iPhone13,2 on 2022-05-01.
# There are 1 unique users of device MacBookPro18,1 on 2022-05-01.
# There are 8 unique users of device iPhone14,2 on 2022-05-01.
# There are 3 unique users of device iPhone11,6 on 2022-05-01.
# There are 4 unique users of device iPhone10,3 on 2022-05-01.
# There are 5 unique users of device iPhone9,4 on 2022-05-01.
# There are 3 unique users of device iPhone11,2 on 2022-05-01.
# There are 2 unique users of device iPhone13,1 on 2022-05-01.
#
# {'date': '2022-05-01', 'e': 'Exception occured trying to fetch 2022-05-01.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd0609cc0>)'}
#
# Doing: 2022-05-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-16&to_date=2022-05-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1652690248,"distinct_id":"6262e84e686adc9a7bbc39f2","$app_build_number":"4383","$app_version_string":"1.67.0","$carrier":"Tele2","$city":"Novosibirsk","$
# Response received. Processing events between 2022-05-16 and 2022-05-16.
# 60217 events received.
# Flattened data has 60217 rows.
# There are 39 unique users of device iPhone13,4 on 2022-05-16.
# There are 11 unique users of device iPhone12,3 on 2022-05-16.
# There are 36 unique users of device iPhone12,1 on 2022-05-16.
# There are 11 unique users of device iPhone14,3 on 2022-05-16.
# There are 13 unique users of device iPhone13,2 on 2022-05-16.
# There are 7 unique users of device iPhone9,1 on 2022-05-16.
# There are 15 unique users of device iPhone13,3 on 2022-05-16.
# There are 8 unique users of device iPhone10,6 on 2022-05-16.
# There are 11 unique users of device iPhone14,5 on 2022-05-16.
# There are 13 unique users of device iPhone11,8 on 2022-05-16.
# There are 11 unique users of device iPhone14,2 on 2022-05-16.
# There are 3 unique users of device MacBookPro18,1 on 2022-05-16.
# There are 6 unique users of device iPhone12,5 on 2022-05-16.
# There are 8 unique users of device iPhone12,8 on 2022-05-16.
# There are 4 unique users of device iPhone10,3 on 2022-05-16.
# There are 7 unique users of device iPhone11,2 on 2022-05-16.
# There are 2 unique users of device iPhone9,3 on 2022-05-16.
# There are 6 unique users of device iPhone11,6 on 2022-05-16.
# There are 3 unique users of device iPhone10,1 on 2022-05-16.
# There are 3 unique users of device iPhone10,4 on 2022-05-16.
#
# {'date': '2022-05-16', 'e': 'Exception occured trying to fetch 2022-05-16.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0703d300>)'}
#
# Doing: 2022-05-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-31&to_date=2022-05-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1653997400,"distinct_id":"6141026b3d174947db3e9398","$app_build_number":"4383","$app_version_string":"1.67.0","$carrier":"","$city":"Hobbs","$device_id":
# Response received. Processing events between 2022-05-31 and 2022-05-31.
# 23550 events received.
# Flattened data has 23550 rows.
# There are 24 unique users of device iPhone12,1 on 2022-05-31.
# There are 12 unique users of device iPhone13,4 on 2022-05-31.
# There are 4 unique users of device iPhone9,1 on 2022-05-31.
# There are 6 unique users of device iPhone14,2 on 2022-05-31.
# There are 8 unique users of device iPhone13,3 on 2022-05-31.
# There are 10 unique users of device iPhone13,2 on 2022-05-31.
# There are 7 unique users of device iPhone12,5 on 2022-05-31.
# There are 4 unique users of device MacBookPro18,1 on 2022-05-31.
# There are 12 unique users of device iPhone14,3 on 2022-05-31.
# There are 6 unique users of device iPhone12,8 on 2022-05-31.
# There are 8 unique users of device iPhone11,8 on 2022-05-31.
# There are 4 unique users of device iPhone12,3 on 2022-05-31.
# There are 8 unique users of device iPhone14,5 on 2022-05-31.
# There are 3 unique users of device iPhone10,3 on 2022-05-31.
# There are 2 unique users of device iPad13,16 on 2022-05-31.
# There are 2 unique users of device iPhone10,2 on 2022-05-31.
# There are 2 unique users of device iPhone14,4 on 2022-05-31.
# There are 2 unique users of device iPhone9,2 on 2022-05-31.
# There are 2 unique users of device iPhone9,3 on 2022-05-31.
# There are 2 unique users of device iPhone8,2 on 2022-05-31.
#
# {'date': '2022-05-31', 'e': 'Exception occured trying to fetch 2022-05-31.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd06d3e00>)'}
#
# Doing: 2022-06-15
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-06-15&to_date=2022-06-15 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1655286965,"distinct_id":"6276e2c70cb135cb2d0bdcb9","$app_build_number":"4693","$app_version_string":"1.69.1","$carrier":"Mobile TeleSystems","$city":"Kr
# Response received. Processing events between 2022-06-15 and 2022-06-15.
# 99198 events received.
# Flattened data has 99198 rows.
# There are 42 unique users of device iPhone14,3 on 2022-06-15.
# There are 27 unique users of device iPhone11,8 on 2022-06-15.
# There are 17 unique users of device iPhone12,3 on 2022-06-15.
# There are 64 unique users of device iPhone12,1 on 2022-06-15.
# There are 24 unique users of device iPhone13,2 on 2022-06-15.
# There are 34 unique users of device iPhone13,4 on 2022-06-15.
# There are 27 unique users of device iPhone14,5 on 2022-06-15.
# There are 14 unique users of device iPhone13,1 on 2022-06-15.
# There are 30 unique users of device iPhone14,2 on 2022-06-15.
# There are 25 unique users of device iPhone13,3 on 2022-06-15.
# There are 33 unique users of device iPhone12,8 on 2022-06-15.
# There are 11 unique users of device iPhone10,6 on 2022-06-15.
# There are 5 unique users of device iPhone8,1 on 2022-06-15.
# There are 19 unique users of device iPhone12,5 on 2022-06-15.
# There are 7 unique users of device iPhone9,3 on 2022-06-15.
# There are 6 unique users of device iPhone14,4 on 2022-06-15.
# There are 1 unique users of device iPhone8,4 on 2022-06-15.
# There are 9 unique users of device iPhone10,5 on 2022-06-15.
# There are 7 unique users of device iPhone10,4 on 2022-06-15.
# There are 10 unique users of device iPhone11,2 on 2022-06-15.
#
# {'date': '2022-06-15', 'e': 'Exception occured trying to fetch 2022-06-15.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0748bf40>)'}

# %%
from pymongo import MongoClient
import pandas as pd




print('Loading secrets ... ')
from secrets import secrets
u = secrets.get('mongo').get('user')
p = secrets.get('mongo').get('password')

con_string = f'mongodb+srv://{u}:{p}@main-4-4.rph7u.mongodb.net/'


# targetdb = 'flickplay-development'
targetdb = 'flickplay-production'

print(f'Connecting to {targetdb}...')
client = MongoClient(con_string)
db = client[targetdb]
print('Connected!')


db.users.find_one({'username': 'allenn'})

# %%
stuff_by_date = dict()


start_date = datetime.date(2022,2,1).isoformat()
end_date = start_date

this_stuff = dict()

df = get_data_between(start_date=start_date, 
                  end_date=end_date,
                  verbose=1)


devices = dict(Counter(df['$model']).most_common(20))

n_users_by_device = dict()

for m in devices.keys()

    dd = df[df['$model'] == m ]
    print(f'''There are {len(set(dd['$user_id'].values))} unique users of device {m} on {start_date}.''')
    n_users_by_device[m] = len(set(dd['$user_id'].values))
    

this_stuff['raw'] = df
this_stuff['devlist'] = devices
this_stuff['users_by_model'] = n_users_by_device

print()

stuff_by_date[start_date] = this_stuff
# Out:
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-11-01&to_date=2022-11-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1667295103,"distinct_id":"2E802B65-580E-4937-A5FD-100783999DBA","$ae_first_app_open_date":"2022-11-01T09:31:43","$app_build_number":"5611","$app_version_
# Response received. Processing events between 2022-11-01 and 2022-11-01.
# 38504 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19199/942482732.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 38504 rows.

# %%
# Out:
# there are 24 unique users of device iPhone15,2
# there are 16 unique users of device iPhone12,3
# there are 8 unique users of device iPhone11,8
# there are 13 unique users of device iPhone13,4
# there are 10 unique users of device iPhone14,4
# there are 3 unique users of device iPhone10,3
# there are 10 unique users of device iPhone14,3
# there are 7 unique users of device iPhone14,2
# there are 4 unique users of device iPhone12,1
# there are 2 unique users of device iPhone10,5
# there are 3 unique users of device iPhone14,6
# there are 3 unique users of device iPhone14,5
# there are 1 unique users of device iPhone10,6
# there are 1 unique users of device iPhone11,6
# there are 5 unique users of device iPhone12,5
# there are 5 unique users of device iPhone12,8
# there are 6 unique users of device iPhone13,2
# there are 3 unique users of device iPhone13,3
# there are 2 unique users of device iPhone14,7
# there are 1 unique users of device iPhone11,2

# %%
df = get_data_between(start_date='2022-11-01',end_date='2022-11-02')
# Out:
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-11-01&to_date=2022-11-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# Response received. Processing events between 2022-11-01 and 2022-11-02.
# 75296 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19159/309477019.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 75296 rows.

# %%
dict(Counter(df['$model']).most_common(10))
# Out:
# {'iPhone15,2': 14314,
#  'iPhone11,8': 11631,
#  'iPhone12,3': 11379,
#  'iPhone14,4': 7784,
#  'iPhone13,4': 7735,
#  'iPhone14,3': 5128,
#  'iPhone10,3': 3284,
#  'iPhone10,5': 3002,
#  'iPhone12,1': 2851,
#  'iPhone14,2': 2547}

# %%
df['$model
# Out:
# 0       iPhone10,2
# 1       iPhone10,2
# 2       iPhone10,2
# 3       iPhone10,2
# 4       iPhone10,2
#            ...
# 8575    iPhone13,4
# 8576    iPhone13,4
# 8577    iPhone13,4
# 8578    iPhone13,4
# 8579    iPhone13,4
# Name: $model, Length: 8580, dtype: object
