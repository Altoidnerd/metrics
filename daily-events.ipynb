# %%
from collections import Counter
import datetime
import json
import matplotlib.pyplot as plt
from os.path import abspath, isdir, isfile, join
from os import mkdir
import pandas as pd
import requests
import sys

from secrets import secrets

auth = secrets.get('mixpanel').get('auth')

pd.set_option('max_columns', None)
# pd.set_option('display.max_rows', None)


def get_data_between(start_date=None, 
                     end_date=None,
                     verbose=False):

    print('Doing API call to mixpanel.')
    
    if start_date is None or end_date is None:
        start_date = '2022-1-1'
        end_date   = '2022-1-7'
    
    url = f'https://data.mixpanel.com/api/2.0/export?from_date={start_date}&to_date={end_date}'
    headers = {
        "accept": "text/plain",
        "authorization": f"{auth}"
    }
    print(f'Getting {url} with \n{headers}')
    response = requests.get(url, headers=headers)
    
    verbose and print(response.text[:200])
    result = {'events': []}
    events = response.text.strip().split('\n')
    
    # with open('~/Desktop/EVENTS/err.log', 'a') as f:
    #     f.write(str(start_date)+':\n')
    #     f.write(response.text)
    print(f'Response received. Processing events between {start_date} and {end_date}.')
    for event in events:
        result['events'].append(json.loads(event))


    # Flatten all events
    print(f'''{len(result['events'])} events received.''')
    data =  [ _['properties'] for _ in result['events']] 
    df = pd.DataFrame.from_records(data)

    # this df is missing the event names
    # df
    def humanize_timestamp(ts):
        ts = int(ts)
        return datetime.datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')

    # changing unix timestamp to stuff that is useful
    # a human readable date string
    df['date'] = [ humanize_timestamp(ts) for ts in df.time ] 
    # a python datetime format
    df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
    # the event names are here:
    event_names = [ _['event'] for _ in result['events']]
    # reorder the columns
    old_columns = list(df.columns)
    df['event'] = event_names
    newcolumns = ['event', 'date'] + old_columns
    df = df[newcolumns]
    
    print(f'Flattened data has {len(df)} rows.')
    return df


def do_histogram(df,
                 save_as=None):
    
    '''
    If save is None, no plot will be saved;
    else, pass a string and itll save to that path.
    '''
    
    print('Building histogram')
    
    c = dict(Counter(df.event).most_common(20))
    c.pop('performance__network', None)
    fig, ax = plt.subplots(figsize=(20, 7))
    # plt.rcParams["figure.figsize"] = [20, 7]
    # plt.rcParams["figure.autolayout"] = True
    plt.xticks(rotation=70)
    plt.yscale('log')
    plt.title('Frequency of most common user events in November')
    plt.bar(c.keys(), c.values())
    plt.show()
    
    if save_as:
        outfile = join(abspath('img'), save_as)
        if len(outfile.split('.'))>=1:
            astype = outfile.split('.')[-1]
        else:
            astype = 'pdf'
            outfile = outfile+'.pdf'
            
        plt.savefig(outfile,
                    dpi=300,
                    format=astype)
    
    return plt

    
odfs = []
    
def main(outdir='data'):

    i_date = datetime.date(2022,3,13)
    dt = datetime.timedelta(days=1)

    for i in range(332):
        new_date = (i_date+dt*i).isoformat()
        print(f'Doing date: {new_date}.')
        try:
            df = get_data_between(start_date=new_date,
                                  end_date=new_date,
                                  verbose=1)

            do_histogram(df)
            
            if not isdir(outdir):
                if not isdir(abspath(outdir)):
                    print(f'Making {abspath(outdir)}')
                    mkdir(abspath(outdir))
            
            outfile = join(abspath(outdir), f'{new_date}.csv')
            print(f'Saving to {outfile}.') # defaults to ./data/
            df.to_csv(outfile)
            odfs.append(df)
            print(len(odfs), 'many dfs')

        except:
            log = {}
            log['date'] = new_date
            log['e'] = f'Exception occured trying to fetch {new_date}.'
            log['info'] = str(sys.exc_info())
            continue

    
    
# outdir = 'data'
# i_date = datetime.date(2022,4,12)
# dt = datetime.timedelta(days=1)

# # dfs = [] 

# for i in range(300):
#     start_date = (i_date + dt*i).isoformat()
#     end_date = start_date
    
#     print(start_date)
#     try:
#         df = get_data_between(start_date=start_date, 
#                               end_date=end_date,
#                               verbose=1)

#         devices = dict(Counter(df['$model']).most_common(20))
#         devices_users = dict()
#         devices_N_users = dict()

#         outfile = join(abspath(outdir), f'{start_date}.csv')
#         print(f'Saving to {outfile}.') # defaults to ./data/
#         df.to_csv(outfile)
#         odfs.append(df)
#         print(len(odfs), 'many dfs')

#         dfs.append(df)
#         # plt.rcParams["figure.figsize"] = [20, 7]
#         # plt.rcParams["figure.autolayout"] = True
#         plt.xticks(rotation=70)
#         plt.yscale('log')
#         plt.title(f'Frequency of most common devices on {start_date}.')
#         plt.bar(devices.keys(), devices.values())
#         plt.show()
#         print('Number of dfs:',len(dfs))
    
#     except:
#         continue
        
        
# main()
    
#     df = get_data_between(start_date=new_date,
#                           end_date=new_date)

#     do_histogram(df)

#     outfile = f'~/Desktop/EVENTS/{new_date}.csv'
#     print(f'Saving to {outfile}.')
#     df.to_csv(outfile)

dfs = []
    
outdir = 'data'
i_date = datetime.date(2022,12,21)
dt = datetime.timedelta(days=1)

# dfs = [] 

for i in range(15):
    start_date = (i_date + dt*i).isoformat()
    end_date = start_date
    
    if isfile(f'./data/{start_date}.csv'):
        print(f'./data/{start_date}.csv exists; skipping.')
        continue
    
    print(start_date)
    try:
        df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)

        devices = dict(Counter(df['$model']).most_common(20))
        devices_users = dict()
        devices_N_users = dict()

        outfile = join(abspath(outdir), f'{start_date}.csv')
        print(f'Saving to {outfile}.') # defaults to ./data/
        df.to_csv(outfile)
        odfs.append(df)
        print(len(odfs), 'many dfs')

        dfs.append(df)
        # plt.rcParams["figure.figsize"] = [20, 7]
        # plt.rcParams["figure.autolayout"] = True
        plt.xticks(rotation=70)
        plt.yscale('log')
        plt.title(f'Frequency of most common devices on {start_date}.')
        plt.bar(devices.keys(), devices.values())
        plt.show()
        print('Number of dfs:',len(dfs))
    

    except:
        continue
# Out:
# 2022-12-21
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-21&to_date=2022-12-21 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1671640021,"distinct_id":"639378e5e35bc96cb684153e","$app_build_number":"5953","$app_version_string":"1.78.2","$carrier":"Verizon","$device_id":"31DE7476
# Response received. Processing events between 2022-12-21 and 2022-12-21.
# 22442 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_28914/164581566.py:64: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 22442 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-21.csv.
# 1 many dfs
# Number of dfs: 1
# 2022-12-22
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-22&to_date=2022-12-22 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1671694764,"distinct_id":"61cb1d9e09372204c929d9ee","$app_build_number":"5953","$app_version_string":"1.78.2","$carrier":"Personal","$city":"Burzaco","$d
# Response received. Processing events between 2022-12-22 and 2022-12-22.
# 25345 events received.
# Flattened data has 25345 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-22.csv.
# 2 many dfs
# Number of dfs: 2
# 2022-12-23
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-23&to_date=2022-12-23 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1671834695,"distinct_id":"63a69cc72c100307ed6d1536","$app_build_number":"5953","$app_version_string":"1.78.2","$carrier":"","$city":"Seoul","$device_i
# Response received. Processing events between 2022-12-23 and 2022-12-23.
# 24435 events received.
# Flattened data has 24435 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-23.csv.
# 3 many dfs
# Number of dfs: 3
# 2022-12-24
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-24&to_date=2022-12-24 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1671890775,"distinct_id":"63a777d65ea8268b3c5fc169","$app_build_number":"5964","$app_version_string":"1.78.2","$carrier":"Tuenti","$city":"Buenos Aire
# Response received. Processing events between 2022-12-24 and 2022-12-24.
# 13131 events received.
# Flattened data has 13131 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-24.csv.
# 4 many dfs
# Number of dfs: 4
# 2022-12-25
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-25&to_date=2022-12-25 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1671998037,"distinct_id":"636d64c6032346d36fb32c99","$app_build_number":"5854","$app_version_string":"1.78","$carrier":"","$city":"Sydney","$device_id":"
# Response received. Processing events between 2022-12-25 and 2022-12-25.
# 12148 events received.
# Flattened data has 12148 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-25.csv.
# 5 many dfs
# Number of dfs: 5
# 2022-12-26
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-26&to_date=2022-12-26 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1672017019,"distinct_id":"6280c6b32fff973d6ab0fe00","$app_build_number":"5953","$app_version_string":"1.78.2","$carrier":"T-Mobile","$city":"Henderson","
# Response received. Processing events between 2022-12-26 and 2022-12-26.
# 10950 events received.
# Flattened data has 10950 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-26.csv.
# 6 many dfs
# Number of dfs: 6
# 2022-12-27
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-27&to_date=2022-12-27 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1672170245,"distinct_id":"63abbb849a62f206c6b9e312","$app_build_number":"6014","$app_version_string":"1.79","$carrier":"Globe","$city":"Juban","$devic
# Response received. Processing events between 2022-12-27 and 2022-12-27.
# 17213 events received.
# Flattened data has 17213 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-27.csv.
# 7 many dfs
# Number of dfs: 7
# 2022-12-28
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-28&to_date=2022-12-28 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1672223906,"distinct_id":"95FC8011-8002-4771-90FB-94A22D2CA8B7","$ae_first_app_open_date":"2022-12-28T10:38:26","$app_build_number":"5953","$app_version_
# Response received. Processing events between 2022-12-28 and 2022-12-28.
# 21427 events received.
# Flattened data has 21427 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-28.csv.
# 8 many dfs
# Number of dfs: 8
# 2022-12-29
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-29&to_date=2022-12-29 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1672312495,"distinct_id":"AA4D0307-DA95-4D39-9928-7014AEFE1FB2","$ae_updated_version":"1.79","$app_build_number":"6003","$app_version_string":"1.79","$carri
# Response received. Processing events between 2022-12-29 and 2022-12-29.
# 20471 events received.
# Flattened data has 20471 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-29.csv.
# 9 many dfs
# Number of dfs: 9
# 2022-12-30
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-30&to_date=2022-12-30 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1672444363,"distinct_id":"62c789dfff6514c9fc8485a4","$ae_updated_version":"1.79","$app_build_number":"6003","$app_version_string":"1.79","$carrier":"Verizon
# Response received. Processing events between 2022-12-30 and 2022-12-30.
# 23561 events received.
# Flattened data has 23561 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-30.csv.
# 10 many dfs
# Number of dfs: 10
# 2022-12-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-12-31&to_date=2022-12-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1672515271,"distinct_id":"B6F9BC7D-4CCD-4FC3-916A-1A4DFB56B165","$ae_first_app_open_date":"2022-12-31T19:34:31","$app_build_number":"5854","$app_version_
# Response received. Processing events between 2022-12-31 and 2022-12-31.
# 20741 events received.
# Flattened data has 20741 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2022-12-31.csv.
# 11 many dfs
# Number of dfs: 11
# 2023-01-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-01&to_date=2023-01-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1672560226,"distinct_id":"6293081e82c92e0a0ca0fd92","$app_build_number":"6023","$app_version_string":"1.79.1","$carrier":"","$city":"San Antonio","$devic
# Response received. Processing events between 2023-01-01 and 2023-01-01.
# 13914 events received.
# Flattened data has 13914 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2023-01-01.csv.
# 12 many dfs
# Number of dfs: 12
# 2023-01-02
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-02&to_date=2023-01-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"signup__anonymous","properties":{"time":1672663306,"distinct_id":"63b3418a4f3dad1962f6e73e","$app_build_number":"5964","$app_version_string":"1.78.2","$carrier":"","$city":"Seoul","$device_i
# Response received. Processing events between 2023-01-02 and 2023-01-02.
# 20537 events received.
# Flattened data has 20537 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2023-01-02.csv.
# 13 many dfs
# Number of dfs: 13
# 2023-01-03
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-03&to_date=2023-01-03 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1672731921,"distinct_id":"63342897cb986f449326b64e","$app_build_number":"6034","$app_version_string":"1.79.1","$carrier":"中華電信","$city":"Taipei","$device
# Response received. Processing events between 2023-01-03 and 2023-01-03.
# 23658 events received.
# Flattened data has 23658 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2023-01-03.csv.
# 14 many dfs
# Number of dfs: 14
# 2023-01-04
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2023-01-04&to_date=2023-01-04 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"profile__load_page","properties":{"time":1672832288,"distinct_id":"63b5d59fdb39337b726b7e61","$app_build_number":"5714","$app_version_string":"1.77","$carrier":"","$city":"Seoul","$device_id
# Response received. Processing events between 2023-01-04 and 2023-01-04.
# 24573 events received.
# Flattened data has 24573 rows.
# Saving to /Users/allen/Desktop/clo/flickplay/mixpanel-events/data/2023-01-04.csv.
# 15 many dfs
# Number of dfs: 15

# %%
# dfs = []
    
# outdir = 'data'
# i_date = datetime.date(2022,1,1)
# dt = datetime.timedelta(days=1)

# # dfs = [] 

# for i in range(365):
#     start_date = (i_date + dt*i).isoformat()
#     end_date = start_date
    
#     if isfile(f'./data/{start_date}.csv'):
#         print(f'./data/{start_date}.csv exists; skipping.')
#         continue
    
#     print(start_date)
#     try:
#         df = get_data_between(start_date=start_date, 
#                               end_date=end_date,
#                               verbose=1)

#         devices = dict(Counter(df['$model']).most_common(20))
#         devices_users = dict()
#         devices_N_users = dict()

#         outfile = join(abspath(outdir), f'{start_date}.csv')
#         print(f'Saving to {outfile}.') # defaults to ./data/
#         df.to_csv(outfile)
#         odfs.append(df)
#         print(len(odfs), 'many dfs')

#         dfs.append(df)
#         # plt.rcParams["figure.figsize"] = [20, 7]
#         # plt.rcParams["figure.autolayout"] = True
#         plt.xticks(rotation=70)
#         plt.yscale('log')
#         plt.title(f'Frequency of most common devices on {start_date}.')
#         plt.bar(devices.keys(), devices.values())
#         plt.show()
#         print('Number of dfs:',len(dfs))
    

#     except:
#         continue

# %%
import glob
import os


#os.chdir('''/Users/allen/Desktop/mixpanel-events/data''')
os.chdir('data')
dfs = []
infiles = list(sorted(glob.glob('*.csv')))
ifinal = len(infiles)//2
               
for inf in infiles[0:ifinal]:
    dfs.append(pd.read_csv(inf))

    
df = pd.concat(dfs)
# Out:
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (38,67,69,70,71,74,75,77,78,94,96,97,98,99,100,101,104,105,107,112,113,114,117,118,119,121,122,123,125,126,127,128,129,130,131,132,133,134,135,136,139,140,141,142,145,146,147,149,150,151,152,153,154,155) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (26,32,52,67,100,112,116,117,118,123,124,126,127,128,130,131,132,133,134,135,141,143,147,148,149,150,151,153,154,157,158,159) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (26,32,64,65,66,69,70,72,73,74,83,91,92,93,104,105,106,108,109,110,111,112,115,117,120,122,123,124,125,126,127,128,130,131,132,135,136,137) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (73,84,101,117,118,123,130,131,132,133,140,141,142,143,144,145,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (86,90,92,94,119,120,121,122,126,128,129,130,132,133,136,139,140) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6,26,29,32,54,56,59,60,61,90,91,92,101,102,103,105,107,121,122,124,125,126,127,128,130,131,132,133,135,138,139,140,141,144,145,147,148,149,150,151) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (75,76,77,78,83,86,95,97,101,102,106,107,108,110,111,112,122,123,124,125,127,128,129,131,136,137,138,139,140,141,142,147,148,149,150,151,152,153,154,155,156,157,158,159) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5,29,41,43,53,88,89,92,106,118,121,122,123,129,130,133,134,135,136,141,142,149,150,152,154,155,156,157,158,159) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/allen/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5,26,31,38,90,94,97,105,112,115,116,117,118,119,120,126,135,136,137,138,140,141,142,143,144,145,146,147,153,154,155,156,157,158,159,162,163,164,165,167,168,169) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
infiles
# Out:
# ['2022-12-22.csv',
#  '2022-12-23.csv',
#  '2022-12-24.csv',
#  '2022-12-25.csv',
#  '2022-12-26.csv',
#  '2022-12-27.csv',
#  '2022-12-28.csv',
#  '2022-12-29.csv',
#  '2022-12-30.csv',
#  '2022-12-31.csv',
#  '2022-12-session-len.csv']

# %%
import datetime
import pandas as pd
import os
import glob
import warnings
warnings.filterwarnings("ignore")

os.chdir('''/Users/allen/Desktop/clo/flickplay/mixpanel-events/data''')
# os.chdir('''./data''')
infiles = list(sorted(glob.glob('2022*.csv')))
bigdf=pd.DataFrame(columns = [ c for c in pd.read_csv(infiles[0]).columns if c not in ['Unnamed: 0'] ])

for infile in infiles[:20]:
    df = pd.read_csv(infile, low_memory=True)
    df.index=df.date
    df = df.drop(columns = ['Unnamed: 0'])
    print(min(df.index),max(df.index))
    bigdf = pd.concat([bigdf, df])
    print(len(df), len(bigdf))
    
# bigdf.index = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
# bigdf['date'] = bigdf.index.values
bigdf['date'] = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
bigdf
# Out:
# 2022-12-22 00:07:28 2022-12-22 23:59:59
# 25345 25345
# 2022-12-23 00:00:04 2022-12-23 23:36:52
# 24435 49780
# 2022-12-24 00:01:03 2022-12-24 23:51:53
# 13131 62911
# 2022-12-25 00:11:32 2022-12-25 23:49:50
# 12148 75059
# 2022-12-26 00:02:25 2022-12-26 23:49:48
# 10950 86009
# 2022-12-27 00:25:43 2022-12-27 23:54:55
# 17213 103222
# 2022-12-28 01:50:30 2022-12-28 23:59:55
# 21427 124649
# 2022-12-29 00:00:01 2022-12-29 23:36:37
# 20471 145120
# 2022-12-30 00:07:59 2022-12-30 23:54:21
# 23561 168681
# 2022-12-31 00:05:28 2022-12-31 23:56:52
# 20741 189422
#                                            event        date        time  \
# 2022-12-22 07:39:24               session__start  2022-12-22  1671694764
# 2022-12-22 07:39:25               deeplink__open  2022-12-22  1671694765
# 2022-12-22 07:39:25         performance__network  2022-12-22  1671694765
# 2022-12-22 07:39:26         performance__network  2022-12-22  1671694766
# 2022-12-22 07:39:26         performance__network  2022-12-22  1671694766
# ...                                          ...         ...         ...
# 2022-12-31 22:33:23         performance__network  2022-12-31  1672526003
# 2022-12-31 22:33:23         performance__network  2022-12-31  1672526003
# 2022-12-31 22:33:26         performance__network  2022-12-31  1672526006
# 2022-12-31 22:33:26  profile_settings__load_page  2022-12-31  1672526006
# 2022-12-31 22:33:30                  $ae_session  2022-12-31  1672526010
#
#                                   distinct_id $app_build_number  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee              5953
# ...                                       ...               ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:23  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:26  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:26  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:30  62d5044122648df88a71ed06              6023
#
#                     $app_version_string  $carrier    $city  \
# 2022-12-22 07:39:24              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:25              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:25              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:26              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:26              1.78.2  Personal  Burzaco
# ...                                 ...       ...      ...
# 2022-12-31 22:33:23              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:23              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:26              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:26              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:30              1.79.1    Telcel   Juarez
#
#                                                $device_id  \
# 2022-12-22 07:39:24  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:25  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:25  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:26  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:26  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# ...                                                   ...
# 2022-12-31 22:33:23  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:23  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:26  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:26  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:30  838F2D8E-DA73-4B42-B2D6-1A9884041C41
#
#                     $had_persisted_distinct_id        $insert_id $lib_version  \
# 2022-12-22 07:39:24                       True  26d8c9ee2e3084a8        3.5.1
# 2022-12-22 07:39:25                       True  76dcfc654a80d6ad        3.5.1
# 2022-12-22 07:39:25                       True  e77386186104dced        3.5.1
# 2022-12-22 07:39:26                       True  46f282f75d3e321e        3.5.1
# 2022-12-22 07:39:26                       True  0cac86ab3fbe3af0        3.5.1
# ...                                        ...               ...          ...
# 2022-12-31 22:33:23                       True  a4f3ad43c0de4127        3.5.1
# 2022-12-31 22:33:23                       True  957bc1f527e8072c        3.5.1
# 2022-12-31 22:33:26                       True  868ee0f552c00ee4        3.5.1
# 2022-12-31 22:33:26                       True  2dae21a2164d48a2        3.5.1
# 2022-12-31 22:33:30                       True  ca210493f9f647f5        3.5.1
#
#                     $manufacturer      $model  $mp_api_endpoint  \
# 2022-12-22 07:39:24         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:25         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:25         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:26         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:26         Apple  iPhone14,2  api.mixpanel.com
# ...                           ...         ...               ...
# 2022-12-31 22:33:23         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:23         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:26         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:26         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:30         Apple  iPhone12,1  api.mixpanel.com
#
#                     $mp_api_timestamp_ms  $os $os_version $radio  \
# 2022-12-22 07:39:24        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:25        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:25        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:26        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:26        1671723578450  iOS        16.1    LTE
# ...                                  ...  ...         ...    ...
# 2022-12-31 22:33:23        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:23        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:26        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:26        1672554811377  iOS        16.2    LTE
# 2022-12-31 22:33:30        1672554811377  iOS        16.2    LTE
#
#                           $region $screen_height $screen_width  \
# 2022-12-22 07:39:24  Buenos Aires            844           390
# 2022-12-22 07:39:25  Buenos Aires            844           390
# 2022-12-22 07:39:25  Buenos Aires            844           390
# 2022-12-22 07:39:26  Buenos Aires            844           390
# 2022-12-22 07:39:26  Buenos Aires            844           390
# ...                           ...            ...           ...
# 2022-12-31 22:33:23  Quintana Roo            896           414
# 2022-12-31 22:33:23  Quintana Roo            896           414
# 2022-12-31 22:33:26  Quintana Roo            896           414
# 2022-12-31 22:33:26  Quintana Roo            896           414
# 2022-12-31 22:33:30  Quintana Roo            896           414
#
#                                      $user_id $wifi  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee  True
# ...                                       ...   ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:23  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:26  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:26  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:30  62d5044122648df88a71ed06  True
#
#                                                      IDFV anon_user  \
# 2022-12-22 07:39:24  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:25  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:25  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:26  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:26  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# ...                                                   ...       ...
# 2022-12-31 22:33:23  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:23  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:26  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:26  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:30  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
#
#                      app_build                        app_session_id  \
# 2022-12-22 07:39:24     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:25     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:25     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:26     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:26     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# ...                        ...                                   ...
# 2022-12-31 22:33:23     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:23     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:26     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:26     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:30     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
#
#                     app_version   env location_enabled mp_country_code mp_lib  \
# 2022-12-22 07:39:24      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:25      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:25      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:26      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:26      1.78.2  prod            False              AR  swift
# ...                         ...   ...              ...             ...    ...
# 2022-12-31 22:33:23      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:23      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:26      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:26      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:30      1.79.1  prod             True              MX  swift
#
#                     mp_processing_time_ms              user_gps_location  \
# 2022-12-22 07:39:24         1671723578494  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:25         1671723578493  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:25         1671723578494  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:26         1671723578493  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:26         1671723578494  lat: -34.7910; long: -58.3906
# ...                                   ...                            ...
# 2022-12-31 22:33:23         1672554811489   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:23         1672554811487   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:26         1672554811480   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:26         1672554811484   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:30         1672554811477   lat: 21.1489; long: -86.9030
#
#                                       user_id  user_location_accuracy  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee                    -2.0
# ...                                       ...                     ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:23  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:26  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:26  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:30  62d5044122648df88a71ed06                    -2.0
#
#                                                path duration_ms method  \
# 2022-12-22 07:39:24                             NaN         NaN    NaN
# 2022-12-22 07:39:25  video/63a3696cf8b38497fa2bcb39         NaN    NaN
# 2022-12-22 07:39:25                             NaN        1179   POST
# 2022-12-22 07:39:26                             NaN        1918    GET
# 2022-12-22 07:39:26                             NaN        1917    GET
# ...                                             ...         ...    ...
# 2022-12-31 22:33:23                             NaN         153    GET
# 2022-12-31 22:33:23                             NaN        3315    GET
# 2022-12-31 22:33:26                             NaN         918    GET
# 2022-12-31 22:33:26                             NaN      <null>    NaN
# 2022-12-31 22:33:30                             NaN         NaN    NaN
#
#                      response_bytes  status_code  \
# 2022-12-22 07:39:24             NaN          NaN
# 2022-12-22 07:39:25             NaN          NaN
# 2022-12-22 07:39:25          2495.0        200.0
# 2022-12-22 07:39:26        257279.0        200.0
# 2022-12-22 07:39:26          3781.0        200.0
# ...                             ...          ...
# 2022-12-31 22:33:23            58.0        200.0
# 2022-12-31 22:33:23       1058613.0        200.0
# 2022-12-31 22:33:26         84262.0        200.0
# 2022-12-31 22:33:26             NaN          NaN
# 2022-12-31 22:33:30             NaN          NaN
#
#                                                       url feature_source_page  \
# 2022-12-22 07:39:24                                   NaN                 NaN
# 2022-12-22 07:39:25                                   NaN                 NaN
# 2022-12-22 07:39:25          api.app.flickplay.co/users/*                 NaN
# 2022-12-22 07:39:26           api.app.flickplay.co/config                 NaN
# 2022-12-22 07:39:26          api.app.flickplay.co/users/*                 NaN
# ...                                                   ...                 ...
# 2022-12-31 22:33:23      api.app.flickplay.co/spotrequest                 NaN
# 2022-12-31 22:33:23  api.app.flickplay.co/flicks/storesV2                 NaN
# 2022-12-31 22:33:26          api.app.flickplay.co/users/*                 NaN
# 2022-12-31 22:33:26                                   NaN   user_profile_main
# 2022-12-31 22:33:30                                   NaN                 NaN
#
#                     feature_session_id feature_session_type  tab  count  \
# 2022-12-22 07:39:24                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:25                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:25                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:26                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:26                NaN                  NaN  NaN    NaN
# ...                                ...                  ...  ...    ...
# 2022-12-31 22:33:23                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:23                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:26                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:26                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:30                NaN                  NaN  NaN    NaN
#
#                     result           profile_user_id username experience_ids  \
# 2022-12-22 07:39:24    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:25    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:25    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:26    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:26    NaN                       NaN      NaN            NaN
# ...                    ...                       ...      ...            ...
# 2022-12-31 22:33:23    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:23    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:26    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:26    NaN  62d5044122648df88a71ed06      NaN            NaN
# 2022-12-31 22:33:30    NaN                       NaN      NaN            NaN
#
#                     experience_names location_id location_name session  \
# 2022-12-22 07:39:24              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:25              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:25              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:26              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:26              NaN         NaN           NaN     NaN
# ...                              ...         ...           ...     ...
# 2022-12-31 22:33:23              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:23              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:26              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:26              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:30              NaN         NaN           NaN     NaN
#
#                     sub_session video_id video_type video_user_id  \
# 2022-12-22 07:39:24         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:25         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:25         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:26         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:26         NaN      NaN        NaN           NaN
# ...                         ...      ...        ...           ...
# 2022-12-31 22:33:23         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:23         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:26         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:26         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:30         NaN      NaN        NaN           NaN
#
#                      $ae_session_length session_length feature_session_length  \
# 2022-12-22 07:39:24                 NaN            NaN                    NaN
# 2022-12-22 07:39:25                 NaN            NaN                    NaN
# 2022-12-22 07:39:25                 NaN            NaN                    NaN
# 2022-12-22 07:39:26                 NaN            NaN                    NaN
# 2022-12-22 07:39:26                 NaN            NaN                    NaN
# ...                                 ...            ...                    ...
# 2022-12-31 22:33:23                 NaN            NaN                    NaN
# 2022-12-31 22:33:23                 NaN            NaN                    NaN
# 2022-12-31 22:33:26                 NaN            NaN                    NaN
# 2022-12-31 22:33:26                 NaN            NaN                    NaN
# 2022-12-31 22:33:30               114.6            NaN                    NaN
#
#                     session_id session_type source_page if_empty  \
# 2022-12-22 07:39:24        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:25        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:25        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:26        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:26        NaN          NaN         NaN      NaN
# ...                        ...          ...         ...      ...
# 2022-12-31 22:33:23        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:23        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:26        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:26        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:30        NaN          NaN         NaN      NaN
#
#                      wallet_count wallet_name anonymous_user_id type  \
# 2022-12-22 07:39:24           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:25           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:25           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:26           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:26           NaN         NaN               NaN  NaN
# ...                           ...         ...               ...  ...
# 2022-12-31 22:33:23           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:23           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:26           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:26           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:30           NaN         NaN               NaN  NaN
#
#                     $ae_first_app_open_date  nft_sync_count wallet_address  \
# 2022-12-22 07:39:24                     NaN             NaN            NaN
# 2022-12-22 07:39:25                     NaN             NaN            NaN
# 2022-12-22 07:39:25                     NaN             NaN            NaN
# 2022-12-22 07:39:26                     NaN             NaN            NaN
# 2022-12-22 07:39:26                     NaN             NaN            NaN
# ...                                     ...             ...            ...
# 2022-12-31 22:33:23                     NaN             NaN            NaN
# 2022-12-31 22:33:23                     NaN             NaN            NaN
# 2022-12-31 22:33:26                     NaN             NaN            NaN
# 2022-12-31 22:33:26                     NaN             NaN            NaN
# 2022-12-31 22:33:30                     NaN             NaN            NaN
#
#                     error_code  col_position creator_user_id creator_username  \
# 2022-12-22 07:39:24        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:25        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:25        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:26        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:26        NaN           NaN             NaN              NaN
# ...                        ...           ...             ...              ...
# 2022-12-31 22:33:23        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:23        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:26        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:26        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:30        NaN           NaN             NaN              NaN
#
#                      row_position  distance_m active avatar_display card_type  \
# 2022-12-22 07:39:24           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:25           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:25           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:26           NaN         NaN    NaN            NaN       NaN
# ...                           ...         ...    ...            ...       ...
# 2022-12-31 22:33:23           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:23           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:30           NaN         NaN    NaN            NaN       NaN
#
#                     experience_id experience_name experience_state  \
# 2022-12-22 07:39:24           NaN             NaN              NaN
# 2022-12-22 07:39:25           NaN             NaN              NaN
# 2022-12-22 07:39:25           NaN             NaN              NaN
# 2022-12-22 07:39:26           NaN             NaN              NaN
# 2022-12-22 07:39:26           NaN             NaN              NaN
# ...                           ...             ...              ...
# 2022-12-31 22:33:23           NaN             NaN              NaN
# 2022-12-31 22:33:23           NaN             NaN              NaN
# 2022-12-31 22:33:26           NaN             NaN              NaN
# 2022-12-31 22:33:26           NaN             NaN              NaN
# 2022-12-31 22:33:30           NaN             NaN              NaN
#
#                     experience_type if_have_stock if_nft if_unlocked  \
# 2022-12-22 07:39:24             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:25             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:25             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:26             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:26             NaN           NaN    NaN         NaN
# ...                             ...           ...    ...         ...
# 2022-12-31 22:33:23             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:23             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:26             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:26             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:30             NaN           NaN    NaN         NaN
#
#                     experience_tier  goal_like  position $ae_updated_version  \
# 2022-12-22 07:39:24             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:25             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:25             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:26             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:26             NaN        NaN       NaN                 NaN
# ...                             ...        ...       ...                 ...
# 2022-12-31 22:33:23             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:23             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:26             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:26             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:30             NaN        NaN       NaN                 NaN
#
#                     action invited_by source source_id share_platform  \
# 2022-12-22 07:39:24    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:25    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:25    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:26    NaN        NaN    NaN       NaN            NaN
# ...                    ...        ...    ...       ...            ...
# 2022-12-31 22:33:23    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:23    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:30    NaN        NaN    NaN       NaN            NaN
#
#                     category_id category_name  total_clips  \
# 2022-12-22 07:39:24         NaN           NaN          NaN
# 2022-12-22 07:39:25         NaN           NaN          NaN
# 2022-12-22 07:39:25         NaN           NaN          NaN
# 2022-12-22 07:39:26         NaN           NaN          NaN
# 2022-12-22 07:39:26         NaN           NaN          NaN
# ...                         ...           ...          ...
# 2022-12-31 22:33:23         NaN           NaN          NaN
# 2022-12-31 22:33:23         NaN           NaN          NaN
# 2022-12-31 22:33:26         NaN           NaN          NaN
# 2022-12-31 22:33:26         NaN           NaN          NaN
# 2022-12-31 22:33:30         NaN           NaN          NaN
#
#                      total_video_time_ms filter_id button_state  \
# 2022-12-22 07:39:24                  NaN       NaN          NaN
# 2022-12-22 07:39:25                  NaN       NaN          NaN
# 2022-12-22 07:39:25                  NaN       NaN          NaN
# 2022-12-22 07:39:26                  NaN       NaN          NaN
# 2022-12-22 07:39:26                  NaN       NaN          NaN
# ...                                  ...       ...          ...
# 2022-12-31 22:33:23                  NaN       NaN          NaN
# 2022-12-31 22:33:23                  NaN       NaN          NaN
# 2022-12-31 22:33:26                  NaN       NaN          NaN
# 2022-12-31 22:33:26                  NaN       NaN          NaN
# 2022-12-31 22:33:30                  NaN       NaN          NaN
#
#                      start_time_ms music_id  caption_length  friend_count  \
# 2022-12-22 07:39:24            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:25            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:25            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:26            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:26            NaN      NaN             NaN           NaN
# ...                            ...      ...             ...           ...
# 2022-12-31 22:33:23            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:23            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:26            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:26            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:30            NaN      NaN             NaN           NaN
#
#                      hashtag_count  experience_count save_to_local  \
# 2022-12-22 07:39:24            NaN               NaN           NaN
# 2022-12-22 07:39:25            NaN               NaN           NaN
# 2022-12-22 07:39:25            NaN               NaN           NaN
# 2022-12-22 07:39:26            NaN               NaN           NaN
# 2022-12-22 07:39:26            NaN               NaN           NaN
# ...                            ...               ...           ...
# 2022-12-31 22:33:23            NaN               NaN           NaN
# 2022-12-31 22:33:23            NaN               NaN           NaN
# 2022-12-31 22:33:26            NaN               NaN           NaN
# 2022-12-31 22:33:26            NaN               NaN           NaN
# 2022-12-31 22:33:30            NaN               NaN           NaN
#
#                     spot_to_map entry_point  col_count  row_count button_type  \
# 2022-12-22 07:39:24         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:25         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:25         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:26         NaN         NaN        NaN        NaN         NaN
# ...                         ...         ...        ...        ...         ...
# 2022-12-31 22:33:23         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:23         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:30         NaN         NaN        NaN        NaN         NaN
#
#                     entry_category_id entry_category_name  tutorial_step  \
# 2022-12-22 07:39:24               NaN                 NaN            NaN
# 2022-12-22 07:39:25               NaN                 NaN            NaN
# 2022-12-22 07:39:25               NaN                 NaN            NaN
# 2022-12-22 07:39:26               NaN                 NaN            NaN
# 2022-12-22 07:39:26               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2022-12-31 22:33:23               NaN                 NaN            NaN
# 2022-12-31 22:33:23               NaN                 NaN            NaN
# 2022-12-31 22:33:26               NaN                 NaN            NaN
# 2022-12-31 22:33:26               NaN                 NaN            NaN
# 2022-12-31 22:33:30               NaN                 NaN            NaN
#
#                     object_placed object_type place_type  clip category_ids  \
# 2022-12-22 07:39:24           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:25           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:25           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:26           NaN         NaN        NaN   NaN          NaN
# ...                           ...         ...        ...   ...          ...
# 2022-12-31 22:33:23           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:23           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:30           NaN         NaN        NaN   NaN          NaN
#
#                     category_names experience_types text toggle_state   id  \
# 2022-12-22 07:39:24            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:25            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:25            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:26            NaN              NaN  NaN          NaN  NaN
# ...                            ...              ...  ...          ...  ...
# 2022-12-31 22:33:23            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:23            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:30            NaN              NaN  NaN          NaN  NaN
#
#                     name previous_page style_id coin_id coin_type trash_type  \
# 2022-12-22 07:39:24  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:25  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:25  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:26  NaN           NaN      NaN     NaN       NaN        NaN
# ...                  ...           ...      ...     ...       ...        ...
# 2022-12-31 22:33:23  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:23  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:30  NaN           NaN      NaN     NaN       NaN        NaN
#
#                      clip_duration_ms  clip_start_time_ms reason option  \
# 2022-12-22 07:39:24               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:25               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:25               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:26               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:26               NaN                 NaN    NaN    NaN
# ...                               ...                 ...    ...    ...
# 2022-12-31 22:33:23               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:23               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:26               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:26               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:30               NaN                 NaN    NaN    NaN
#
#                     platform search_text  position_offset  entity_id store_id  \
# 2022-12-22 07:39:24      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:25      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:25      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:26      NaN         NaN              NaN        NaN      NaN
# ...                      ...         ...              ...        ...      ...
# 2022-12-31 22:33:23      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:23      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:30      NaN         NaN              NaN        NaN      NaN
#
#                     store_name poi_type  price_value property  \
# 2022-12-22 07:39:24        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:25        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:25        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:26        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:26        NaN      NaN          NaN      NaN
# ...                        ...      ...          ...      ...
# 2022-12-31 22:33:23        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:23        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:26        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:26        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:30        NaN      NaN          NaN      NaN
#
#                     property_category reward_id if_nft_reward if_redeemed  \
# 2022-12-22 07:39:24               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:25               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:25               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:26               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:26               NaN       NaN           NaN         NaN
# ...                               ...       ...           ...         ...
# 2022-12-31 22:33:23               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:23               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:26               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:26               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:30               NaN       NaN           NaN         NaN
#
#                     reward_state if_claimed               date.1  \
# 2022-12-22 07:39:24          NaN        NaN  2022-12-22 07:39:24
# 2022-12-22 07:39:25          NaN        NaN  2022-12-22 07:39:25
# 2022-12-22 07:39:25          NaN        NaN  2022-12-22 07:39:25
# 2022-12-22 07:39:26          NaN        NaN  2022-12-22 07:39:26
# 2022-12-22 07:39:26          NaN        NaN  2022-12-22 07:39:26
# ...                          ...        ...                  ...
# 2022-12-31 22:33:23          NaN        NaN  2022-12-31 22:33:23
# 2022-12-31 22:33:23          NaN        NaN  2022-12-31 22:33:23
# 2022-12-31 22:33:26          NaN        NaN  2022-12-31 22:33:26
# 2022-12-31 22:33:26          NaN        NaN  2022-12-31 22:33:26
# 2022-12-31 22:33:30          NaN        NaN  2022-12-31 22:33:30
#
#                     destination_coin_type destination_id destination_name  \
# 2022-12-22 07:39:24                   NaN            NaN              NaN
# 2022-12-22 07:39:25                   NaN            NaN              NaN
# 2022-12-22 07:39:25                   NaN            NaN              NaN
# 2022-12-22 07:39:26                   NaN            NaN              NaN
# 2022-12-22 07:39:26                   NaN            NaN              NaN
# ...                                   ...            ...              ...
# 2022-12-31 22:33:23                   NaN            NaN              NaN
# 2022-12-31 22:33:23                   NaN            NaN              NaN
# 2022-12-31 22:33:26                   NaN            NaN              NaN
# 2022-12-31 22:33:26                   NaN            NaN              NaN
# 2022-12-31 22:33:30                   NaN            NaN              NaN
#
#                     destination_type  navigation_distance_m  \
# 2022-12-22 07:39:24              NaN                    NaN
# 2022-12-22 07:39:25              NaN                    NaN
# 2022-12-22 07:39:25              NaN                    NaN
# 2022-12-22 07:39:26              NaN                    NaN
# 2022-12-22 07:39:26              NaN                    NaN
# ...                              ...                    ...
# 2022-12-31 22:33:23              NaN                    NaN
# 2022-12-31 22:33:23              NaN                    NaN
# 2022-12-31 22:33:26              NaN                    NaN
# 2022-12-31 22:33:26              NaN                    NaN
# 2022-12-31 22:33:30              NaN                    NaN
#
#                      navigation_duration_s  remaining_distance_m  \
# 2022-12-22 07:39:24                    NaN                   NaN
# 2022-12-22 07:39:25                    NaN                   NaN
# 2022-12-22 07:39:25                    NaN                   NaN
# 2022-12-22 07:39:26                    NaN                   NaN
# 2022-12-22 07:39:26                    NaN                   NaN
# ...                                    ...                   ...
# 2022-12-31 22:33:23                    NaN                   NaN
# 2022-12-31 22:33:23                    NaN                   NaN
# 2022-12-31 22:33:26                    NaN                   NaN
# 2022-12-31 22:33:26                    NaN                   NaN
# 2022-12-31 22:33:30                    NaN                   NaN
#
#                      remaining_duration_s  first_open  from_position  \
# 2022-12-22 07:39:24                   NaN         NaN            NaN
# 2022-12-22 07:39:25                   NaN         NaN            NaN
# 2022-12-22 07:39:25                   NaN         NaN            NaN
# 2022-12-22 07:39:26                   NaN         NaN            NaN
# 2022-12-22 07:39:26                   NaN         NaN            NaN
# ...                                   ...         ...            ...
# 2022-12-31 22:33:23                   NaN         NaN            NaN
# 2022-12-31 22:33:23                   NaN         NaN            NaN
# 2022-12-31 22:33:26                   NaN         NaN            NaN
# 2022-12-31 22:33:26                   NaN         NaN            NaN
# 2022-12-31 22:33:30                   NaN         NaN            NaN
#
#                      to_position message target  reload_amount $ae_iap_name  \
# 2022-12-22 07:39:24          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:25          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:25          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:26          NaN     NaN    NaN            NaN          NaN
# ...                          ...     ...    ...            ...          ...
# 2022-12-31 22:33:23          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:23          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:30          NaN     NaN    NaN            NaN          NaN
#
#                      $ae_iap_price  $ae_iap_quantity badge_id badge_name  \
# 2022-12-22 07:39:24            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:25            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:25            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:26            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:26            NaN               NaN      NaN        NaN
# ...                            ...               ...      ...        ...
# 2022-12-31 22:33:23            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:23            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:26            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:26            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:30            NaN               NaN      NaN        NaN
#
#                     location  deeplink_type deeplink_url first_trigger traffic
# 2022-12-22 07:39:24      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:25      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:25      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:26      NaN            NaN          NaN           NaN     NaN
# ...                      ...            ...          ...           ...     ...
# 2022-12-31 22:33:23      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:23      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:30      NaN            NaN          NaN           NaN     NaN
#
# [189422 rows x 180 columns]

# %%
bigdf
# Out:
#                                            event        date        time  \
# 2022-12-22 07:39:24               session__start  2022-12-22  1671694764
# 2022-12-22 07:39:25               deeplink__open  2022-12-22  1671694765
# 2022-12-22 07:39:25         performance__network  2022-12-22  1671694765
# 2022-12-22 07:39:26         performance__network  2022-12-22  1671694766
# 2022-12-22 07:39:26         performance__network  2022-12-22  1671694766
# ...                                          ...         ...         ...
# 2022-12-31 22:33:23         performance__network  2022-12-31  1672526003
# 2022-12-31 22:33:23         performance__network  2022-12-31  1672526003
# 2022-12-31 22:33:26         performance__network  2022-12-31  1672526006
# 2022-12-31 22:33:26  profile_settings__load_page  2022-12-31  1672526006
# 2022-12-31 22:33:30                  $ae_session  2022-12-31  1672526010
#
#                                   distinct_id $app_build_number  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee              5953
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee              5953
# ...                                       ...               ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:23  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:26  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:26  62d5044122648df88a71ed06              6023
# 2022-12-31 22:33:30  62d5044122648df88a71ed06              6023
#
#                     $app_version_string  $carrier    $city  \
# 2022-12-22 07:39:24              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:25              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:25              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:26              1.78.2  Personal  Burzaco
# 2022-12-22 07:39:26              1.78.2  Personal  Burzaco
# ...                                 ...       ...      ...
# 2022-12-31 22:33:23              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:23              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:26              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:26              1.79.1    Telcel   Juarez
# 2022-12-31 22:33:30              1.79.1    Telcel   Juarez
#
#                                                $device_id  \
# 2022-12-22 07:39:24  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:25  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:25  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:26  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# 2022-12-22 07:39:26  CA6C0634-DD89-432B-A9BB-2C9FA159FAD2
# ...                                                   ...
# 2022-12-31 22:33:23  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:23  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:26  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:26  838F2D8E-DA73-4B42-B2D6-1A9884041C41
# 2022-12-31 22:33:30  838F2D8E-DA73-4B42-B2D6-1A9884041C41
#
#                     $had_persisted_distinct_id        $insert_id $lib_version  \
# 2022-12-22 07:39:24                       True  26d8c9ee2e3084a8        3.5.1
# 2022-12-22 07:39:25                       True  76dcfc654a80d6ad        3.5.1
# 2022-12-22 07:39:25                       True  e77386186104dced        3.5.1
# 2022-12-22 07:39:26                       True  46f282f75d3e321e        3.5.1
# 2022-12-22 07:39:26                       True  0cac86ab3fbe3af0        3.5.1
# ...                                        ...               ...          ...
# 2022-12-31 22:33:23                       True  a4f3ad43c0de4127        3.5.1
# 2022-12-31 22:33:23                       True  957bc1f527e8072c        3.5.1
# 2022-12-31 22:33:26                       True  868ee0f552c00ee4        3.5.1
# 2022-12-31 22:33:26                       True  2dae21a2164d48a2        3.5.1
# 2022-12-31 22:33:30                       True  ca210493f9f647f5        3.5.1
#
#                     $manufacturer      $model  $mp_api_endpoint  \
# 2022-12-22 07:39:24         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:25         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:25         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:26         Apple  iPhone14,2  api.mixpanel.com
# 2022-12-22 07:39:26         Apple  iPhone14,2  api.mixpanel.com
# ...                           ...         ...               ...
# 2022-12-31 22:33:23         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:23         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:26         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:26         Apple  iPhone12,1  api.mixpanel.com
# 2022-12-31 22:33:30         Apple  iPhone12,1  api.mixpanel.com
#
#                     $mp_api_timestamp_ms  $os $os_version $radio  \
# 2022-12-22 07:39:24        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:25        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:25        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:26        1671723578450  iOS        16.1    LTE
# 2022-12-22 07:39:26        1671723578450  iOS        16.1    LTE
# ...                                  ...  ...         ...    ...
# 2022-12-31 22:33:23        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:23        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:26        1672554811376  iOS        16.2    LTE
# 2022-12-31 22:33:26        1672554811377  iOS        16.2    LTE
# 2022-12-31 22:33:30        1672554811377  iOS        16.2    LTE
#
#                           $region $screen_height $screen_width  \
# 2022-12-22 07:39:24  Buenos Aires            844           390
# 2022-12-22 07:39:25  Buenos Aires            844           390
# 2022-12-22 07:39:25  Buenos Aires            844           390
# 2022-12-22 07:39:26  Buenos Aires            844           390
# 2022-12-22 07:39:26  Buenos Aires            844           390
# ...                           ...            ...           ...
# 2022-12-31 22:33:23  Quintana Roo            896           414
# 2022-12-31 22:33:23  Quintana Roo            896           414
# 2022-12-31 22:33:26  Quintana Roo            896           414
# 2022-12-31 22:33:26  Quintana Roo            896           414
# 2022-12-31 22:33:30  Quintana Roo            896           414
#
#                                      $user_id $wifi  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee  True
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee  True
# ...                                       ...   ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:23  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:26  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:26  62d5044122648df88a71ed06  True
# 2022-12-31 22:33:30  62d5044122648df88a71ed06  True
#
#                                                      IDFV anon_user  \
# 2022-12-22 07:39:24  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:25  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:25  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:26  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# 2022-12-22 07:39:26  0D47E479-CC4A-44C9-84D2-4993B4681B9F     False
# ...                                                   ...       ...
# 2022-12-31 22:33:23  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:23  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:26  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:26  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
# 2022-12-31 22:33:30  F896DA0B-F65E-4945-BC9C-92C1E425F3FF     False
#
#                      app_build                        app_session_id  \
# 2022-12-22 07:39:24     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:25     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:25     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:26     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# 2022-12-22 07:39:26     5953.0  0239BAED-1ADA-4453-8317-C163E2170679
# ...                        ...                                   ...
# 2022-12-31 22:33:23     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:23     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:26     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:26     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
# 2022-12-31 22:33:30     6023.0  7EDAF50A-78AB-438E-9210-6A14F236E629
#
#                     app_version   env location_enabled mp_country_code mp_lib  \
# 2022-12-22 07:39:24      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:25      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:25      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:26      1.78.2  prod            False              AR  swift
# 2022-12-22 07:39:26      1.78.2  prod            False              AR  swift
# ...                         ...   ...              ...             ...    ...
# 2022-12-31 22:33:23      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:23      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:26      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:26      1.79.1  prod             True              MX  swift
# 2022-12-31 22:33:30      1.79.1  prod             True              MX  swift
#
#                     mp_processing_time_ms              user_gps_location  \
# 2022-12-22 07:39:24         1671723578494  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:25         1671723578493  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:25         1671723578494  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:26         1671723578493  lat: -34.7910; long: -58.3906
# 2022-12-22 07:39:26         1671723578494  lat: -34.7910; long: -58.3906
# ...                                   ...                            ...
# 2022-12-31 22:33:23         1672554811489   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:23         1672554811487   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:26         1672554811480   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:26         1672554811484   lat: 21.1489; long: -86.9030
# 2022-12-31 22:33:30         1672554811477   lat: 21.1489; long: -86.9030
#
#                                       user_id  user_location_accuracy  \
# 2022-12-22 07:39:24  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:25  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee                    -2.0
# 2022-12-22 07:39:26  61cb1d9e09372204c929d9ee                    -2.0
# ...                                       ...                     ...
# 2022-12-31 22:33:23  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:23  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:26  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:26  62d5044122648df88a71ed06                    -2.0
# 2022-12-31 22:33:30  62d5044122648df88a71ed06                    -2.0
#
#                                                path duration_ms method  \
# 2022-12-22 07:39:24                             NaN         NaN    NaN
# 2022-12-22 07:39:25  video/63a3696cf8b38497fa2bcb39         NaN    NaN
# 2022-12-22 07:39:25                             NaN        1179   POST
# 2022-12-22 07:39:26                             NaN        1918    GET
# 2022-12-22 07:39:26                             NaN        1917    GET
# ...                                             ...         ...    ...
# 2022-12-31 22:33:23                             NaN         153    GET
# 2022-12-31 22:33:23                             NaN        3315    GET
# 2022-12-31 22:33:26                             NaN         918    GET
# 2022-12-31 22:33:26                             NaN      <null>    NaN
# 2022-12-31 22:33:30                             NaN         NaN    NaN
#
#                      response_bytes  status_code  \
# 2022-12-22 07:39:24             NaN          NaN
# 2022-12-22 07:39:25             NaN          NaN
# 2022-12-22 07:39:25          2495.0        200.0
# 2022-12-22 07:39:26        257279.0        200.0
# 2022-12-22 07:39:26          3781.0        200.0
# ...                             ...          ...
# 2022-12-31 22:33:23            58.0        200.0
# 2022-12-31 22:33:23       1058613.0        200.0
# 2022-12-31 22:33:26         84262.0        200.0
# 2022-12-31 22:33:26             NaN          NaN
# 2022-12-31 22:33:30             NaN          NaN
#
#                                                       url feature_source_page  \
# 2022-12-22 07:39:24                                   NaN                 NaN
# 2022-12-22 07:39:25                                   NaN                 NaN
# 2022-12-22 07:39:25          api.app.flickplay.co/users/*                 NaN
# 2022-12-22 07:39:26           api.app.flickplay.co/config                 NaN
# 2022-12-22 07:39:26          api.app.flickplay.co/users/*                 NaN
# ...                                                   ...                 ...
# 2022-12-31 22:33:23      api.app.flickplay.co/spotrequest                 NaN
# 2022-12-31 22:33:23  api.app.flickplay.co/flicks/storesV2                 NaN
# 2022-12-31 22:33:26          api.app.flickplay.co/users/*                 NaN
# 2022-12-31 22:33:26                                   NaN   user_profile_main
# 2022-12-31 22:33:30                                   NaN                 NaN
#
#                     feature_session_id feature_session_type  tab  count  \
# 2022-12-22 07:39:24                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:25                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:25                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:26                NaN                  NaN  NaN    NaN
# 2022-12-22 07:39:26                NaN                  NaN  NaN    NaN
# ...                                ...                  ...  ...    ...
# 2022-12-31 22:33:23                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:23                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:26                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:26                NaN                  NaN  NaN    NaN
# 2022-12-31 22:33:30                NaN                  NaN  NaN    NaN
#
#                     result           profile_user_id username experience_ids  \
# 2022-12-22 07:39:24    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:25    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:25    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:26    NaN                       NaN      NaN            NaN
# 2022-12-22 07:39:26    NaN                       NaN      NaN            NaN
# ...                    ...                       ...      ...            ...
# 2022-12-31 22:33:23    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:23    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:26    NaN                       NaN      NaN            NaN
# 2022-12-31 22:33:26    NaN  62d5044122648df88a71ed06      NaN            NaN
# 2022-12-31 22:33:30    NaN                       NaN      NaN            NaN
#
#                     experience_names location_id location_name session  \
# 2022-12-22 07:39:24              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:25              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:25              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:26              NaN         NaN           NaN     NaN
# 2022-12-22 07:39:26              NaN         NaN           NaN     NaN
# ...                              ...         ...           ...     ...
# 2022-12-31 22:33:23              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:23              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:26              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:26              NaN         NaN           NaN     NaN
# 2022-12-31 22:33:30              NaN         NaN           NaN     NaN
#
#                     sub_session video_id video_type video_user_id  \
# 2022-12-22 07:39:24         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:25         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:25         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:26         NaN      NaN        NaN           NaN
# 2022-12-22 07:39:26         NaN      NaN        NaN           NaN
# ...                         ...      ...        ...           ...
# 2022-12-31 22:33:23         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:23         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:26         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:26         NaN      NaN        NaN           NaN
# 2022-12-31 22:33:30         NaN      NaN        NaN           NaN
#
#                      $ae_session_length session_length feature_session_length  \
# 2022-12-22 07:39:24                 NaN            NaN                    NaN
# 2022-12-22 07:39:25                 NaN            NaN                    NaN
# 2022-12-22 07:39:25                 NaN            NaN                    NaN
# 2022-12-22 07:39:26                 NaN            NaN                    NaN
# 2022-12-22 07:39:26                 NaN            NaN                    NaN
# ...                                 ...            ...                    ...
# 2022-12-31 22:33:23                 NaN            NaN                    NaN
# 2022-12-31 22:33:23                 NaN            NaN                    NaN
# 2022-12-31 22:33:26                 NaN            NaN                    NaN
# 2022-12-31 22:33:26                 NaN            NaN                    NaN
# 2022-12-31 22:33:30               114.6            NaN                    NaN
#
#                     session_id session_type source_page if_empty  \
# 2022-12-22 07:39:24        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:25        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:25        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:26        NaN          NaN         NaN      NaN
# 2022-12-22 07:39:26        NaN          NaN         NaN      NaN
# ...                        ...          ...         ...      ...
# 2022-12-31 22:33:23        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:23        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:26        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:26        NaN          NaN         NaN      NaN
# 2022-12-31 22:33:30        NaN          NaN         NaN      NaN
#
#                      wallet_count wallet_name anonymous_user_id type  \
# 2022-12-22 07:39:24           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:25           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:25           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:26           NaN         NaN               NaN  NaN
# 2022-12-22 07:39:26           NaN         NaN               NaN  NaN
# ...                           ...         ...               ...  ...
# 2022-12-31 22:33:23           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:23           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:26           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:26           NaN         NaN               NaN  NaN
# 2022-12-31 22:33:30           NaN         NaN               NaN  NaN
#
#                     $ae_first_app_open_date  nft_sync_count wallet_address  \
# 2022-12-22 07:39:24                     NaN             NaN            NaN
# 2022-12-22 07:39:25                     NaN             NaN            NaN
# 2022-12-22 07:39:25                     NaN             NaN            NaN
# 2022-12-22 07:39:26                     NaN             NaN            NaN
# 2022-12-22 07:39:26                     NaN             NaN            NaN
# ...                                     ...             ...            ...
# 2022-12-31 22:33:23                     NaN             NaN            NaN
# 2022-12-31 22:33:23                     NaN             NaN            NaN
# 2022-12-31 22:33:26                     NaN             NaN            NaN
# 2022-12-31 22:33:26                     NaN             NaN            NaN
# 2022-12-31 22:33:30                     NaN             NaN            NaN
#
#                     error_code  col_position creator_user_id creator_username  \
# 2022-12-22 07:39:24        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:25        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:25        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:26        NaN           NaN             NaN              NaN
# 2022-12-22 07:39:26        NaN           NaN             NaN              NaN
# ...                        ...           ...             ...              ...
# 2022-12-31 22:33:23        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:23        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:26        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:26        NaN           NaN             NaN              NaN
# 2022-12-31 22:33:30        NaN           NaN             NaN              NaN
#
#                      row_position  distance_m active avatar_display card_type  \
# 2022-12-22 07:39:24           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:25           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:25           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-22 07:39:26           NaN         NaN    NaN            NaN       NaN
# ...                           ...         ...    ...            ...       ...
# 2022-12-31 22:33:23           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:23           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:26           NaN         NaN    NaN            NaN       NaN
# 2022-12-31 22:33:30           NaN         NaN    NaN            NaN       NaN
#
#                     experience_id experience_name experience_state  \
# 2022-12-22 07:39:24           NaN             NaN              NaN
# 2022-12-22 07:39:25           NaN             NaN              NaN
# 2022-12-22 07:39:25           NaN             NaN              NaN
# 2022-12-22 07:39:26           NaN             NaN              NaN
# 2022-12-22 07:39:26           NaN             NaN              NaN
# ...                           ...             ...              ...
# 2022-12-31 22:33:23           NaN             NaN              NaN
# 2022-12-31 22:33:23           NaN             NaN              NaN
# 2022-12-31 22:33:26           NaN             NaN              NaN
# 2022-12-31 22:33:26           NaN             NaN              NaN
# 2022-12-31 22:33:30           NaN             NaN              NaN
#
#                     experience_type if_have_stock if_nft if_unlocked  \
# 2022-12-22 07:39:24             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:25             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:25             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:26             NaN           NaN    NaN         NaN
# 2022-12-22 07:39:26             NaN           NaN    NaN         NaN
# ...                             ...           ...    ...         ...
# 2022-12-31 22:33:23             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:23             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:26             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:26             NaN           NaN    NaN         NaN
# 2022-12-31 22:33:30             NaN           NaN    NaN         NaN
#
#                     experience_tier  goal_like  position $ae_updated_version  \
# 2022-12-22 07:39:24             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:25             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:25             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:26             NaN        NaN       NaN                 NaN
# 2022-12-22 07:39:26             NaN        NaN       NaN                 NaN
# ...                             ...        ...       ...                 ...
# 2022-12-31 22:33:23             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:23             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:26             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:26             NaN        NaN       NaN                 NaN
# 2022-12-31 22:33:30             NaN        NaN       NaN                 NaN
#
#                     action invited_by source source_id share_platform  \
# 2022-12-22 07:39:24    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:25    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:25    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-22 07:39:26    NaN        NaN    NaN       NaN            NaN
# ...                    ...        ...    ...       ...            ...
# 2022-12-31 22:33:23    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:23    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:26    NaN        NaN    NaN       NaN            NaN
# 2022-12-31 22:33:30    NaN        NaN    NaN       NaN            NaN
#
#                     category_id category_name  total_clips  \
# 2022-12-22 07:39:24         NaN           NaN          NaN
# 2022-12-22 07:39:25         NaN           NaN          NaN
# 2022-12-22 07:39:25         NaN           NaN          NaN
# 2022-12-22 07:39:26         NaN           NaN          NaN
# 2022-12-22 07:39:26         NaN           NaN          NaN
# ...                         ...           ...          ...
# 2022-12-31 22:33:23         NaN           NaN          NaN
# 2022-12-31 22:33:23         NaN           NaN          NaN
# 2022-12-31 22:33:26         NaN           NaN          NaN
# 2022-12-31 22:33:26         NaN           NaN          NaN
# 2022-12-31 22:33:30         NaN           NaN          NaN
#
#                      total_video_time_ms filter_id button_state  \
# 2022-12-22 07:39:24                  NaN       NaN          NaN
# 2022-12-22 07:39:25                  NaN       NaN          NaN
# 2022-12-22 07:39:25                  NaN       NaN          NaN
# 2022-12-22 07:39:26                  NaN       NaN          NaN
# 2022-12-22 07:39:26                  NaN       NaN          NaN
# ...                                  ...       ...          ...
# 2022-12-31 22:33:23                  NaN       NaN          NaN
# 2022-12-31 22:33:23                  NaN       NaN          NaN
# 2022-12-31 22:33:26                  NaN       NaN          NaN
# 2022-12-31 22:33:26                  NaN       NaN          NaN
# 2022-12-31 22:33:30                  NaN       NaN          NaN
#
#                      start_time_ms music_id  caption_length  friend_count  \
# 2022-12-22 07:39:24            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:25            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:25            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:26            NaN      NaN             NaN           NaN
# 2022-12-22 07:39:26            NaN      NaN             NaN           NaN
# ...                            ...      ...             ...           ...
# 2022-12-31 22:33:23            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:23            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:26            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:26            NaN      NaN             NaN           NaN
# 2022-12-31 22:33:30            NaN      NaN             NaN           NaN
#
#                      hashtag_count  experience_count save_to_local  \
# 2022-12-22 07:39:24            NaN               NaN           NaN
# 2022-12-22 07:39:25            NaN               NaN           NaN
# 2022-12-22 07:39:25            NaN               NaN           NaN
# 2022-12-22 07:39:26            NaN               NaN           NaN
# 2022-12-22 07:39:26            NaN               NaN           NaN
# ...                            ...               ...           ...
# 2022-12-31 22:33:23            NaN               NaN           NaN
# 2022-12-31 22:33:23            NaN               NaN           NaN
# 2022-12-31 22:33:26            NaN               NaN           NaN
# 2022-12-31 22:33:26            NaN               NaN           NaN
# 2022-12-31 22:33:30            NaN               NaN           NaN
#
#                     spot_to_map entry_point  col_count  row_count button_type  \
# 2022-12-22 07:39:24         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:25         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:25         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-22 07:39:26         NaN         NaN        NaN        NaN         NaN
# ...                         ...         ...        ...        ...         ...
# 2022-12-31 22:33:23         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:23         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:26         NaN         NaN        NaN        NaN         NaN
# 2022-12-31 22:33:30         NaN         NaN        NaN        NaN         NaN
#
#                     entry_category_id entry_category_name  tutorial_step  \
# 2022-12-22 07:39:24               NaN                 NaN            NaN
# 2022-12-22 07:39:25               NaN                 NaN            NaN
# 2022-12-22 07:39:25               NaN                 NaN            NaN
# 2022-12-22 07:39:26               NaN                 NaN            NaN
# 2022-12-22 07:39:26               NaN                 NaN            NaN
# ...                               ...                 ...            ...
# 2022-12-31 22:33:23               NaN                 NaN            NaN
# 2022-12-31 22:33:23               NaN                 NaN            NaN
# 2022-12-31 22:33:26               NaN                 NaN            NaN
# 2022-12-31 22:33:26               NaN                 NaN            NaN
# 2022-12-31 22:33:30               NaN                 NaN            NaN
#
#                     object_placed object_type place_type  clip category_ids  \
# 2022-12-22 07:39:24           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:25           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:25           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-22 07:39:26           NaN         NaN        NaN   NaN          NaN
# ...                           ...         ...        ...   ...          ...
# 2022-12-31 22:33:23           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:23           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:26           NaN         NaN        NaN   NaN          NaN
# 2022-12-31 22:33:30           NaN         NaN        NaN   NaN          NaN
#
#                     category_names experience_types text toggle_state   id  \
# 2022-12-22 07:39:24            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:25            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:25            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-22 07:39:26            NaN              NaN  NaN          NaN  NaN
# ...                            ...              ...  ...          ...  ...
# 2022-12-31 22:33:23            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:23            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:26            NaN              NaN  NaN          NaN  NaN
# 2022-12-31 22:33:30            NaN              NaN  NaN          NaN  NaN
#
#                     name previous_page style_id coin_id coin_type trash_type  \
# 2022-12-22 07:39:24  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:25  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:25  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-22 07:39:26  NaN           NaN      NaN     NaN       NaN        NaN
# ...                  ...           ...      ...     ...       ...        ...
# 2022-12-31 22:33:23  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:23  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:26  NaN           NaN      NaN     NaN       NaN        NaN
# 2022-12-31 22:33:30  NaN           NaN      NaN     NaN       NaN        NaN
#
#                      clip_duration_ms  clip_start_time_ms reason option  \
# 2022-12-22 07:39:24               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:25               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:25               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:26               NaN                 NaN    NaN    NaN
# 2022-12-22 07:39:26               NaN                 NaN    NaN    NaN
# ...                               ...                 ...    ...    ...
# 2022-12-31 22:33:23               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:23               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:26               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:26               NaN                 NaN    NaN    NaN
# 2022-12-31 22:33:30               NaN                 NaN    NaN    NaN
#
#                     platform search_text  position_offset  entity_id store_id  \
# 2022-12-22 07:39:24      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:25      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:25      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-22 07:39:26      NaN         NaN              NaN        NaN      NaN
# ...                      ...         ...              ...        ...      ...
# 2022-12-31 22:33:23      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:23      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:26      NaN         NaN              NaN        NaN      NaN
# 2022-12-31 22:33:30      NaN         NaN              NaN        NaN      NaN
#
#                     store_name poi_type  price_value property  \
# 2022-12-22 07:39:24        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:25        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:25        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:26        NaN      NaN          NaN      NaN
# 2022-12-22 07:39:26        NaN      NaN          NaN      NaN
# ...                        ...      ...          ...      ...
# 2022-12-31 22:33:23        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:23        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:26        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:26        NaN      NaN          NaN      NaN
# 2022-12-31 22:33:30        NaN      NaN          NaN      NaN
#
#                     property_category reward_id if_nft_reward if_redeemed  \
# 2022-12-22 07:39:24               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:25               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:25               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:26               NaN       NaN           NaN         NaN
# 2022-12-22 07:39:26               NaN       NaN           NaN         NaN
# ...                               ...       ...           ...         ...
# 2022-12-31 22:33:23               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:23               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:26               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:26               NaN       NaN           NaN         NaN
# 2022-12-31 22:33:30               NaN       NaN           NaN         NaN
#
#                     reward_state if_claimed               date.1  \
# 2022-12-22 07:39:24          NaN        NaN  2022-12-22 07:39:24
# 2022-12-22 07:39:25          NaN        NaN  2022-12-22 07:39:25
# 2022-12-22 07:39:25          NaN        NaN  2022-12-22 07:39:25
# 2022-12-22 07:39:26          NaN        NaN  2022-12-22 07:39:26
# 2022-12-22 07:39:26          NaN        NaN  2022-12-22 07:39:26
# ...                          ...        ...                  ...
# 2022-12-31 22:33:23          NaN        NaN  2022-12-31 22:33:23
# 2022-12-31 22:33:23          NaN        NaN  2022-12-31 22:33:23
# 2022-12-31 22:33:26          NaN        NaN  2022-12-31 22:33:26
# 2022-12-31 22:33:26          NaN        NaN  2022-12-31 22:33:26
# 2022-12-31 22:33:30          NaN        NaN  2022-12-31 22:33:30
#
#                     destination_coin_type destination_id destination_name  \
# 2022-12-22 07:39:24                   NaN            NaN              NaN
# 2022-12-22 07:39:25                   NaN            NaN              NaN
# 2022-12-22 07:39:25                   NaN            NaN              NaN
# 2022-12-22 07:39:26                   NaN            NaN              NaN
# 2022-12-22 07:39:26                   NaN            NaN              NaN
# ...                                   ...            ...              ...
# 2022-12-31 22:33:23                   NaN            NaN              NaN
# 2022-12-31 22:33:23                   NaN            NaN              NaN
# 2022-12-31 22:33:26                   NaN            NaN              NaN
# 2022-12-31 22:33:26                   NaN            NaN              NaN
# 2022-12-31 22:33:30                   NaN            NaN              NaN
#
#                     destination_type  navigation_distance_m  \
# 2022-12-22 07:39:24              NaN                    NaN
# 2022-12-22 07:39:25              NaN                    NaN
# 2022-12-22 07:39:25              NaN                    NaN
# 2022-12-22 07:39:26              NaN                    NaN
# 2022-12-22 07:39:26              NaN                    NaN
# ...                              ...                    ...
# 2022-12-31 22:33:23              NaN                    NaN
# 2022-12-31 22:33:23              NaN                    NaN
# 2022-12-31 22:33:26              NaN                    NaN
# 2022-12-31 22:33:26              NaN                    NaN
# 2022-12-31 22:33:30              NaN                    NaN
#
#                      navigation_duration_s  remaining_distance_m  \
# 2022-12-22 07:39:24                    NaN                   NaN
# 2022-12-22 07:39:25                    NaN                   NaN
# 2022-12-22 07:39:25                    NaN                   NaN
# 2022-12-22 07:39:26                    NaN                   NaN
# 2022-12-22 07:39:26                    NaN                   NaN
# ...                                    ...                   ...
# 2022-12-31 22:33:23                    NaN                   NaN
# 2022-12-31 22:33:23                    NaN                   NaN
# 2022-12-31 22:33:26                    NaN                   NaN
# 2022-12-31 22:33:26                    NaN                   NaN
# 2022-12-31 22:33:30                    NaN                   NaN
#
#                      remaining_duration_s  first_open  from_position  \
# 2022-12-22 07:39:24                   NaN         NaN            NaN
# 2022-12-22 07:39:25                   NaN         NaN            NaN
# 2022-12-22 07:39:25                   NaN         NaN            NaN
# 2022-12-22 07:39:26                   NaN         NaN            NaN
# 2022-12-22 07:39:26                   NaN         NaN            NaN
# ...                                   ...         ...            ...
# 2022-12-31 22:33:23                   NaN         NaN            NaN
# 2022-12-31 22:33:23                   NaN         NaN            NaN
# 2022-12-31 22:33:26                   NaN         NaN            NaN
# 2022-12-31 22:33:26                   NaN         NaN            NaN
# 2022-12-31 22:33:30                   NaN         NaN            NaN
#
#                      to_position message target  reload_amount $ae_iap_name  \
# 2022-12-22 07:39:24          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:25          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:25          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-22 07:39:26          NaN     NaN    NaN            NaN          NaN
# ...                          ...     ...    ...            ...          ...
# 2022-12-31 22:33:23          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:23          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:26          NaN     NaN    NaN            NaN          NaN
# 2022-12-31 22:33:30          NaN     NaN    NaN            NaN          NaN
#
#                      $ae_iap_price  $ae_iap_quantity badge_id badge_name  \
# 2022-12-22 07:39:24            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:25            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:25            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:26            NaN               NaN      NaN        NaN
# 2022-12-22 07:39:26            NaN               NaN      NaN        NaN
# ...                            ...               ...      ...        ...
# 2022-12-31 22:33:23            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:23            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:26            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:26            NaN               NaN      NaN        NaN
# 2022-12-31 22:33:30            NaN               NaN      NaN        NaN
#
#                     location  deeplink_type deeplink_url first_trigger traffic
# 2022-12-22 07:39:24      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:25      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:25      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-22 07:39:26      NaN            NaN          NaN           NaN     NaN
# ...                      ...            ...          ...           ...     ...
# 2022-12-31 22:33:23      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:23      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:26      NaN            NaN          NaN           NaN     NaN
# 2022-12-31 22:33:30      NaN            NaN          NaN           NaN     NaN
#
# [189422 rows x 180 columns]

# %%
import pandas as pd
import datetime
import glob
import pymysql
from mysql.connector import connect
import os
from sqlalchemy import create_engine


    
data_dir = '/Users/allen/Desktop/clo/flickplay/mixpanel-events/data'

host='localhost'
user='root'
password=''
port=3306
database='fpa'
creds = dict(host=host,user=user,password=password,database=database)

def get_alchemy_con():
    host='localhost'
    user='root'
    password=''
    port=3306
    database='fpa'
    return create_engine(f'mysql+pymysql://{user}:{password}@localhost/{database}')

def get_pymysql_con():
    return pymysql.connect(**creds)

def get_mysql_connector_con():
    return connect(**creds)
# get the superset of column names

def get_all_columns(path_to_csvs='/Users/allen/Desktop/clo/flickplay/mixpanel-events/data/mon'):
    all_columns = set()

    for inf in glob.glob('*.csv'):
        cols = pd.read_csv(inf).columns

        for col in cols:
            all_columns.add(col)

        print('all:',len(all_columns),'these:',len(cols))
    
    to_be_removed = [
        'Unnamed: 0',
        'date.1',
        'path'
    ]

    for colname in to_be_removed:
        all_columns.remove(colname)
        
    return all_columns


con = get_alchemy_con()

# %%
columns = pd.read_sql('SELECT * FROM fpa.events limit 1', con).columns

df1 = pd.DataFrame(columns = columns )

bigdf = pd.concat([df1, bigdf])

bigdf = bigdf[columns]

# %%
# bigdf.to_sql('events',
#            con,
#            if_exists='append',
#              index=False)

# %%
import matplotlib.pyplot as plt
from collections import Counter


vals = dict(Counter(bigdf.event).most_common(10))

# plt.rcParams["figure.figsize"] = [20, 7]
# plt.rcParams["figure.autolayout"] = True
plt.xticks(rotation=70)
plt.yscale('log')
plt.title('Frequency of most common user events in November')
# plt.bar(c.keys(), c.values())
plt.bar(vals.keys(), vals.values())
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Questions
#
# * What are the non-web3 user characteristics? What do they do?
# * What are the actual number of daily, weekly, monthly active users?
# * Distinguish web3 power users from non?
# * The popular times of day for use? Use vs time of day?
# * Variance of popularity of features over time (within day, week, month)
# * Video creation broken down by which videos are created with NFTs vs not with NFTs?
# * What predicts dropoff?

# %%
# Out:
# ['profile_video__load_page',
#  'profile_tour__load_page',
#  'profile__load_page',
#  'profile_video__open',
#  'profile__signin_signup',
#  'profile_tour__sub_tab',
#  'profile_draft__open',
#  'profile_video__',
#  'profile_tour__',
#  'profile_edit__invite',
#  'profile_draft__select',
#  'profile_draft__select_check',
#  'profile_draft__select_cancel',
#  'profile_draft__delete',
#  'profile_draft__delete_confirm']

# %%
b = bigdf.loc['2022-02-06']

print(len(b[b['$user_id']=='60d2d9a220ba361847a6f2ed']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: '2022-02-06'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_21347/1929214859.py in <module>
# ----> 1 b = bigdf.loc['2022-02-06']
#       2
#       3 print(len(b[b['$user_id']=='60d2d9a220ba361847a6f2ed']))
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '2022-02-06'

# %%
bigdf.groupby('index')
# Out:
# ['2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  '2022-05-23',
#  ...]

# %%
d = dates[0]
d.isoformat()
# Out:
# '2022-05-23'

# %%
 

odfs = []
    
def main():

#     i_date = datetime.date(2022,1,1)
#     dt = datetime.timedelta(days=15)

#     for i in range(332):
#         new_date = (i_date+dt*i).isoformat()
#         print(f'Doing date: {new_date}.')
#         try:
#             df = get_data_between(start_date=new_date,
#                                   end_date=new_date,
#                                   verbose=1)

#             do_histogram(df)


    i_date = datetime.date(2022,1,1)
    n_days = random.randint(15,16)
    dt = datetime.timedelta(days=n_days)

    for i in range(12):
        print()


        start_date = (i_date + dt*i).isoformat()
        end_date = start_date

        print('Doing:' ,start_date)
        try:
            this_stuff = dict()

            df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)


            devices = dict(Counter(df['$model']).most_common(20))

            n_users_by_device = dict()

            for m in devices.keys():

                dd = df[df['$model'] == m ]
                print(f'''There are {len(set(dd['$user_id'].values))} unique users of device {m} on {start_date}.''')
                n_users_by_device[m] = len(set(dd['$user_id'].values))


            this_stuff['raw'] = df
            this_stuff['devlist'] = devices
            this_stuff['users_by_model'] = n_users_by_device

            print()

            stuff_by_date[start_date] = this_stuff
            # plt.rcParams["figure.figsize"] = [20, 7]
            # plt.rcParams["figure.autolayout"] = True
            plt.xticks(rotation=70)
            plt.yscale('log')
            plt.title(f'Frequency of most common devices on {start_date}.')
            plt.bar(devices.keys(), devices.values())
            plt.show()



            outfile = f'~/Desktop/EVENTS/{new_date}.csv'
            print(f'Saving to {outfile}.')
            df.to_csv(outfile)

            odfs.append(df)
            print(len(odfs), 'many dfs')
            
            stuff_by_date[start_date] = this_stuff

        except:
            log = {}
            log['date'] = start_date
            log['e'] = f'Exception occured trying to fetch {start_date}.'
            log['info'] = str(sys.exc_info())
            print(log)
            continue

    
main()
# Out:
# Doing: 2022-01-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-01&to_date=2022-01-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-01 and 2022-01-01.
# {'date': '2022-01-01', 'e': 'Exception occured trying to fetch 2022-01-01.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c063f8d40>)"}
#
# Doing: 2022-01-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-16&to_date=2022-01-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-16 and 2022-01-16.
# {'date': '2022-01-16', 'e': 'Exception occured trying to fetch 2022-01-16.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c0647e4c0>)"}
#
# Doing: 2022-01-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-01-31&to_date=2022-01-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
#
# Response received. Processing events between 2022-01-31 and 2022-01-31.
# {'date': '2022-01-31', 'e': 'Exception occured trying to fetch 2022-01-31.', 'info': "(<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)'), <traceback object at 0x7f9c063f8e40>)"}
#
# Doing: 2022-02-15
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-02-15&to_date=2022-02-15 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1644887464,"distinct_id":"93EF2D5B-B7F7-4391-B25F-3D2CC87B0E7B","$ae_first_app_open_date":"2022-02-15T01:11:04","$app_build_number":"3853","$app_version_
# Response received. Processing events between 2022-02-15 and 2022-02-15.
# 54214 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19199/942482732.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 54214 rows.
# There are 36 unique users of device iPhone12,1 on 2022-02-15.
# There are 36 unique users of device iPhone13,4 on 2022-02-15.
# There are 5 unique users of device iPhone9,1 on 2022-02-15.
# There are 25 unique users of device iPhone13,2 on 2022-02-15.
# There are 20 unique users of device iPhone13,3 on 2022-02-15.
# There are 19 unique users of device iPhone11,8 on 2022-02-15.
# There are 1 unique users of device iPad8,6 on 2022-02-15.
# There are 1 unique users of device x86_64 on 2022-02-15.
# There are 14 unique users of device iPhone12,5 on 2022-02-15.
# There are 15 unique users of device iPhone14,5 on 2022-02-15.
# There are 14 unique users of device iPhone14,2 on 2022-02-15.
# There are 22 unique users of device iPhone14,3 on 2022-02-15.
# There are 8 unique users of device iPhone12,3 on 2022-02-15.
# There are 13 unique users of device iPhone12,8 on 2022-02-15.
# There are 7 unique users of device iPhone11,6 on 2022-02-15.
# There are 5 unique users of device iPhone10,2 on 2022-02-15.
# There are 5 unique users of device iPhone10,1 on 2022-02-15.
# There are 3 unique users of device iPhone10,4 on 2022-02-15.
# There are 3 unique users of device iPhone9,2 on 2022-02-15.
# There are 3 unique users of device iPhone13,1 on 2022-02-15.
#
# {'date': '2022-02-15', 'e': 'Exception occured trying to fetch 2022-02-15.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd029d180>)'}
#
# Doing: 2022-03-02
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-02&to_date=2022-03-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1646188100,"distinct_id":"62153feeae2a90a088ba3794","$ae_updated_version":"1.61.0","$app_build_number":"3923","$app_version_string":"1.61.0","$carrier":"Ver
# Response received. Processing events between 2022-03-02 and 2022-03-02.
# 40648 events received.
# Flattened data has 40648 rows.
# There are 71 unique users of device iPhone12,1 on 2022-03-02.
# There are 61 unique users of device iPhone13,4 on 2022-03-02.
# There are 48 unique users of device iPhone11,8 on 2022-03-02.
# There are 32 unique users of device iPhone12,5 on 2022-03-02.
# There are 55 unique users of device iPhone13,2 on 2022-03-02.
# There are 30 unique users of device iPhone14,5 on 2022-03-02.
# There are 16 unique users of device iPhone10,2 on 2022-03-02.
# There are 39 unique users of device iPhone14,3 on 2022-03-02.
# There are 28 unique users of device iPhone13,3 on 2022-03-02.
# There are 3 unique users of device iPad8,6 on 2022-03-02.
# There are 12 unique users of device iPhone13,1 on 2022-03-02.
# There are 30 unique users of device iPhone12,8 on 2022-03-02.
# There are 16 unique users of device iPhone12,3 on 2022-03-02.
# There are 16 unique users of device iPhone14,2 on 2022-03-02.
# There are 12 unique users of device iPhone10,6 on 2022-03-02.
# There are 4 unique users of device x86_64 on 2022-03-02.
# There are 9 unique users of device iPhone11,2 on 2022-03-02.
# There are 11 unique users of device iPhone11,6 on 2022-03-02.
# There are 2 unique users of device iPhone8,4 on 2022-03-02.
# There are 3 unique users of device iPhone9,1 on 2022-03-02.
#
# {'date': '2022-03-02', 'e': 'Exception occured trying to fetch 2022-03-02.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0566a600>)'}
#
# Doing: 2022-03-17
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-17&to_date=2022-03-17 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1647526785,"distinct_id":"621197eea439dd27c51ca057","$ae_updated_version":"1.62.0","$app_build_number":"3973","$app_version_string":"1.62.0","$carrier":"","
# Response received. Processing events between 2022-03-17 and 2022-03-17.
# 43627 events received.
# Flattened data has 43627 rows.
# There are 50 unique users of device iPhone13,2 on 2022-03-17.
# There are 62 unique users of device iPhone12,1 on 2022-03-17.
# There are 34 unique users of device iPhone13,4 on 2022-03-17.
# There are 9 unique users of device iPhone12,3 on 2022-03-17.
# There are 21 unique users of device iPhone14,3 on 2022-03-17.
# There are 4 unique users of device iPhone11,2 on 2022-03-17.
# There are 28 unique users of device iPhone11,8 on 2022-03-17.
# There are 17 unique users of device iPhone12,5 on 2022-03-17.
# There are 15 unique users of device iPhone13,3 on 2022-03-17.
# There are 10 unique users of device iPhone13,1 on 2022-03-17.
# There are 19 unique users of device iPhone14,5 on 2022-03-17.
# There are 17 unique users of device iPhone12,8 on 2022-03-17.
# There are 3 unique users of device iPhone8,1 on 2022-03-17.
# There are 14 unique users of device iPhone11,6 on 2022-03-17.
# There are 15 unique users of device iPhone14,2 on 2022-03-17.
# There are 8 unique users of device iPhone10,2 on 2022-03-17.
# There are 7 unique users of device iPhone10,6 on 2022-03-17.
# There are 4 unique users of device x86_64 on 2022-03-17.
# There are 2 unique users of device iPhone9,1 on 2022-03-17.
# There are 1 unique users of device iPhone9,4 on 2022-03-17.
#
# {'date': '2022-03-17', 'e': 'Exception occured trying to fetch 2022-03-17.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd044af40>)'}
#
# Doing: 2022-04-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-04-01&to_date=2022-04-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"deeplink__open","properties":{"time":1648822334,"distinct_id":"5ff0b0579c245f7bc7253438","$app_build_number":"4083","$app_version_string":"1.63.0","$carrier":"","$city":"Largo","$device_id":
# Response received. Processing events between 2022-04-01 and 2022-04-01.
# 46780 events received.
# Flattened data has 46780 rows.
# There are 62 unique users of device iPhone12,1 on 2022-04-01.
# There are 32 unique users of device iPhone13,4 on 2022-04-01.
# There are 33 unique users of device iPhone13,3 on 2022-04-01.
# There are 16 unique users of device iPhone14,2 on 2022-04-01.
# There are 18 unique users of device iPhone11,8 on 2022-04-01.
# There are 7 unique users of device x86_64 on 2022-04-01.
# There are 19 unique users of device iPhone14,5 on 2022-04-01.
# There are 4 unique users of device iPhone9,1 on 2022-04-01.
# There are 8 unique users of device iPhone12,8 on 2022-04-01.
# There are 16 unique users of device iPhone14,3 on 2022-04-01.
# There are 15 unique users of device iPhone13,2 on 2022-04-01.
# There are 8 unique users of device iPhone10,6 on 2022-04-01.
# There are 9 unique users of device iPhone12,3 on 2022-04-01.
# There are 9 unique users of device iPhone13,1 on 2022-04-01.
# There are 8 unique users of device iPhone11,6 on 2022-04-01.
# There are 6 unique users of device iPhone10,1 on 2022-04-01.
# There are 7 unique users of device iPhone10,2 on 2022-04-01.
# There are 6 unique users of device iPhone10,3 on 2022-04-01.
# There are 10 unique users of device iPhone12,5 on 2022-04-01.
# There are 3 unique users of device iPhone9,4 on 2022-04-01.
#
# {'date': '2022-04-01', 'e': 'Exception occured trying to fetch 2022-04-01.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd04ff940>)'}
#
# Doing: 2022-04-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-04-16&to_date=2022-04-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"homefeed__tab","properties":{"time":1650135591,"distinct_id":"625b7487baa145b2cec6675c","$app_build_number":"4083","$app_version_string":"1.63.0","$carrier":"","$city":"Buenos Aires","$devic
# Response received. Processing events between 2022-04-16 and 2022-04-16.
# 16288 events received.
# Flattened data has 16288 rows.
# There are 36 unique users of device iPhone12,1 on 2022-04-16.
# There are 5 unique users of device iPhone12,3 on 2022-04-16.
# There are 13 unique users of device iPhone13,4 on 2022-04-16.
# There are 8 unique users of device iPhone11,8 on 2022-04-16.
# There are 8 unique users of device iPhone14,5 on 2022-04-16.
# There are 8 unique users of device iPhone13,2 on 2022-04-16.
# There are 7 unique users of device iPhone13,3 on 2022-04-16.
# There are 9 unique users of device iPhone14,3 on 2022-04-16.
# There are 1 unique users of device iPhone12,5 on 2022-04-16.
# There are 5 unique users of device iPhone14,2 on 2022-04-16.
# There are 3 unique users of device iPhone10,4 on 2022-04-16.
# There are 3 unique users of device iPhone10,2 on 2022-04-16.
# There are 1 unique users of device iPhone11,2 on 2022-04-16.
# There are 1 unique users of device iPad12,1 on 2022-04-16.
# There are 3 unique users of device iPhone10,1 on 2022-04-16.
# There are 3 unique users of device iPhone13,1 on 2022-04-16.
# There are 2 unique users of device iPad13,1 on 2022-04-16.
# There are 2 unique users of device iPhone10,3 on 2022-04-16.
# There are 3 unique users of device iPhone12,8 on 2022-04-16.
# There are 2 unique users of device iPad8,1 on 2022-04-16.
#
# {'date': '2022-04-16', 'e': 'Exception occured trying to fetch 2022-04-16.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c06e03f00>)'}
#
# Doing: 2022-05-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-01&to_date=2022-05-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"homefeed__tab","properties":{"time":1651417018,"distinct_id":"626f02285a00c94e675a9aa6","$app_build_number":"4333","$app_version_string":"1.66.0","$carrier":"CMHK","$city":"Los Angeles","$de
# Response received. Processing events between 2022-05-01 and 2022-05-01.
# 23369 events received.
# Flattened data has 23369 rows.
# There are 32 unique users of device iPhone12,1 on 2022-05-01.
# There are 8 unique users of device iPhone14,3 on 2022-05-01.
# There are 10 unique users of device iPhone11,8 on 2022-05-01.
# There are 14 unique users of device iPhone13,4 on 2022-05-01.
# There are 2 unique users of device iPhone10,5 on 2022-05-01.
# There are 4 unique users of device iPhone9,3 on 2022-05-01.
# There are 7 unique users of device iPhone14,5 on 2022-05-01.
# There are 9 unique users of device iPhone12,5 on 2022-05-01.
# There are 8 unique users of device iPhone12,8 on 2022-05-01.
# There are 14 unique users of device iPhone13,3 on 2022-05-01.
# There are 4 unique users of device iPhone10,6 on 2022-05-01.
# There are 3 unique users of device iPhone12,3 on 2022-05-01.
# There are 6 unique users of device iPhone13,2 on 2022-05-01.
# There are 1 unique users of device MacBookPro18,1 on 2022-05-01.
# There are 8 unique users of device iPhone14,2 on 2022-05-01.
# There are 3 unique users of device iPhone11,6 on 2022-05-01.
# There are 4 unique users of device iPhone10,3 on 2022-05-01.
# There are 5 unique users of device iPhone9,4 on 2022-05-01.
# There are 3 unique users of device iPhone11,2 on 2022-05-01.
# There are 2 unique users of device iPhone13,1 on 2022-05-01.
#
# {'date': '2022-05-01', 'e': 'Exception occured trying to fetch 2022-05-01.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd0609cc0>)'}
#
# Doing: 2022-05-16
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-16&to_date=2022-05-16 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1652690248,"distinct_id":"6262e84e686adc9a7bbc39f2","$app_build_number":"4383","$app_version_string":"1.67.0","$carrier":"Tele2","$city":"Novosibirsk","$
# Response received. Processing events between 2022-05-16 and 2022-05-16.
# 60217 events received.
# Flattened data has 60217 rows.
# There are 39 unique users of device iPhone13,4 on 2022-05-16.
# There are 11 unique users of device iPhone12,3 on 2022-05-16.
# There are 36 unique users of device iPhone12,1 on 2022-05-16.
# There are 11 unique users of device iPhone14,3 on 2022-05-16.
# There are 13 unique users of device iPhone13,2 on 2022-05-16.
# There are 7 unique users of device iPhone9,1 on 2022-05-16.
# There are 15 unique users of device iPhone13,3 on 2022-05-16.
# There are 8 unique users of device iPhone10,6 on 2022-05-16.
# There are 11 unique users of device iPhone14,5 on 2022-05-16.
# There are 13 unique users of device iPhone11,8 on 2022-05-16.
# There are 11 unique users of device iPhone14,2 on 2022-05-16.
# There are 3 unique users of device MacBookPro18,1 on 2022-05-16.
# There are 6 unique users of device iPhone12,5 on 2022-05-16.
# There are 8 unique users of device iPhone12,8 on 2022-05-16.
# There are 4 unique users of device iPhone10,3 on 2022-05-16.
# There are 7 unique users of device iPhone11,2 on 2022-05-16.
# There are 2 unique users of device iPhone9,3 on 2022-05-16.
# There are 6 unique users of device iPhone11,6 on 2022-05-16.
# There are 3 unique users of device iPhone10,1 on 2022-05-16.
# There are 3 unique users of device iPhone10,4 on 2022-05-16.
#
# {'date': '2022-05-16', 'e': 'Exception occured trying to fetch 2022-05-16.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0703d300>)'}
#
# Doing: 2022-05-31
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-05-31&to_date=2022-05-31 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1653997400,"distinct_id":"6141026b3d174947db3e9398","$app_build_number":"4383","$app_version_string":"1.67.0","$carrier":"","$city":"Hobbs","$device_id":
# Response received. Processing events between 2022-05-31 and 2022-05-31.
# 23550 events received.
# Flattened data has 23550 rows.
# There are 24 unique users of device iPhone12,1 on 2022-05-31.
# There are 12 unique users of device iPhone13,4 on 2022-05-31.
# There are 4 unique users of device iPhone9,1 on 2022-05-31.
# There are 6 unique users of device iPhone14,2 on 2022-05-31.
# There are 8 unique users of device iPhone13,3 on 2022-05-31.
# There are 10 unique users of device iPhone13,2 on 2022-05-31.
# There are 7 unique users of device iPhone12,5 on 2022-05-31.
# There are 4 unique users of device MacBookPro18,1 on 2022-05-31.
# There are 12 unique users of device iPhone14,3 on 2022-05-31.
# There are 6 unique users of device iPhone12,8 on 2022-05-31.
# There are 8 unique users of device iPhone11,8 on 2022-05-31.
# There are 4 unique users of device iPhone12,3 on 2022-05-31.
# There are 8 unique users of device iPhone14,5 on 2022-05-31.
# There are 3 unique users of device iPhone10,3 on 2022-05-31.
# There are 2 unique users of device iPad13,16 on 2022-05-31.
# There are 2 unique users of device iPhone10,2 on 2022-05-31.
# There are 2 unique users of device iPhone14,4 on 2022-05-31.
# There are 2 unique users of device iPhone9,2 on 2022-05-31.
# There are 2 unique users of device iPhone9,3 on 2022-05-31.
# There are 2 unique users of device iPhone8,2 on 2022-05-31.
#
# {'date': '2022-05-31', 'e': 'Exception occured trying to fetch 2022-05-31.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9bd06d3e00>)'}
#
# Doing: 2022-06-15
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-06-15&to_date=2022-06-15 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"session__start","properties":{"time":1655286965,"distinct_id":"6276e2c70cb135cb2d0bdcb9","$app_build_number":"4693","$app_version_string":"1.69.1","$carrier":"Mobile TeleSystems","$city":"Kr
# Response received. Processing events between 2022-06-15 and 2022-06-15.
# 99198 events received.
# Flattened data has 99198 rows.
# There are 42 unique users of device iPhone14,3 on 2022-06-15.
# There are 27 unique users of device iPhone11,8 on 2022-06-15.
# There are 17 unique users of device iPhone12,3 on 2022-06-15.
# There are 64 unique users of device iPhone12,1 on 2022-06-15.
# There are 24 unique users of device iPhone13,2 on 2022-06-15.
# There are 34 unique users of device iPhone13,4 on 2022-06-15.
# There are 27 unique users of device iPhone14,5 on 2022-06-15.
# There are 14 unique users of device iPhone13,1 on 2022-06-15.
# There are 30 unique users of device iPhone14,2 on 2022-06-15.
# There are 25 unique users of device iPhone13,3 on 2022-06-15.
# There are 33 unique users of device iPhone12,8 on 2022-06-15.
# There are 11 unique users of device iPhone10,6 on 2022-06-15.
# There are 5 unique users of device iPhone8,1 on 2022-06-15.
# There are 19 unique users of device iPhone12,5 on 2022-06-15.
# There are 7 unique users of device iPhone9,3 on 2022-06-15.
# There are 6 unique users of device iPhone14,4 on 2022-06-15.
# There are 1 unique users of device iPhone8,4 on 2022-06-15.
# There are 9 unique users of device iPhone10,5 on 2022-06-15.
# There are 7 unique users of device iPhone10,4 on 2022-06-15.
# There are 10 unique users of device iPhone11,2 on 2022-06-15.
#
# {'date': '2022-06-15', 'e': 'Exception occured trying to fetch 2022-06-15.', 'info': '(<class \'NameError\'>, NameError("name \'stuff_by_date\' is not defined"), <traceback object at 0x7f9c0748bf40>)'}

# %%
from pymongo import MongoClient
import pandas as pd




print('Loading secrets ... ')
from secrets import secrets
u = secrets.get('mongo').get('user')
p = secrets.get('mongo').get('password')

con_string = f'mongodb+srv://{u}:{p}@main-4-4.rph7u.mongodb.net/'


# targetdb = 'flickplay-development'
targetdb = 'flickplay-production'

print(f'Connecting to {targetdb}...')
client = MongoClient(con_string)
db = client[targetdb]
print('Connected!')


db.users.find_one({'username': 'allenn'})

# %%
stuff_by_date = dict()


start_date = datetime.date(2022,2,1).isoformat()
end_date = start_date

this_stuff = dict()

df = get_data_between(start_date=start_date, 
                  end_date=end_date,
                  verbose=1)


devices = dict(Counter(df['$model']).most_common(20))

n_users_by_device = dict()

for m in devices.keys()

    dd = df[df['$model'] == m ]
    print(f'''There are {len(set(dd['$user_id'].values))} unique users of device {m} on {start_date}.''')
    n_users_by_device[m] = len(set(dd['$user_id'].values))
    

this_stuff['raw'] = df
this_stuff['devlist'] = devices
this_stuff['users_by_model'] = n_users_by_device

print()

stuff_by_date[start_date] = this_stuff
# Out:
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-11-01&to_date=2022-11-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_first_open","properties":{"time":1667295103,"distinct_id":"2E802B65-580E-4937-A5FD-100783999DBA","$ae_first_app_open_date":"2022-11-01T09:31:43","$app_build_number":"5611","$app_version_
# Response received. Processing events between 2022-11-01 and 2022-11-01.
# 38504 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19199/942482732.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 38504 rows.

# %%
# Out:
# there are 24 unique users of device iPhone15,2
# there are 16 unique users of device iPhone12,3
# there are 8 unique users of device iPhone11,8
# there are 13 unique users of device iPhone13,4
# there are 10 unique users of device iPhone14,4
# there are 3 unique users of device iPhone10,3
# there are 10 unique users of device iPhone14,3
# there are 7 unique users of device iPhone14,2
# there are 4 unique users of device iPhone12,1
# there are 2 unique users of device iPhone10,5
# there are 3 unique users of device iPhone14,6
# there are 3 unique users of device iPhone14,5
# there are 1 unique users of device iPhone10,6
# there are 1 unique users of device iPhone11,6
# there are 5 unique users of device iPhone12,5
# there are 5 unique users of device iPhone12,8
# there are 6 unique users of device iPhone13,2
# there are 3 unique users of device iPhone13,3
# there are 2 unique users of device iPhone14,7
# there are 1 unique users of device iPhone11,2

# %%
df = get_data_between(start_date='2022-11-01',end_date='2022-11-02')
# Out:
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-11-01&to_date=2022-11-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# Response received. Processing events between 2022-11-01 and 2022-11-02.
# 75296 events received.
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_19159/309477019.py:57: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datetime = [ datetime.datetime.utcfromtimestamp(ts) for ts in df.time ]
# Flattened data has 75296 rows.

# %%
dict(Counter(df['$model']).most_common(10))
# Out:
# {'iPhone15,2': 14314,
#  'iPhone11,8': 11631,
#  'iPhone12,3': 11379,
#  'iPhone14,4': 7784,
#  'iPhone13,4': 7735,
#  'iPhone14,3': 5128,
#  'iPhone10,3': 3284,
#  'iPhone10,5': 3002,
#  'iPhone12,1': 2851,
#  'iPhone14,2': 2547}

# %%
df['$model
# Out:
# 0       iPhone10,2
# 1       iPhone10,2
# 2       iPhone10,2
# 3       iPhone10,2
# 4       iPhone10,2
#            ...
# 8575    iPhone13,4
# 8576    iPhone13,4
# 8577    iPhone13,4
# 8578    iPhone13,4
# 8579    iPhone13,4
# Name: $model, Length: 8580, dtype: object
