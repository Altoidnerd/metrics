# %%
from collections import Counter
import datetime
from datetime import timedelta
import json
import matplotlib.pyplot as plt
from os.path import abspath, isdir, isfile, join
import os
from os import mkdir
import pandas as pd
import requests
import sys

from flickplay.get_connections import get_alchemy_con, get_pymysql_con
from flickplay.ETL import get_data_between

# %%
dfs = []
    
outdir = '/Users/allen/Developer/clo/flickplay/mixpanel-events/update_tables/data'
outdir = os.path.abspath(outdir)

print('outdir:', outdir)

i_date = datetime.date(2022,3,1)
dt = datetime.timedelta(days=1)

for i in range(100):
    start_date = (i_date + dt*i).isoformat()
    end_date = start_date
    
    if isfile(f'{outdir}/{start_date}.csv'):
        print(f'{outdir}/{start_date}.csv exists; skipping.')
        continue
    
    print(start_date)
    try:
        df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)

        devices = dict(Counter(df['$model']).most_common(20))
        devices_users = dict()
        devices_N_users = dict()

        outfile = join(abspath(outdir), f'{start_date}.csv')
        print(f'Saving to {outfile}.') # defaults to ./data/
        
        df.to_csv(outfile)
        dfs.append(df)
        print(len(odfs), 'many dfs')

        dfs.append(df)
        plt.xticks(rotation=70)
        plt.yscale('log')
        plt.title(f'Frequency of most common devices on {start_date}.')
        plt.bar(devices.keys(), devices.values())
        plt.show()
        print('Number of dfs:',len(dfs))
    

    except:
        continue
# Out:
# '/Users/allen/Developer/clo/flickplay/mixpanel-events/data'

# %%
dfs = []
    
outdir = '/Users/allen/Developer/clo/flickplay/mixpanel-events/update_tables/data'
outdir = os.path.abspath(outdir)

print('outdir:', outdir)

i_date = datetime.date(2022,3,1)
dt = datetime.timedelta(days=1)

for i in range(100):
    start_date = (i_date + dt*i).isoformat()
    end_date = start_date
    
    if isfile(f'{outdir}/{start_date}.csv'):
        print(f'{outdir}/{start_date}.csv exists; skipping.')
        continue
    
    print(start_date)
    try:
        df = get_data_between(start_date=start_date, 
                              end_date=end_date,
                              verbose=1)

        devices = dict(Counter(df['$model']).most_common(20))
        devices_users = dict()
        devices_N_users = dict()

        outfile = join(abspath(outdir), f'{start_date}.csv')
        print(f'Saving to {outfile}.') # defaults to ./data/
        
        df.to_csv(outfile)
        dfs.append(df)
        print(len(odfs), 'many dfs')

        dfs.append(df)
        plt.xticks(rotation=70)
        plt.yscale('log')
        plt.title(f'Frequency of most common devices on {start_date}.')
        plt.bar(devices.keys(), devices.values())
        plt.show()
        print('Number of dfs:',len(dfs))
    

    except:
        continue
# Out:
# outdir: /Users/allen/Developer/clo/flickplay/mixpanel-events/update_tables/data
# 2022-03-01
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-01&to_date=2022-03-01 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# {"event":"$ae_updated","properties":{"time":1646099111,"distinct_id":"61c2a409291cbd51047f5b4a","$ae_updated_version":"1.61.0","$app_build_number":"3923","$app_version_string":"1.61.0","$carrier":"","
# Response received. Processing events between 2022-03-01 and 2022-03-01.
# 56936 events received.
# Flattened data has 56936 rows.
# Saving to /Users/allen/Developer/clo/flickplay/mixpanel-events/update_tables/data/2022-03-01.csv.
# 2022-03-02
# Doing API call to mixpanel.
# Getting https://data.mixpanel.com/api/2.0/export?from_date=2022-03-02&to_date=2022-03-02 with
# {'accept': 'text/plain', 'authorization': 'Basic Y2M3ZmViNzk2MWY4ZTUzNjQxNDM1MGNjMzZlMDdmNWY6'}
# ...

# %%
import glob
import os


#os.chdir('''/Users/allen/Desktop/mixpanel-events/data''')
os.chdir('data')
dfs = []
infiles = list(sorted(glob.glob('2023-*.csv')))
ifinal = len(infiles)//2
               
for inf in infiles[0:ifinal]:
    dfs.append(pd.read_csv(inf))

    
df = pd.concat(dfs)

# %%
import datetime
import pandas as pd
import os
import glob
import warnings
warnings.filterwarnings("ignore")

os.chdir('''/Users/allen/Developer/clo/flickplay/mixpanel-events/data''')
# os.chdir('''./data''')
infiles = list(sorted(glob.glob('2023*.csv')))
bigdf=pd.DataFrame(columns = [ c for c in pd.read_csv(infiles[0]).columns if c not in ['Unnamed: 0'] ])

for infile in infiles[:20]:
    df = pd.read_csv(infile, low_memory=True)
    df.index=df.date
    df = df.drop(columns = ['Unnamed: 0'])
    print(min(df.index),max(df.index))
    bigdf = pd.concat([bigdf, df])
    print(len(df), len(bigdf))
    
# bigdf.index = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
# bigdf['date'] = bigdf.index.values
bigdf['date'] = [ datetime.date.fromtimestamp(ts).isoformat() for ts in bigdf.time]
bigdf

# %%
import os
import pandas as pd
import datetime
from datetime import timedelta
import glob
import warnings
import pymysql
from mysql.connector import connect
import os
from sqlalchemy import create_engine
import sys

host='localhost'
user='root'
password=''
port=3306
database='fpa'
creds = dict(host=host,user=user,password=password,database=database)

def get_alchemy_local_con(database='fpa'):
    host='localhost'
    user='root'
    password=''
    port=3306
    database=database
    return create_engine(f'mysql+pymysql://{user}:{password}@localhost/{database}')



con = get_alchemy_local_con()

columns = pd.read_sql('SELECT * FROM fpa.events LIMIT 1', con).columns

df1 = pd.DataFrame(columns = columns )

# bigdf = pd.concat([df1, bigdf])

# bigdf = bigdf[columns]

df1
# Out:
# Empty DataFrame
# ...

# %%
con = get_alchemy_con()

# %%
df = pd.read_sql('''SHOW DATABASES;''',con)

# %%
df
# Out:
#              Database
# 0                 fpa
# 1  information_schema
# 2               mysql
# 3  performance_schema
# 4                 SAS
# 5                 sys

# %%
from flickplay.get_gcp_connections import GCPConnector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/n6/zc0mx_b953d7fmyh83yrflj40000gn/T/ipykernel_42664/2976231829.py in <module>
# ----> 1 from flickplay.get_gcp_connections import GCPConnector
#
# ModuleNotFoundError: No module named 'flickplay.get_gcp_connections'

# %%
G
